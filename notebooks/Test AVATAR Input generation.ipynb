# %% [markdown]
# # Test Avatar Input Generation

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from ocpa.objects.log.importer.ocel import factory as ocel_import_factory
from ocpa.objects.log.importer.csv import factory as ocel_import_factory_csv

# %%
def writeVariantToFile(file, lst):
    with open(file, 'w') as outfile:
        for entry in lst:
            print_trace = ""
            for index, ev in enumerate(entry):
                if index == 0:
                    print_trace = str(ev).replace(" ", "")
                else:
                    print_trace = print_trace + " " + str(ev).replace(" ", "")
            outfile.write(print_trace.strip() + "\n")

# %% [markdown]
# # O2C Log

# %% [markdown]
# ### Standard Petri Net

# %% [markdown]
# In a first step, we load the OCEL-log into the notebook and generate the object-centric petri net.

# %%
filename = "../src/data/jsonocel/order_process.jsonocel"
ocel = ocel_import_factory.apply(filename)

# %%
ocel.log.log
# Out:
#              event_id event_activity            event_timestamp  \
# event_index
# 0                   0    Place Order 2022-10-20 16:56:19.864004
# 1                   1  Confirm Order 2022-10-20 16:56:20.864004
# 2                   2      Pick Item 2022-10-20 17:01:51.864004
# 3                   3      Pick Item 2022-10-20 17:01:51.864004
# 4                   4      Pay Order 2022-10-20 17:01:51.864004
# ...               ...            ...                        ...
# 2386             2386    Start Route 2022-12-17 23:00:15.871959
# 2387             2387      End Route 2022-12-18 04:01:04.871959
# 2388             2388       Fuel Car 2022-12-18 06:59:45.871959
# 2389             2389    Start Route 2022-12-18 07:25:24.871959
# 2390             2390      End Route 2022-12-18 12:23:32.871959
#
#                  event_start_timestamp     order                item  \
# event_index
# 0           2022-10-20 16:56:19.864004  [order1]      [item2, item3]
# 1           2022-10-20 16:56:20.864004  [order1]      [item2, item3]
# 2           2022-10-20 17:01:51.864004        []             [item3]
# 3           2022-10-20 17:01:51.864004        []             [item2]
# 4           2022-10-20 17:01:51.864004  [order1]                  []
# ...                                ...       ...                 ...
# 2386        2022-12-17 23:00:15.871959        []  [item199, item196]
# 2387        2022-12-18 04:01:04.871959        []  [item199, item196]
# 2388        2022-12-18 06:59:45.871959        []                  []
# 2389        2022-12-18 07:25:24.871959        []  [item259, item265]
# 2390        2022-12-18 12:23:32.871959        []  [item259, item265]
#
#                   delivery
# event_index
# 0                       []
# 1                       []
# 2                       []
# 3                       []
# 4                       []
# ...                    ...
# 2386          [delivery64]
# 2387          [delivery64]
# 2388         [delivery193]
# 2389         [delivery193]
# 2390         [delivery193]
#
# [2391 rows x 7 columns]

# %%
# since the process execution mappings have lists of length one,
# we create another dictionary that only contains the the value inside the list to be able to derive the case
mapping_dict = {key: ocel.process_execution_mappings[key][0] for key in ocel.process_execution_mappings}
# we generate a new column in the class (log) that contains the process execution (case) number via the generated dictionary
ocel.log.log['event_execution'] = ocel.log.log.index.map(mapping_dict)

# %%
ocel.log.log
# Out:
#              event_id event_activity            event_timestamp  \
# event_index
# 0                   0    Place Order 2022-10-20 16:56:19.864004
# 1                   1  Confirm Order 2022-10-20 16:56:20.864004
# 2                   2      Pick Item 2022-10-20 17:01:51.864004
# 3                   3      Pick Item 2022-10-20 17:01:51.864004
# 4                   4      Pay Order 2022-10-20 17:01:51.864004
# ...               ...            ...                        ...
# 2386             2386    Start Route 2022-12-17 23:00:15.871959
# 2387             2387      End Route 2022-12-18 04:01:04.871959
# 2388             2388       Fuel Car 2022-12-18 06:59:45.871959
# 2389             2389    Start Route 2022-12-18 07:25:24.871959
# 2390             2390      End Route 2022-12-18 12:23:32.871959
#
#                  event_start_timestamp     order                item  \
# event_index
# 0           2022-10-20 16:56:19.864004  [order1]      [item2, item3]
# 1           2022-10-20 16:56:20.864004  [order1]      [item2, item3]
# 2           2022-10-20 17:01:51.864004        []             [item3]
# 3           2022-10-20 17:01:51.864004        []             [item2]
# 4           2022-10-20 17:01:51.864004  [order1]                  []
# ...                                ...       ...                 ...
# 2386        2022-12-17 23:00:15.871959        []  [item199, item196]
# 2387        2022-12-18 04:01:04.871959        []  [item199, item196]
# 2388        2022-12-18 06:59:45.871959        []                  []
# 2389        2022-12-18 07:25:24.871959        []  [item259, item265]
# 2390        2022-12-18 12:23:32.871959        []  [item259, item265]
#
#                   delivery  event_execution
# event_index
# 0                       []               33
# 1                       []               33
# 2                       []               33
# 3                       []               33
# 4                       []               33
# ...                    ...              ...
# 2386          [delivery64]                0
# 2387          [delivery64]                0
# 2388         [delivery193]                0
# 2389         [delivery193]                0
# 2390         [delivery193]                0
#
# [2391 rows x 8 columns]

# %%
# generate a grouped df such that we can iterate through the log case by case (sort by timestamp to ensure the correct process sequence)
grouped_df = ocel.log.log.sort_values('event_timestamp').groupby('event_execution')

# %%
sorted_log = ocel.log.log.sort_values(['event_execution','event_timestamp'])

# %%
sorted_log
# Out:
#              event_id     event_activity            event_timestamp  \
# event_index
# 5                   5        Place Order 2022-10-20 17:06:18.864004
# 6                   6      Confirm Order 2022-10-20 17:06:19.864004
# 7                   7  Item out of stock 2022-10-20 17:11:46.864004
# 8                   8          Pick Item 2022-10-20 17:11:47.864004
# 9                   9          Pay Order 2022-10-20 17:11:47.864004
# ...               ...                ...                        ...
# 1220             1220          Pick Item 2022-10-21 23:47:47.867991
# 1240             1240         Load Cargo 2022-10-22 00:18:31.867991
# 1838             1838           Fuel Car 2022-10-29 13:17:48.870968
# 1840             1840        Start Route 2022-10-29 13:43:07.870968
# 1844             1844          End Route 2022-10-29 18:43:20.870968
#
#                  event_start_timestamp     order                item  \
# event_index
# 5           2022-10-20 17:06:18.864004  [order2]      [item4, item5]
# 6           2022-10-20 17:06:19.864004  [order2]      [item4, item5]
# 7           2022-10-20 17:11:46.864004        []             [item5]
# 8           2022-10-20 17:11:47.864004        []             [item4]
# 9           2022-10-20 17:11:47.864004  [order2]                  []
# ...                                ...       ...                 ...
# 1220        2022-10-21 23:47:47.867991        []           [item373]
# 1240        2022-10-22 00:18:31.867991        []  [item373, item372]
# 1838        2022-10-29 13:17:48.870968        []                  []
# 1840        2022-10-29 13:43:07.870968        []  [item373, item372]
# 1844        2022-10-29 18:43:20.870968        []  [item373, item372]
#
#                   delivery  event_execution
# event_index
# 5                       []                0
# 6                       []                0
# 7                       []                0
# 8                       []                0
# 9                       []                0
# ...                    ...              ...
# 1220                    []               47
# 1240         [delivery139]               47
# 1838         [delivery139]               47
# 1840         [delivery139]               47
# 1844         [delivery139]               47
#
# [2391 rows x 8 columns]

# %%
object_types = ["order","item","delivery"]

# %%
columns_to_consider = ['event_activity']

# %%
columns_to_consider.extend(object_types)

# %%
columns_to_consider
# Out:
# ['event_activity', 'order', 'item', 'delivery']

# %%
sorted_log.loc[:, columns_to_consider]
# Out:
#                 event_activity     order                item       delivery
# event_index
# 5                  Place Order  [order2]      [item4, item5]             []
# 6                Confirm Order  [order2]      [item4, item5]             []
# 7            Item out of stock        []             [item5]             []
# 8                    Pick Item        []             [item4]             []
# 9                    Pay Order  [order2]                  []             []
# ...                        ...       ...                 ...            ...
# 1220                 Pick Item        []           [item373]             []
# 1240                Load Cargo        []  [item373, item372]  [delivery139]
# 1838                  Fuel Car        []                  []  [delivery139]
# 1840               Start Route        []  [item373, item372]  [delivery139]
# 1844                 End Route        []  [item373, item372]  [delivery139]
#
# [2391 rows x 4 columns]

# %%
# create a list of lists from the DataFrame
input_sentences = []
for row in sorted_log.loc[:, columns_to_consider].values:
    input_sentences.append(list(row))

print(input_sentences)
# Out:
# [['Place Order', ['order2'], ['item4', 'item5'], []], ['Confirm Order', ['order2'], ['item4', 'item5'], []], ['Item out of stock', [], ['item5'], []], ['Pick Item', [], ['item4'], []], ['Pay Order', ['order2'], [], []], ['Reorder Item', [], ['item5'], []], ['Place Order', ['order5'], ['item11', 'item10'], []], ['Confirm Order', ['order5'], ['item11', 'item10'], []], ['Pay Order', ['order5'], [], []], ['Pick Item', [], ['item10'], []], ['Pick Item', [], ['item11'], []], ['Place Order', ['order6'], ['item12', 'item13'], []], ['Confirm Order', ['order6'], ['item12', 'item13'], []], ['Item out of stock', [], ['item13'], []], ['Pick Item', [], ['item12'], []], ['Payment Reminder', ['order6'], [], []], ['Reorder Item', [], ['item13'], []], ['Place Order', ['order7'], ['item14', 'item15'], []], ['Confirm Order', ['order7'], ['item14', 'item15'], []], ['Item out of stock', [], ['item14'], []], ['Reorder Item', [], ['item14'], []], ['Pay Order', ['order7'], [], []], ['Pick Item', [], ['item15'], []], ['Place Order', ['order8'], ['item16', 'item17'], []], ['Confirm Order', ['order8'], ['item16', 'item17'], []], ['Item out of stock', [], ['item17'], []], ['Payment Reminder', ['order8'], [], []], ['Reorder Item', [], ['item17'], []], ['Pick Item', [], ['item16'], []], ['Load Cargo', [], ['item4', 'item11'], ['delivery1']], ['Place Order', ['order9'], ['item18', 'item19'], []], ['Confirm Order', ['order9'], ['item18', 'item19'], []], ['Item out of stock', [], ['item18'], []], ['Pick Item', [], ['item19'], []], ['Pay Order', ['order9'], [], []], ['Reorder Item', [], ['item18'], []], ['Load Cargo', [], ['item12', 'item10'], ['delivery7']], ['Place Order', ['order10'], ['item21', 'item20'], []], ['Confirm Order', ['order10'], ['item21', 'item20'], []], ['Pay Order', ['order10'], [], []], ['Pick Item', [], ['item21'], []], ['Pick Item', [], ['item20'], []], ['Load Cargo', [], ['item16', 'item15'], ['delivery5']], ['Place Order', ['order13'], ['item26', 'item27'], []], ['Confirm Order', ['order13'], ['item26', 'item27'], []], ['Load Cargo', [], ['item21', 'item19'], ['delivery6']], ['Payment Reminder', ['order13'], [], []], ['Pick Item', [], ['item26'], []], ['Pick Item', [], ['item27'], []], ['Place Order', ['order14'], ['item28', 'item29'], []], ['Confirm Order', ['order14'], ['item28', 'item29'], []], ['Item out of stock', [], ['item29'], []], ['Payment Reminder', ['order14'], [], []], ['Pick Item', [], ['item28'], []], ['Reorder Item', [], ['item29'], []], ['Place Order', ['order15'], ['item30', 'item31'], []], ['Confirm Order', ['order15'], ['item30', 'item31'], []], ['Item out of stock', [], ['item31'], []], ['Item out of stock', [], ['item30'], []], ['Reorder Item', [], ['item31'], []], ['Pay Order', ['order15'], [], []], ['Reorder Item', [], ['item30'], []], ['Place Order', ['order16'], ['item32', 'item33'], []], ['Confirm Order', ['order16'], ['item32', 'item33'], []], ['Item out of stock', [], ['item32'], []], ['Payment Reminder', ['order16'], [], []], ['Pick Item', [], ['item33'], []], ['Reorder Item', [], ['item32'], []], ['Load Cargo', [], ['item26', 'item20'], ['delivery16']], ['Place Order', ['order17'], ['item35', 'item34'], []], ['Confirm Order', ['order17'], ['item35', 'item34'], []], ['Item out of stock', [], ['item34'], []], ['Payment Reminder', ['order17'], [], []], ['Pick Item', [], ['item35'], []], ['Reorder Item', [], ['item34'], []], ['Load Cargo', [], ['item27', 'item28'], ['delivery14']], ['Place Order', ['order18'], ['item37', 'item36'], []], ['Confirm Order', ['order18'], ['item37', 'item36'], []], ['Item out of stock', [], ['item36'], []], ['Payment Reminder', ['order18'], [], []], ['Pick Item', [], ['item37'], []], ['Reorder Item', [], ['item36'], []], ['Place Order', ['order19'], ['item38', 'item39'], []], ['Confirm Order', ['order19'], ['item38', 'item39'], []], ['Item out of stock', [], ['item39'], []], ['Pay Order', ['order19'], [], []], ['Pick Item', [], ['item38'], []], ['Reorder Item', [], ['item39'], []],  ...
