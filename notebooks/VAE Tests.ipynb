# %% [markdown]
# # VAE Tests

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from ocpa.objects.log.importer.ocel import factory as ocel_import_factory
from ocpa.algo.conformance.precision_and_fitness import evaluator as quality_measure_factory
from ocpa.algo.discovery.ocpn import algorithm as ocpn_discovery_factory
from src.utils import get_happy_path_log, create_flower_model, generate_variant_model, sample_traces,

# %%
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
import argparse
import json
from keras import backend as K
from keras.losses import categorical_crossentropy
from keras.layers import Layer
from keras.layers import Input, LSTM, TimeDistributed
from keras.layers.core import Dense, Lambda
from keras.models import Model
from nltk.tokenize import word_tokenize
import tensorflow as tf
import pandas as pd
import numpy as np
import codecs
import os, re
from tqdm import tqdm
import random
from datetime import datetime, timedelta
import time

# %%
filename = "../src/data/jsonocel/order_process.jsonocel"
ocel = ocel_import_factory.apply(filename)
ocpn = ocpn_discovery_factory.apply(ocel, parameters={"debug": False})
train_log = sample_traces(ocel, ocpn, 10000)
# Out:
# Check the arcs: 100%|██████████| 46/46 [00:00<?, ?it/s]
# Generate the traces: 100%|██████████| 10000/10000 [00:00<00:00, 23734.58it/s]

# %%
train_log
# Out:
# [['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Fuel Car',
#   'Reorder Item',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Load Cargo',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Start Route',
#   'Pay Order',
#   'Item out of stock',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Fuel Car',
#   'Item out of stock',
#   'Pay Order',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Fuel Car',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Reorder Item',
#   'Pay Order',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Payment Reminder',
#   'Pay Order',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Fuel Car',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pay Order',
#   'Fuel Car',
#   'Load Cargo',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Fuel Car',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Fuel Car',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Pay Order',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Start Route',
#   'End Route',
#   'Payment Reminder',
#   'Pay Order'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Fuel Car',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Fuel Car',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Payment Reminder',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Fuel Car',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Fuel Car',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Fuel Car',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Fuel Car',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Item out of stock',
#   'Fuel Car',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Item out of stock',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Fuel Car',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Fuel Car',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Fuel Car',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'Item out of stock',
#   'Reorder Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Fuel Car',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Item out of stock',
#   'End Route',
#   'Payment Reminder',
#   'Pay Order'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Fuel Car',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pick Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Start Route',
#   'Payment Reminder',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Fuel Car',
#   'Pay Order',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Load Cargo',
#   'Start Route',
#   'End Route',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Fuel Car',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Fuel Car',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'Payment Reminder',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Fuel Car',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'Item out of stock',
#   'Reorder Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Fuel Car',
#   'Reorder Item',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Payment Reminder',
#   'Pay Order',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Item out of stock',
#   'Payment Reminder',
#   'Fuel Car',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Payment Reminder',
#   'Start Route',
#   'Pick Item',
#   'Pay Order',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Fuel Car',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'End Route',
#   'Pay Order'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Fuel Car',
#   'Payment Reminder',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'Payment Reminder',
#   'End Route',
#   'Pay Order'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pick Item',
#   'Payment Reminder',
#   'Reorder Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Load Cargo',
#   'Pick Item',
#   'Start Route',
#   'Payment Reminder',
#   'Load Cargo',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'Item out of stock',
#   'Reorder Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Fuel Car',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Pay Order',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Item out of stock',
#   'Reorder Item',
#   'End Route',
#   'Pay Order'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Fuel Car',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'Item out of stock',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Fuel Car',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'End Route',
#   'Pay Order'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Fuel Car',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Fuel Car',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'End Route',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Fuel Car',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Payment Reminder',
#   'Reorder Item',
#   'Fuel Car',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Payment Reminder',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Fuel Car',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Fuel Car',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Start Route',
#   'Payment Reminder',
#   'End Route',
#   'Pay Order'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'Item out of stock',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'End Route',
#   'Pay Order'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pick Item',
#   'Pay Order',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pick Item',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pay Order',
#   'Load Cargo',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Payment Reminder',
#   'Payment Reminder',
#   'End Route',
#   'Payment Reminder',
#   'Pay Order'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Load Cargo',
#   'Fuel Car',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'Pay Order',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Fuel Car',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Payment Reminder',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Fuel Car',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Start Route',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Fuel Car',
#   'Reorder Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route',
#   'Payment Reminder',
#   'Pay Order'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Fuel Car',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Item out of stock',
#   'Load Cargo',
#   'Payment Reminder',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
# ...
#   'Pick Item',
#   'Fuel Car',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Fuel Car',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'Pay Order',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Fuel Car',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pick Item',
#   'Payment Reminder',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Fuel Car',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Item out of stock',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Reorder Item',
#   'Load Cargo',
#   'Pay Order',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Item out of stock',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Fuel Car',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Fuel Car',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Item out of stock',
#   'Pay Order',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Fuel Car',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Fuel Car',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Reorder Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Pick Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Start Route',
#   'End Route',
#   'Pay Order'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Fuel Car',
#   'Item out of stock',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Payment Reminder',
#   'Payment Reminder',
#   'End Route',
#   'Pay Order'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Payment Reminder',
#   'Fuel Car',
#   'Load Cargo',
#   'Pay Order',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Fuel Car',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Reorder Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Item out of stock',
#   'Fuel Car',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Load Cargo',
#   'Pay Order',
#   'Item out of stock',
#   'Fuel Car',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Pick Item',
#   'Start Route',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Load Cargo',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Fuel Car',
#   'Item out of stock',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Pick Item',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Fuel Car',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Item out of stock',
#   'Payment Reminder',
#   'Load Cargo',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pay Order',
#   'Start Route',
#   'Pick Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Pay Order',
#   'Fuel Car',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pay Order',
#   'Pick Item',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Fuel Car',
#   'Item out of stock',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pick Item',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Pick Item',
#   'Load Cargo',
#   'Pay Order',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Pay Order',
#   'Load Cargo',
#   'Item out of stock',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Place Order',
#   'Confirm Order',
#   'Item out of stock',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pay Order',
#   'Pick Item',
#   'Fuel Car',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pick Item',
#   'Payment Reminder',
#   'Pay Order',
#   'Item out of stock',
#   'Load Cargo',
#   'Reorder Item',
#   'Start Route',
#   'Pick Item',
#   'Load Cargo',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Reorder Item',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pay Order',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'Item out of stock',
#   'End Route'],
#  ['Fuel Car',
#   'Place Order',
#   'Confirm Order',
#   'Payment Reminder',
#   'Pick Item',
#   'Payment Reminder',
#   'Payment Reminder',
#   'Item out of stock',
#   'Payment Reminder',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Payment Reminder',
#   'Start Route',
#   'Pay Order',
#   'End Route'],
#  ['Place Order',
#   'Fuel Car',
#   'Confirm Order',
#   'Pay Order',
#   'Item out of stock',
#   'Reorder Item',
#   'Pick Item',
#   'Load Cargo',
#   'Start Route',
#   'End Route'],
#  ...]

# %%
data_path = '../src/data/sampled_data_order.txt'

# %%
# with open(data_path, "w", encoding="utf-8") as file:
#     for sentence in train_log:
#         line = " ".join(sentence) + "\n"
#         file.write(line)

# %%
# Open the file in read mode
file = open(data_path, "r")

# Read the file line by line and split into words
lines = file.readlines()
file.close()

# Process each line and store words in a list of lists
train_log = []
for line in lines:
    words = line.lower().strip().split()
    line = " ".join(words)
    train_log.append(line)

# %%
train_log
# Out:
# ['place order confirm order item out of stock fuel car reorder item pick item payment reminder pay order load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder item out of stock reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pick item payment reminder payment reminder load cargo pay order start route end route',
#  'place order fuel car confirm order pick item payment reminder load cargo item out of stock reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pick item load cargo payment reminder start route pay order item out of stock end route',
#  'fuel car place order confirm order pick item load cargo pay order item out of stock reorder item start route end route',
#  'place order fuel car confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order confirm order payment reminder fuel car item out of stock pay order pick item reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock pick item reorder item pick item payment reminder payment reminder payment reminder pay order load cargo start route end route',
#  'place order confirm order pay order pick item item out of stock load cargo fuel car reorder item start route end route',
#  'fuel car place order confirm order pay order pick item load cargo item out of stock start route reorder item pick item end route',
#  'fuel car place order confirm order payment reminder payment reminder payment reminder pick item load cargo start route pay order end route',
#  'fuel car place order confirm order pay order item out of stock pick item load cargo reorder item start route end route',
#  'fuel car place order confirm order item out of stock payment reminder pay order pick item reorder item load cargo pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder pay order item out of stock pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item payment reminder load cargo reorder item pay order start route pick item end route',
#  'fuel car place order confirm order pick item load cargo item out of stock start route payment reminder pay order end route',
#  'fuel car place order confirm order pick item item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pick item load cargo pay order item out of stock reorder item start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock reorder item pay order pick item fuel car load cargo start route end route',
#  'place order fuel car confirm order item out of stock payment reminder pay order pick item load cargo start route reorder item end route',
#  'place order confirm order item out of stock pick item reorder item pay order fuel car load cargo pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item load cargo pay order reorder item start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item load cargo reorder item start route pick item load cargo start route end route',
#  'place order confirm order payment reminder payment reminder pay order item out of stock fuel car pick item reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock pay order pick item load cargo fuel car reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock pick item load cargo payment reminder pay order start route reorder item pick item load cargo end route',
#  'fuel car place order confirm order item out of stock reorder item pick item payment reminder payment reminder pay order load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo item out of stock reorder item start route pick item end route',
#  'fuel car place order confirm order payment reminder pay order pick item load cargo item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pick item load cargo payment reminder start route end route payment reminder pay order',
#  'place order fuel car confirm order item out of stock payment reminder pay order pick item load cargo start route reorder item end route',
#  'place order confirm order pay order pick item fuel car item out of stock load cargo start route reorder item end route',
#  'place order confirm order payment reminder pay order pick item load cargo item out of stock reorder item pick item load cargo fuel car start route end route',
#  'fuel car place order confirm order item out of stock pick item load cargo start route reorder item pick item pay order end route',
#  'fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item load cargo reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item item out of stock payment reminder load cargo reorder item pick item payment reminder load cargo pay order start route end route',
#  'fuel car place order confirm order item out of stock reorder item pick item load cargo payment reminder pay order start route end route',
#  'fuel car place order confirm order pick item item out of stock load cargo payment reminder reorder item pay order pick item start route load cargo end route',
#  'place order confirm order payment reminder item out of stock fuel car pay order reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock pay order pick item load cargo reorder item pick item fuel car load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order pay order fuel car pick item load cargo item out of stock reorder item start route pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock payment reminder reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock fuel car pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock payment reminder reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item pay order item out of stock load cargo reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock pick item reorder item pick item load cargo pay order start route end route',
#  'fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item load cargo pay order item out of stock reorder item start route end route',
#  'fuel car place order confirm order item out of stock payment reminder pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pick item item out of stock load cargo pay order reorder item pick item load cargo start route end route',
#  'place order confirm order payment reminder payment reminder item out of stock fuel car reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pay order pick item item out of stock reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder pay order pick item load cargo item out of stock reorder item start route end route',
#  'fuel car place order confirm order pick item item out of stock reorder item pay order load cargo start route pick item load cargo end route',
#  'place order fuel car confirm order payment reminder item out of stock reorder item pay order pick item load cargo start route end route',
#  'place order fuel car confirm order pay order pick item load cargo start route item out of stock end route',
#  'place order confirm order pick item payment reminder item out of stock payment reminder pay order fuel car load cargo reorder item start route end route',
#  'place order confirm order pick item pay order fuel car load cargo item out of stock start route reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo item out of stock start route end route',
#  'place order fuel car confirm order item out of stock reorder item payment reminder payment reminder pay order pick item load cargo start route end route',
#  'place order confirm order payment reminder fuel car item out of stock reorder item pay order pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock pick item pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pay order item out of stock pick item load cargo reorder item start route pick item end route',
#  'place order fuel car confirm order payment reminder item out of stock payment reminder payment reminder reorder item payment reminder pay order pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder item out of stock payment reminder pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item payment reminder pay order load cargo start route item out of stock reorder item end route',
#  'fuel car place order confirm order payment reminder payment reminder payment reminder payment reminder payment reminder pick item item out of stock reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pick item load cargo payment reminder payment reminder pay order start route end route',
#  'fuel car place order confirm order pick item item out of stock reorder item payment reminder pick item payment reminder pay order load cargo start route end route',
#  'fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route end route',
#  'fuel car place order confirm order item out of stock reorder item pick item pay order load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'place order confirm order pay order item out of stock pick item fuel car reorder item load cargo start route end route',
#  'place order fuel car confirm order payment reminder pay order item out of stock pick item load cargo reorder item start route end route',
#  'fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item load cargo start route item out of stock end route payment reminder pay order',
#  'fuel car place order confirm order payment reminder item out of stock pick item reorder item payment reminder load cargo pay order pick item load cargo start route end route',
#  'place order confirm order fuel car pay order pick item item out of stock load cargo reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item reorder item load cargo pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder item out of stock reorder item pay order pick item load cargo start route end route',
#  'place order confirm order pay order pick item item out of stock reorder item pick item load cargo fuel car start route end route',
#  'fuel car place order confirm order item out of stock payment reminder payment reminder reorder item pick item payment reminder load cargo payment reminder payment reminder start route payment reminder pay order end route',
#  'place order confirm order pick item payment reminder fuel car pay order load cargo item out of stock start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pay order pick item item out of stock load cargo reorder item pick item start route load cargo end route',
#  'place order fuel car confirm order item out of stock payment reminder payment reminder payment reminder payment reminder payment reminder pick item reorder item pick item payment reminder pay order load cargo start route end route',
#  'fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item load cargo start route pick item load cargo start route end route',
#  'place order fuel car confirm order pick item payment reminder payment reminder load cargo start route end route payment reminder payment reminder pay order',
#  'fuel car place order confirm order pay order pick item item out of stock load cargo start route reorder item pick item load cargo end route',
#  'place order confirm order payment reminder fuel car item out of stock payment reminder payment reminder pick item reorder item load cargo pick item payment reminder pay order load cargo start route end route',
#  'fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo item out of stock start route reorder item pick item end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pick item item out of stock payment reminder pay order load cargo reorder item pick item start route load cargo start route end route',
#  'place order confirm order pick item fuel car item out of stock payment reminder payment reminder reorder item load cargo start route payment reminder pay order end route',
#  'place order confirm order pick item pay order item out of stock reorder item fuel car pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock payment reminder payment reminder pay order pick item reorder item load cargo pick item start route end route',
#  'place order confirm order fuel car item out of stock reorder item payment reminder pick item payment reminder payment reminder payment reminder payment reminder pay order load cargo start route end route',
#  'place order confirm order fuel car payment reminder pick item pay order load cargo start route item out of stock reorder item end route',
#  'fuel car place order confirm order payment reminder item out of stock reorder item payment reminder pick item pay order load cargo start route end route',
#  'fuel car place order confirm order item out of stock pay order pick item reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order confirm order fuel car payment reminder payment reminder item out of stock pick item reorder item pick item load cargo payment reminder payment reminder start route pay order end route',
#  'place order confirm order payment reminder item out of stock fuel car reorder item pick item payment reminder pay order load cargo start route end route',
#  'fuel car place order confirm order item out of stock payment reminder pay order pick item reorder item load cargo start route end route',
#  'place order confirm order fuel car payment reminder pick item load cargo pay order item out of stock reorder item start route pick item end route',
#  'fuel car place order confirm order pay order pick item load cargo item out of stock reorder item pick item start route end route',
#  'place order fuel car confirm order pick item item out of stock load cargo payment reminder pay order start route reorder item end route',
#  'place order confirm order payment reminder pick item payment reminder item out of stock payment reminder fuel car load cargo start route reorder item payment reminder pay order end route',
#  'place order fuel car confirm order pay order pick item load cargo item out of stock reorder item start route end route',
#  'fuel car place order confirm order pick item pay order item out of stock load cargo start route end route',
#  'place order confirm order fuel car pay order pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder payment reminder pick item item out of stock load cargo reorder item payment reminder start route pick item pay order end route',
#  'fuel car place order confirm order item out of stock reorder item payment reminder pay order pick item load cargo start route end route',
#  'place order confirm order payment reminder payment reminder fuel car payment reminder item out of stock pick item load cargo reorder item pick item start route end route pay order',
#  'place order confirm order pick item fuel car payment reminder load cargo item out of stock reorder item pick item start route payment reminder end route pay order',
#  'fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route end route',
#  'fuel car place order confirm order payment reminder item out of stock pick item payment reminder reorder item payment reminder payment reminder payment reminder load cargo pick item start route payment reminder load cargo pay order start route end route',
#  'place order fuel car confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock reorder item pay order pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder pay order pick item item out of stock load cargo reorder item start route pick item end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item pay order load cargo start route item out of stock reorder item end route',
#  'fuel car place order confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock pick item reorder item pay order pick item fuel car load cargo start route end route',
#  'fuel car place order confirm order pick item pay order load cargo start route end route',
#  'place order fuel car confirm order pick item payment reminder item out of stock reorder item payment reminder load cargo pay order start route pick item load cargo start route end route',
#  'fuel car place order confirm order pick item load cargo start route item out of stock reorder item end route pay order',
#  'fuel car place order confirm order item out of stock reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock reorder item pick item pay order load cargo start route end route',
#  'place order fuel car confirm order pay order pick item item out of stock load cargo start route reorder item pick item load cargo end route',
#  'place order fuel car confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item load cargo start route reorder item pick item load cargo end route',
#  'place order confirm order payment reminder item out of stock fuel car payment reminder pick item payment reminder pay order load cargo reorder item pick item start route load cargo end route',
#  'fuel car place order confirm order payment reminder pick item pay order load cargo start route item out of stock end route',
#  'fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route end route',
#  'place order confirm order item out of stock payment reminder payment reminder pick item fuel car load cargo start route reorder item pick item end route pay order',
#  'place order confirm order item out of stock pick item payment reminder load cargo fuel car start route pay order end route',
#  'place order fuel car confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order pick item load cargo fuel car item out of stock payment reminder pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder payment reminder pick item load cargo payment reminder item out of stock start route reorder item pick item end route payment reminder payment reminder payment reminder payment reminder pay order',
#  'fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pay order pick item load cargo item out of stock reorder item pick item start route end route',
#  'place order confirm order pay order item out of stock fuel car reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item reorder item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo item out of stock reorder item start route pick item end route',
#  'fuel car place order confirm order payment reminder item out of stock reorder item pick item load cargo payment reminder pay order start route end route',
#  'fuel car place order confirm order item out of stock payment reminder pay order pick item load cargo reorder item start route end route',
#  'fuel car place order confirm order payment reminder pick item load cargo payment reminder pay order item out of stock reorder item start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pick item pay order load cargo start route end route',
#  'place order confirm order pick item item out of stock load cargo payment reminder reorder item fuel car start route pay order end route',
#  'place order fuel car confirm order pick item pay order item out of stock load cargo reorder item start route end route',
#  'place order fuel car confirm order pick item payment reminder load cargo start route pay order end route',
#  'place order fuel car confirm order payment reminder item out of stock pick item pay order load cargo reorder item start route pick item end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item load cargo item out of stock start route pay order end route',
#  'fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock payment reminder pay order pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pay order pick item load cargo item out of stock start route end route',
#  'place order confirm order fuel car payment reminder item out of stock payment reminder pay order pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item pay order load cargo reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock pick item reorder item fuel car pay order pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo item out of stock start route end route',
#  'place order fuel car confirm order item out of stock pick item payment reminder payment reminder payment reminder reorder item pay order pick item load cargo start route end route',
#  'place order fuel car confirm order pick item load cargo pay order item out of stock reorder item pick item start route load cargo end route',
#  'place order confirm order item out of stock fuel car reorder item payment reminder pick item load cargo start route payment reminder payment reminder pay order end route',
#  'fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route end route',
#  'fuel car place order confirm order pick item payment reminder pay order load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item reorder item load cargo pick item start route payment reminder end route pay order',
#  'place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pick item load cargo start route payment reminder item out of stock pay order reorder item end route',
#  'place order fuel car confirm order pay order pick item load cargo item out of stock start route reorder item end route',
#  'fuel car place order confirm order pick item pay order load cargo start route item out of stock end route',
#  'place order fuel car confirm order payment reminder pay order pick item load cargo item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pick item item out of stock reorder item payment reminder pay order load cargo pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item pay order load cargo start route reorder item pick item end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pick item load cargo item out of stock reorder item start route end route pay order',
#  'fuel car place order confirm order payment reminder item out of stock pick item pay order reorder item load cargo start route pick item end route',
#  'place order fuel car confirm order payment reminder payment reminder payment reminder item out of stock pick item payment reminder reorder item pick item pay order load cargo start route end route',
#  'fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder payment reminder item out of stock reorder item payment reminder pay order pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder pay order pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item reorder item pay order load cargo pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pick item load cargo start route pay order end route',
#  'place order fuel car confirm order pick item pay order item out of stock load cargo reorder item start route pick item end route',
#  'place order fuel car confirm order pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pick item item out of stock load cargo reorder item pick item load cargo start route payment reminder payment reminder end route payment reminder pay order',
#  'place order fuel car confirm order item out of stock reorder item pick item pay order load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo item out of stock start route reorder item end route',
#  'fuel car place order confirm order item out of stock pay order pick item reorder item load cargo pick item load cargo start route end route',
#  'place order confirm order pay order item out of stock pick item reorder item load cargo pick item load cargo fuel car start route end route',
#  'place order fuel car confirm order payment reminder pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pick item item out of stock pay order reorder item load cargo pick item start route load cargo end route',
#  'fuel car place order confirm order pick item payment reminder payment reminder pay order item out of stock load cargo reorder item start route end route',
#  'place order confirm order fuel car pick item load cargo item out of stock start route payment reminder payment reminder pay order end route',
#  'fuel car place order confirm order pick item payment reminder item out of stock load cargo start route pay order reorder item end route',
#  'place order confirm order payment reminder fuel car pick item payment reminder pay order load cargo item out of stock start route reorder item pick item load cargo end route',
#  'place order confirm order fuel car payment reminder item out of stock payment reminder payment reminder payment reminder pick item reorder item pick item pay order load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder payment reminder payment reminder pick item pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock payment reminder pay order pick item load cargo start route reorder item end route',
#  'fuel car place order confirm order pay order item out of stock pick item load cargo start route reorder item end route',
#  'place order confirm order pay order fuel car pick item load cargo item out of stock reorder item start route pick item end route',
#  'fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item load cargo payment reminder pay order start route end route',
#  'fuel car place order confirm order payment reminder payment reminder payment reminder payment reminder pay order pick item item out of stock load cargo start route reorder item pick item load cargo end route',
#  'fuel car place order confirm order pick item item out of stock reorder item payment reminder pay order load cargo start route pick item end route',
#  'fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route end route',
#  'place order fuel car confirm order pick item load cargo item out of stock pay order start route end route',
#  'fuel car place order confirm order payment reminder pay order pick item item out of stock load cargo reorder item pick item start route load cargo end route',
#  'place order fuel car confirm order payment reminder item out of stock pick item load cargo pay order reorder item pick item start route end route',
#  'place order fuel car confirm order pick item load cargo payment reminder start route pay order item out of stock reorder item end route',
#  'place order confirm order item out of stock fuel car reorder item payment reminder payment reminder pick item load cargo start route end route payment reminder pay order',
#  'place order fuel car confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item payment reminder item out of stock pay order load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item load cargo start route end route',
#  'fuel car place order confirm order pick item load cargo item out of stock reorder item pay order start route pick item end route',
#  'place order confirm order item out of stock fuel car reorder item pick item load cargo start route pay order end route',
#  'fuel car place order confirm order pick item payment reminder item out of stock load cargo payment reminder start route pay order end route',
#  'place order confirm order item out of stock reorder item fuel car payment reminder payment reminder pick item pay order load cargo start route end route',
#  'place order fuel car confirm order item out of stock payment reminder pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order pick item load cargo item out of stock reorder item pick item start route load cargo start route end route',
#  'fuel car place order confirm order pick item pay order load cargo start route item out of stock reorder item pick item end route',
#  'fuel car place order confirm order pick item payment reminder pay order load cargo start route item out of stock end route',
#  'place order confirm order fuel car item out of stock pick item reorder item load cargo pay order start route pick item load cargo end route',
#  'place order fuel car confirm order item out of stock reorder item payment reminder pay order pick item load cargo start route end route',
#  'place order confirm order fuel car item out of stock payment reminder payment reminder payment reminder reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pay order pick item item out of stock load cargo start route end route',
#  'place order fuel car confirm order pick item pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder item out of stock pick item payment reminder load cargo pay order start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item load cargo pick item start route end route',
#  'place order fuel car confirm order pick item item out of stock payment reminder pay order load cargo start route reorder item end route',
#  'place order fuel car confirm order pick item item out of stock reorder item load cargo pay order pick item load cargo start route end route',
#  'place order confirm order pick item load cargo fuel car pay order start route item out of stock end route',
#  'fuel car place order confirm order pick item item out of stock payment reminder load cargo pay order start route reorder item end route',
#  'fuel car place order confirm order pick item pay order item out of stock load cargo reorder item start route pick item load cargo start route end route',
#  'fuel car place order confirm order pick item payment reminder item out of stock pay order load cargo start route end route',
#  'place order confirm order payment reminder payment reminder payment reminder item out of stock payment reminder fuel car pay order pick item load cargo start route reorder item pick item end route',
#  'fuel car place order confirm order pay order pick item item out of stock load cargo start route reorder item pick item end route',
#  'place order confirm order fuel car pay order item out of stock pick item reorder item load cargo start route end route',
#  'place order fuel car confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item payment reminder payment reminder item out of stock pay order load cargo start route end route',
#  'place order fuel car confirm order item out of stock reorder item payment reminder payment reminder pick item load cargo pay order start route end route',
#  'fuel car place order confirm order pick item pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock reorder item fuel car pay order pick item load cargo start route end route',
#  'place order confirm order pay order pick item item out of stock load cargo fuel car start route end route',
#  'fuel car place order confirm order pick item pay order item out of stock load cargo reorder item pick item start route load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pick item item out of stock load cargo payment reminder pay order reorder item pick item start route load cargo start route end route',
#  'place order confirm order item out of stock reorder item pick item load cargo payment reminder payment reminder pay order fuel car start route end route',
#  'place order confirm order payment reminder pick item payment reminder load cargo payment reminder pay order item out of stock reorder item pick item load cargo fuel car start route end route',
#  'place order confirm order item out of stock reorder item pay order pick item load cargo fuel car start route end route',
#  'place order confirm order item out of stock fuel car reorder item pick item payment reminder pay order load cargo start route end route',
#  'fuel car place order confirm order item out of stock reorder item pick item pay order load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order pay order pick item load cargo fuel car start route end route',
#  'place order fuel car confirm order item out of stock pay order pick item load cargo start route end route',
#  'place order confirm order payment reminder item out of stock reorder item pick item payment reminder payment reminder pay order fuel car load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pick item pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock payment reminder pay order pick item load cargo reorder item start route pick item end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item load cargo pick item start route load cargo end route',
#  'place order confirm order payment reminder pay order item out of stock pick item load cargo reorder item pick item load cargo fuel car start route end route',
#  'place order confirm order payment reminder fuel car payment reminder pick item item out of stock load cargo pay order start route reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pay order pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item item out of stock payment reminder pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item load cargo payment reminder pay order start route item out of stock reorder item pick item load cargo end route',
#  'place order fuel car confirm order payment reminder pay order item out of stock pick item load cargo reorder item start route pick item load cargo end route',
#  'place order confirm order pick item pay order fuel car load cargo start route item out of stock reorder item pick item end route',
#  'place order fuel car confirm order pick item pay order item out of stock load cargo reorder item start route pick item end route',
#  'place order fuel car confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item pay order reorder item load cargo pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item reorder item load cargo pick item start route end route',
#  'place order confirm order pay order fuel car item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock pick item pay order reorder item load cargo fuel car pick item start route end route',
#  'fuel car place order confirm order item out of stock pay order pick item reorder item load cargo pick item start route end route',
#  'fuel car place order confirm order pick item payment reminder load cargo pay order item out of stock reorder item start route pick item end route',
#  'place order confirm order fuel car item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder payment reminder payment reminder pay order pick item item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item pay order load cargo start route reorder item end route',
#  'place order fuel car confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order pick item load cargo item out of stock start route reorder item pick item load cargo start route end route',
#  'place order confirm order pay order item out of stock fuel car reorder item pick item load cargo start route end route',
#  'place order confirm order fuel car payment reminder pay order item out of stock pick item load cargo reorder item start route pick item end route',
#  'place order fuel car confirm order pay order pick item load cargo item out of stock reorder item start route end route',
#  'fuel car place order confirm order pick item load cargo start route end route payment reminder pay order',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pay order pick item reorder item pick item load cargo start route end route',
#  'place order confirm order payment reminder fuel car payment reminder item out of stock reorder item pay order pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder item out of stock pay order pick item load cargo start route reorder item pick item load cargo end route',
#  'place order confirm order pick item pay order fuel car load cargo item out of stock reorder item start route pick item end route',
#  'place order confirm order item out of stock reorder item payment reminder payment reminder pay order fuel car pick item load cargo start route end route',
#  'place order fuel car confirm order pick item payment reminder item out of stock reorder item pay order load cargo start route pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item item out of stock load cargo start route payment reminder reorder item payment reminder pay order end route',
#  'fuel car place order confirm order payment reminder item out of stock reorder item payment reminder pay order pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder item out of stock pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock pick item pay order load cargo fuel car start route end route',
#  'place order confirm order item out of stock fuel car pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock reorder item payment reminder pick item load cargo pay order start route end route',
#  'place order confirm order fuel car payment reminder pay order item out of stock pick item load cargo start route reorder item end route',
#  'fuel car place order confirm order pay order pick item load cargo start route end route',
# ...
#  'fuel car place order confirm order pick item load cargo payment reminder item out of stock start route end route pay order',
#  'fuel car place order confirm order pick item item out of stock reorder item pick item load cargo payment reminder payment reminder start route payment reminder end route pay order',
#  'fuel car place order confirm order pick item item out of stock pay order load cargo reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item reorder item pay order pick item load cargo start route end route',
#  'place order fuel car confirm order pay order pick item load cargo item out of stock start route end route',
#  'fuel car place order confirm order pay order pick item item out of stock load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item load cargo pick item start route load cargo end route',
#  'place order confirm order item out of stock fuel car payment reminder payment reminder payment reminder pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock payment reminder pick item payment reminder load cargo payment reminder pay order start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item pay order item out of stock reorder item load cargo pick item start route load cargo start route end route',
#  'place order fuel car confirm order pick item load cargo start route end route payment reminder pay order',
#  'place order fuel car confirm order pick item load cargo payment reminder payment reminder pay order start route item out of stock end route',
#  'place order confirm order payment reminder pick item pay order item out of stock reorder item load cargo pick item load cargo fuel car start route end route',
#  'fuel car place order confirm order pick item pay order load cargo item out of stock start route reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder pick item load cargo pay order start route item out of stock end route',
#  'fuel car place order confirm order pick item load cargo item out of stock payment reminder payment reminder reorder item payment reminder start route pay order end route',
#  'fuel car place order confirm order payment reminder pick item pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order pay order fuel car pick item item out of stock load cargo reorder item start route end route',
#  'fuel car place order confirm order item out of stock reorder item pick item payment reminder pay order load cargo start route end route',
#  'place order fuel car confirm order item out of stock pay order pick item load cargo reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock pay order pick item load cargo fuel car reorder item start route end route',
#  'place order confirm order item out of stock payment reminder payment reminder fuel car reorder item payment reminder pay order pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item load cargo reorder item start route end route',
#  'fuel car place order confirm order pay order pick item load cargo item out of stock reorder item start route end route',
#  'place order confirm order payment reminder fuel car payment reminder pick item payment reminder pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder item out of stock reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pick item item out of stock load cargo reorder item payment reminder start route payment reminder pay order pick item load cargo end route',
#  'place order confirm order pick item fuel car item out of stock pay order reorder item load cargo pick item load cargo start route end route',
#  'place order confirm order pay order fuel car item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pick item pay order item out of stock reorder item load cargo start route end route',
#  'fuel car place order confirm order payment reminder pay order pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock reorder item pick item pay order load cargo start route end route',
#  'fuel car place order confirm order pick item item out of stock load cargo start route pay order reorder item end route',
#  'place order confirm order pay order fuel car item out of stock pick item load cargo start route end route',
#  'fuel car place order confirm order pick item pay order item out of stock reorder item load cargo pick item start route load cargo start route end route',
#  'fuel car place order confirm order pay order pick item item out of stock load cargo start route reorder item end route',
#  'place order fuel car confirm order payment reminder item out of stock pick item payment reminder reorder item payment reminder pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item load cargo reorder item start route end route',
#  'fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pay order pick item item out of stock load cargo reorder item start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item load cargo reorder item pick item start route end route',
#  'fuel car place order confirm order item out of stock reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pick item item out of stock payment reminder pay order reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order pick item item out of stock reorder item load cargo pick item start route load cargo end route',
#  'place order confirm order item out of stock reorder item pick item pay order fuel car load cargo start route end route',
#  'fuel car place order confirm order pick item pay order load cargo item out of stock start route end route',
#  'place order fuel car confirm order item out of stock reorder item payment reminder payment reminder pick item pay order load cargo start route end route',
#  'place order fuel car confirm order payment reminder item out of stock reorder item pay order pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock payment reminder pick item payment reminder reorder item load cargo pay order start route pick item load cargo end route',
#  'fuel car place order confirm order item out of stock payment reminder pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder pay order pick item load cargo item out of stock reorder item start route pick item load cargo end route',
#  'place order confirm order pay order fuel car item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order pick item pay order item out of stock reorder item load cargo start route pick item load cargo end route',
#  'place order fuel car confirm order item out of stock pick item pay order load cargo start route end route',
#  'place order fuel car confirm order pick item pay order load cargo start route end route',
#  'place order confirm order payment reminder fuel car pick item item out of stock reorder item pick item pay order load cargo start route end route',
#  'fuel car place order confirm order payment reminder payment reminder pick item item out of stock pay order load cargo reorder item start route end route',
#  'fuel car place order confirm order payment reminder payment reminder payment reminder pay order pick item item out of stock load cargo start route end route',
#  'fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route end route',
#  'fuel car place order confirm order pick item payment reminder payment reminder item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order confirm order pick item payment reminder fuel car payment reminder pay order item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order item out of stock payment reminder pick item pay order load cargo fuel car reorder item pick item start route load cargo end route',
#  'fuel car place order confirm order item out of stock pick item reorder item pick item pay order load cargo start route end route',
#  'place order confirm order fuel car payment reminder pick item payment reminder pay order item out of stock load cargo start route reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order item out of stock payment reminder payment reminder pick item reorder item payment reminder load cargo pick item payment reminder load cargo payment reminder payment reminder payment reminder start route end route pay order',
#  'fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order confirm order fuel car pick item item out of stock load cargo pay order reorder item pick item start route end route',
#  'fuel car place order confirm order pick item payment reminder payment reminder pay order item out of stock reorder item load cargo pick item start route end route',
#  'fuel car place order confirm order payment reminder pay order pick item item out of stock reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item reorder item load cargo pick item start route load cargo start route end route',
#  'fuel car place order confirm order item out of stock pick item reorder item payment reminder pay order pick item load cargo start route end route',
#  'place order fuel car confirm order payment reminder pick item pay order load cargo item out of stock start route reorder item pick item load cargo end route',
#  'fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pay order pick item load cargo start route end route',
#  'place order fuel car confirm order pay order pick item item out of stock load cargo start route end route',
#  'place order confirm order pick item payment reminder fuel car item out of stock payment reminder pay order load cargo start route reorder item end route',
#  'place order fuel car confirm order item out of stock pick item reorder item pick item pay order load cargo start route end route',
#  'fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock reorder item pick item load cargo start route payment reminder payment reminder end route pay order',
#  'place order confirm order pick item item out of stock payment reminder fuel car load cargo pay order reorder item start route end route',
#  'place order confirm order pay order pick item fuel car load cargo start route end route',
#  'place order fuel car confirm order pay order item out of stock pick item reorder item load cargo start route end route',
#  'place order confirm order pick item load cargo pay order item out of stock fuel car reorder item start route pick item end route',
#  'place order confirm order payment reminder pick item payment reminder load cargo pay order item out of stock fuel car reorder item pick item load cargo start route end route',
#  'place order fuel car confirm order pick item payment reminder pay order load cargo item out of stock start route end route',
#  'place order fuel car confirm order payment reminder pay order item out of stock pick item load cargo reorder item pick item start route load cargo end route',
#  'place order fuel car confirm order item out of stock reorder item payment reminder payment reminder payment reminder pick item pay order load cargo start route end route',
#  'fuel car place order confirm order payment reminder pick item payment reminder pay order item out of stock reorder item load cargo pick item load cargo start route end route',
#  'place order confirm order fuel car item out of stock pay order pick item load cargo reorder item start route end route',
#  'place order fuel car confirm order item out of stock pay order pick item reorder item pick item load cargo start route end route',
#  'place order confirm order pay order pick item fuel car load cargo item out of stock start route reorder item pick item load cargo end route',
#  'fuel car place order confirm order item out of stock reorder item payment reminder payment reminder pay order pick item load cargo start route end route',
#  'fuel car place order confirm order pick item pay order item out of stock load cargo reorder item start route pick item end route',
#  'fuel car place order confirm order pick item item out of stock payment reminder load cargo payment reminder reorder item pay order start route pick item end route',
#  'place order confirm order item out of stock pay order fuel car reorder item pick item load cargo start route end route',
#  'fuel car place order confirm order item out of stock reorder item payment reminder payment reminder pick item pay order load cargo start route end route',
#  'fuel car place order confirm order pay order pick item item out of stock reorder item pick item load cargo start route end route',
#  'place order confirm order pick item load cargo fuel car item out of stock payment reminder payment reminder reorder item pick item pay order start route end route',
#  'fuel car place order confirm order pick item load cargo pay order start route end route',
#  'place order fuel car confirm order pick item pay order load cargo item out of stock start route reorder item end route',
#  'place order confirm order item out of stock payment reminder reorder item pay order pick item fuel car load cargo start route end route',
#  'place order fuel car confirm order pick item payment reminder pay order item out of stock load cargo reorder item start route pick item load cargo end route',
#  'place order fuel car confirm order pay order item out of stock pick item load cargo start route reorder item end route',
#  'fuel car place order confirm order payment reminder pay order pick item load cargo start route item out of stock end route',
#  'fuel car place order confirm order payment reminder pick item payment reminder payment reminder item out of stock payment reminder reorder item pick item load cargo payment reminder start route pay order end route',
#  'place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route',
#  ...]

# %%
def create_lstm_vae(input_dim,
                    batch_size,  # we need it for sampling
                    intermediate_dim,
                    latent_dim):
    """
    Creates an LSTM Variational Autoencoder (VAE).

    # Arguments
        input_dim: int.
        batch_size: int.
        intermediate_dim: int, output shape of LSTM.
        latent_dim: int, latent z-layer shape.
        epsilon_std: float, z-layer sigma.


    # References
        - [Building Autoencoders in Keras](https://blog.keras.io/building-autoencoders-in-keras.html)
        - [Generating sentences from a continuous space](https://arxiv.org/abs/1511.06349)
    """
    x = Input(shape=(None, input_dim,))

    # LSTM encoding
    h = LSTM(units=intermediate_dim)(x)

    # VAE Z layer
    z_mean = Dense(units=latent_dim)(h)
    z_log_sigma = Dense(units=latent_dim)(h)

    def sampling(args):
        z_mean, z_log_sigma = args
        epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0., stddev=1.0)
        return z_mean + z_log_sigma * epsilon

    # note that "output_shape" isn't necessary with the TensorFlow backend
    # so you could write `Lambda(sampling)([z_mean, z_log_sigma])`
    z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_sigma])

    z_reweighting = Dense(units=intermediate_dim, activation="linear")
    z_reweighted = z_reweighting(z)

    # "next-word" data for prediction
    decoder_words_input = Input(shape=(None, input_dim,))

    # decoded LSTM layer
    decoder_h = LSTM(intermediate_dim, return_sequences=True, return_state=True)

    # todo: not sure if this initialization is correct
    h_decoded, _, _ = decoder_h(decoder_words_input, initial_state=[z_reweighted, z_reweighted])
    decoder_dense = TimeDistributed(Dense(input_dim, activation="softmax"))
    decoded_onehot = decoder_dense(h_decoded)

    # end-to-end autoencoder
    vae = Model([x, decoder_words_input], decoded_onehot)

    # encoder, from inputs to latent space
    encoder = Model(x, [z_mean, z_log_sigma])

    # generator, from latent space to reconstructed inputs -- for inference's first step
    decoder_state_input = Input(shape=(latent_dim,))
    _z_rewighted = z_reweighting(decoder_state_input)
    _h_decoded, _decoded_h, _decoded_c = decoder_h(decoder_words_input, initial_state=[_z_rewighted, _z_rewighted])
    _decoded_onehot = decoder_dense(_h_decoded)
    generator = Model([decoder_words_input, decoder_state_input], [_decoded_onehot, _decoded_h, _decoded_c])

    # RNN for inference
    input_h = Input(shape=(intermediate_dim,))
    input_c = Input(shape=(intermediate_dim,))
    __h_decoded, __decoded_h, __decoded_c = decoder_h(decoder_words_input, initial_state=[input_h, input_c])
    __decoded_onehot = decoder_dense(__h_decoded)
    stepper = Model([decoder_words_input, input_h, input_c], [__decoded_onehot, __decoded_h, __decoded_c])

    def vae_loss(x, x_decoded_onehot):
        xent_loss = categorical_crossentropy(x, x_decoded_onehot)
        kl_loss = - 0.5 * K.mean(1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma))
        loss = xent_loss + kl_loss
        return loss

    vae.compile(optimizer="adam", loss=vae_loss)
    vae.summary()

    return vae, encoder, generator, stepper

# %%
def decode_sequence(states_value, decoder_adapter_model, rnn_decoder_model, num_decoder_tokens, token2id, id2token, max_seq_length):
    """
    Decoding adapted from this example:
    https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html

    :param states_value:
    :param decoder_adapter_model: reads text representation, makes the first prediction, yields states after the first RNN's step
    :param rnn_decoder_model: reads previous states and makes one RNN step
    :param num_decoder_tokens:
    :param token2id: dict mapping words to ids
    :param id2token: dict mapping ids to words
    :param max_seq_length: the maximum length of the sequence
    :return:
    """

    # generate empty target sequence of length 1
    target_seq = np.zeros((1, 1, num_decoder_tokens))

    # populate the first token of the target sequence with the start character
    target_seq[0, 0, token2id["\t"]] = 1.0

    # sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1)
    stop_condition = False
    decoded_sentence = ""

    first_time = True
    h, c = None, None

    while not stop_condition:

        if first_time:
            # feeding in states sampled with the mean and std provided by encoder
            # and getting current LSTM states to feed in to the decoder at the next step
            output_tokens, h, c = decoder_adapter_model.predict([target_seq, states_value])
            first_time = False
        else:
            # reading output token
            output_tokens, h, c = rnn_decoder_model.predict([target_seq, h, c])

        # sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = id2token[sampled_token_index]
        decoded_sentence += sampled_token + " "

        # exit condition: either hit max length
        # or find stop character.
        if sampled_token == "<end>" or len(decoded_sentence) > max_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

    return decoded_sentence

# %%
def get_text_data(data_path, num_samples=1000):

    # vectorize the data
    input_texts = []
    input_characters = set(["\t"])

    with open(data_path, "r", encoding="utf-8") as f:
        lines = f.read().lower().split("\n")

    for line in lines[: min(num_samples, len(lines) - 1)]:

        #input_text, _ = line.split("\t")
        input_text = word_tokenize(line)
        input_text.append("<end>")

        input_texts.append(input_text)

        for char in input_text:
            if char not in input_characters:
                input_characters.add(char)

    input_characters = sorted(list(input_characters))
    num_encoder_tokens = len(input_characters)
    max_encoder_seq_length = max([len(txt) for txt in input_texts]) + 1

    print("Number of samples:", len(input_texts))
    print("Number of unique input tokens:", num_encoder_tokens)
    print("Max sequence length for inputs:", max_encoder_seq_length)

    input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
    reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())

    encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32")
    decoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32")

    for i, input_text in enumerate(input_texts):
        decoder_input_data[i, 0, input_token_index["\t"]] = 1.0

        for t, char in enumerate(input_text):
            encoder_input_data[i, t, input_token_index[char]] = 1.0
            decoder_input_data[i, t + 1, input_token_index[char]] = 1.0

    return max_encoder_seq_length, num_encoder_tokens, input_characters, input_token_index, reverse_input_char_index, \
           encoder_input_data, decoder_input_data

# %%
#     from argparse import ArgumentParser

#     p = ArgumentParser()
#     p.add_argument("--input", default="data/fra.txt", type=str)
#     p.add_argument("--num_samples", default=3000, type=int)
#     p.add_argument("--batch_size", default=1, type=int)
#     p.add_argument("--epochs", default=40, type=int)
#     p.add_argument("--latent_dim", default=191, type=int)
#     p.add_argument("--inter_dim", default=353, type=int)
#     p.add_argument("--samples", default=5, type=int)
#     args = p.parse_args()

timesteps_max, enc_tokens, characters, char2id, id2char, x, x_decoder = get_text_data(num_samples=10000,
                                                                                      data_path='../src/data/sampled_data_order.txt')

print(x.shape, "Creating model...")
# Out:
# Number of samples: 10000
# Number of unique input tokens: 21
# Max sequence length for inputs: 52
# (10000, 52, 21) Creating model...

# %%
input_dim, timesteps = x.shape[-1], x.shape[-2]
batch_size, latent_dim = 1, 191
intermediate_dim, epochs = 353, 10

vae, enc, gen, stepper = create_lstm_vae(input_dim,
                                         batch_size=batch_size,
                                         intermediate_dim=intermediate_dim,
                                         latent_dim=latent_dim,
                                        )
print("Training model...")

vae.fit([x, x_decoder], x, epochs=epochs, verbose=1)
# Out:
# Model: "model_20"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_26 (InputLayer)          [(None, None, 21)]   0           []
#
#  lstm_10 (LSTM)                 (None, 353)          529500      ['input_26[0][0]']
#
#  dense_20 (Dense)               (None, 191)          67614       ['lstm_10[0][0]']
#
#  dense_21 (Dense)               (None, 191)          67614       ['lstm_10[0][0]']
#
#  lambda_5 (Lambda)              (None, 191)          0           ['dense_20[0][0]',
#                                                                   'dense_21[0][0]']
#
#  input_27 (InputLayer)          [(None, None, 21)]   0           []
#
#  dense_22 (Dense)               (None, 353)          67776       ['lambda_5[0][0]']
#
#  lstm_11 (LSTM)                 [(None, None, 353),  529500      ['input_27[0][0]',
#                                  (None, 353),                     'dense_22[0][0]',
#                                  (None, 353)]                     'dense_22[0][0]']
#
#  time_distributed_5 (TimeDistri  (None, None, 21)    7434        ['lstm_11[0][0]']
#  buted)
#
# ==================================================================================================
# Total params: 1,269,438
# Trainable params: 1,269,438
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Training model...
# Train on 10000 samples
# Epoch 1/10
# 10000/10000 [==============================] - 210s 21ms/sample - loss: 0.5384
# Epoch 2/10
# 10000/10000 [==============================] - 216s 22ms/sample - loss: 0.1780
# Epoch 3/10
# 10000/10000 [==============================] - 215s 22ms/sample - loss: 0.1558
# Epoch 4/10
# 10000/10000 [==============================] - 198s 20ms/sample - loss: 0.1386
# Epoch 5/10
# 10000/10000 [==============================] - 191s 19ms/sample - loss: 0.1260
# Epoch 6/10
# 10000/10000 [==============================] - 178s 18ms/sample - loss: 0.1162
# Epoch 7/10
# 10000/10000 [==============================] - 170s 17ms/sample - loss: 0.1126
# Epoch 8/10
# 10000/10000 [==============================] - 178s 18ms/sample - loss: 0.1088
# Epoch 9/10
# 10000/10000 [==============================] - 171s 17ms/sample - loss: 0.1025
# Epoch 10/10
# 10000/10000 [==============================] - 168s 17ms/sample - loss: 0.1017

# %%
print("Fitted, predicting...")

def decode(s):
    return decode_sequence(s, gen, stepper, input_dim, char2id, id2char, timesteps_max)

log = []

for _ in tqdm(range(10000), desc="Sample Traces"):

    id_from = np.random.randint(0, x.shape[0] - 1)
    id_to = np.random.randint(0, x.shape[0] - 1)

    m_from, std_from = enc.predict([[x[id_from]]])
    m_to, std_to = enc.predict([[x[id_to]]])

    seq_from = np.random.normal(size=(latent_dim,))
    seq_from = m_from + std_from * seq_from

    seq_to = np.random.normal(size=(latent_dim,))
    seq_to = m_to + std_to * seq_to

    #print("==  \t", " ".join([id2char[j] for j in np.argmax(x[id_from], axis=1)]), "==")

    #for v in np.linspace(0, 1, 7):
        #print("%.2f\t" % (1 - v), decode(v * seq_to + (1 - v) * seq_from))

    #print("==  \t", " ".join([id2char[j] for j in np.argmax(x[id_to], axis=1)]), "==")
    parts = " ".join([id2char[j] for j in np.argmax(x[id_to], axis=1)]).split(' <end>')
    log.append([parts[0]])
# Out:
# Fitted, predicting...
# Sample Traces: 100%|██████████| 10000/10000 [04:52<00:00, 34.23it/s]

# %%
log
# Out:
# [['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pay order pick item load cargo reorder item fuel car start route pick item load cargo end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo pick item start route end route'],
#  ['place order confirm order pick item pay order fuel car load cargo item out of stock start route reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder payment reminder item out of stock reorder item pick item pay order load cargo fuel car start route end route'],
#  ['place order fuel car confirm order pick item load cargo pay order item out of stock start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock payment reminder payment reminder payment reminder pick item reorder item load cargo payment reminder pay order start route pick item end route'],
#  ['place order confirm order pick item load cargo pay order fuel car item out of stock start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item load cargo start route end route'],
#  ['place order confirm order fuel car pick item payment reminder load cargo item out of stock payment reminder pay order start route end route'],
#  ['place order confirm order pay order item out of stock pick item reorder item load cargo fuel car pick item load cargo start route end route'],
#  ['place order confirm order payment reminder item out of stock pick item load cargo payment reminder fuel car payment reminder reorder item pay order start route pick item load cargo end route'],
#  ['place order confirm order fuel car payment reminder item out of stock payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order pick item load cargo pay order start route end route'],
#  ['place order confirm order item out of stock fuel car pick item load cargo start route pay order reorder item end route'],
#  ['fuel car place order confirm order pick item item out of stock load cargo reorder item pick item load cargo start route payment reminder payment reminder end route payment reminder pay order'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['place order confirm order payment reminder item out of stock fuel car reorder item payment reminder payment reminder payment reminder pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item pay order load cargo start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock payment reminder pay order load cargo reorder item pick item start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder pick item payment reminder payment reminder item out of stock load cargo payment reminder payment reminder reorder item pay order pick item start route load cargo end route'],
#  ['fuel car place order confirm order pick item load cargo item out of stock start route pay order end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pick item fuel car reorder item load cargo pick item start route pay order load cargo end route'],
#  ['place order fuel car confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder payment reminder payment reminder item out of stock payment reminder pick item payment reminder load cargo pay order reorder item pick item fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder fuel car pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item item out of stock fuel car load cargo start route pay order reorder item end route'],
#  ['fuel car place order confirm order pick item pay order load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order item out of stock load cargo reorder item pick item start route load cargo end route'],
#  ['fuel car place order confirm order item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item payment reminder pay order pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock reorder item fuel car pick item load cargo start route end route'],
#  ['place order confirm order payment reminder item out of stock reorder item pick item pay order load cargo fuel car start route end route'],
#  ['place order confirm order pick item payment reminder payment reminder payment reminder item out of stock fuel car payment reminder load cargo reorder item start route pick item pay order end route'],
#  ['place order confirm order pay order item out of stock pick item fuel car load cargo start route reorder item end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock payment reminder pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder item out of stock pick item load cargo payment reminder start route reorder item pay order end route'],
#  ['fuel car place order confirm order pick item item out of stock load cargo reorder item pick item load cargo start route payment reminder payment reminder end route payment reminder pay order'],
#  ['place order confirm order pick item payment reminder payment reminder load cargo fuel car start route item out of stock end route payment reminder pay order'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock load cargo pay order reorder item pick item start route load cargo end route'],
#  ['place order confirm order pick item item out of stock load cargo payment reminder reorder item pick item pay order fuel car load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock payment reminder pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order pick item pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock fuel car payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder pay order load cargo item out of stock start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder pay order load cargo item out of stock reorder item start route end route'],
#  ['place order fuel car confirm order pick item payment reminder load cargo start route pay order item out of stock reorder item end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item payment reminder load cargo payment reminder pay order start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route reorder item end route'],
#  ['place order confirm order pick item pay order item out of stock fuel car reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock pick item load cargo reorder item fuel car start route end route'],
#  ['place order confirm order item out of stock payment reminder pick item reorder item fuel car load cargo pay order pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item item out of stock load cargo start route reorder item pick item end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo item out of stock reorder item start route end route'],
#  ['place order confirm order payment reminder pick item load cargo fuel car payment reminder payment reminder item out of stock start route payment reminder end route payment reminder pay order'],
#  ['place order fuel car confirm order item out of stock pick item reorder item pay order load cargo start route pick item load cargo end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder payment reminder pick item pay order load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item pick item start route end route'],
#  ['place order confirm order pay order item out of stock pick item load cargo reorder item fuel car pick item start route end route'],
#  ['place order confirm order pick item load cargo fuel car item out of stock payment reminder payment reminder reorder item pick item pay order start route end route'],
#  ['place order confirm order item out of stock pick item load cargo pay order fuel car reorder item start route pick item end route'],
#  ['fuel car place order confirm order pick item load cargo payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock fuel car reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder pay order load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item pick item start route load cargo end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock reorder item pick item start route end route'],
#  ['place order confirm order pay order pick item item out of stock reorder item load cargo pick item load cargo fuel car start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo item out of stock reorder item start route pick item load cargo end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item load cargo start route pay order end route'],
#  ['fuel car place order confirm order payment reminder payment reminder pick item item out of stock load cargo reorder item start route payment reminder payment reminder end route payment reminder pay order'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order confirm order payment reminder fuel car payment reminder item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order confirm order fuel car payment reminder item out of stock pick item pay order reorder item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['place order confirm order payment reminder payment reminder payment reminder payment reminder pay order item out of stock pick item fuel car reorder item load cargo start route pick item end route'],
#  ['place order fuel car confirm order pick item load cargo pay order item out of stock reorder item pick item start route load cargo end route'],
#  ['place order confirm order pick item load cargo payment reminder item out of stock payment reminder pay order fuel car start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item payment reminder payment reminder payment reminder payment reminder payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder pay order load cargo start route item out of stock end route'],
#  ['place order confirm order item out of stock reorder item pay order pick item load cargo fuel car start route end route'],
#  ['fuel car place order confirm order pick item load cargo payment reminder pay order start route item out of stock end route'],
#  ['place order confirm order payment reminder payment reminder payment reminder fuel car payment reminder payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item load cargo payment reminder payment reminder item out of stock reorder item pay order pick item start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder payment reminder pick item pay order load cargo reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder item out of stock pick item payment reminder pay order reorder item pick item fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder item out of stock reorder item pay order load cargo pick item start route load cargo end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pick item payment reminder payment reminder pay order load cargo reorder item fuel car pick item start route end route'],
#  ['place order confirm order pay order item out of stock fuel car reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder item out of stock payment reminder pick item reorder item pay order load cargo pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock reorder item pick item fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder load cargo start route pay order end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order pick item payment reminder load cargo item out of stock payment reminder payment reminder pay order reorder item start route pick item end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item load cargo pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock pick item reorder item load cargo pay order start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order pick item load cargo start route payment reminder pay order end route'],
#  ['fuel car place order confirm order pick item item out of stock load cargo pay order reorder item start route pick item load cargo start route end route'],
#  ['place order confirm order payment reminder fuel car pay order item out of stock pick item load cargo reorder item start route pick item end route'],
#  ['place order confirm order pay order pick item load cargo item out of stock reorder item fuel car pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo start route item out of stock reorder item end route'],
#  ['place order confirm order pick item item out of stock payment reminder payment reminder reorder item pick item fuel car pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item start route pick item load cargo end route'],
#  ['place order confirm order item out of stock payment reminder pick item pay order load cargo reorder item pick item fuel car start route end route'],
#  ['fuel car place order confirm order payment reminder pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder item out of stock payment reminder reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo start route reorder item pick item end route'],
#  ['place order fuel car confirm order pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pick item pay order load cargo item out of stock reorder item start route end route'],
#  ['place order fuel car confirm order item out of stock pick item payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['place order confirm order fuel car pay order pick item item out of stock load cargo start route reorder item pick item end route'],
#  ['place order fuel car confirm order pay order item out of stock pick item load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pick item load cargo item out of stock start route payment reminder end route payment reminder pay order'],
#  ['place order confirm order pick item load cargo item out of stock reorder item pay order pick item load cargo fuel car start route end route'],
#  ['place order confirm order fuel car pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder pay order item out of stock reorder item load cargo pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock reorder item fuel car pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['place order confirm order pay order pick item item out of stock reorder item fuel car load cargo start route pick item end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car pick item pay order load cargo item out of stock start route reorder item end route'],
#  ['place order fuel car confirm order pay order item out of stock pick item load cargo start route reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock payment reminder payment reminder load cargo pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car item out of stock payment reminder pick item reorder item payment reminder payment reminder payment reminder pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder pay order load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order payment reminder item out of stock reorder item pick item payment reminder payment reminder payment reminder pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock reorder item pick item start route end route'],
#  ['place order confirm order pick item load cargo pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock pick item reorder item pick item load cargo payment reminder payment reminder pay order start route end route'],
#  ['place order confirm order payment reminder fuel car payment reminder pay order pick item item out of stock reorder item load cargo pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo start route item out of stock reorder item end route'],
#  ['place order fuel car confirm order pick item payment reminder load cargo payment reminder item out of stock pay order start route end route'],
#  ['place order fuel car confirm order pick item payment reminder load cargo payment reminder pay order item out of stock start route reorder item end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock reorder item pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder load cargo item out of stock pay order start route reorder item end route'],
#  ['place order confirm order pay order fuel car item out of stock pick item load cargo start route end route'],
#  ['place order confirm order fuel car payment reminder item out of stock reorder item pick item load cargo start route end route pay order'],
#  ['place order fuel car confirm order item out of stock payment reminder pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pay order reorder item fuel car pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item reorder item pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car pick item load cargo start route end route payment reminder pay order'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item payment reminder load cargo payment reminder payment reminder start route pay order end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order pick item load cargo start route pay order item out of stock reorder item end route'],
#  ['place order confirm order fuel car pay order pick item item out of stock reorder item load cargo start route pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item pay order fuel car load cargo item out of stock start route end route'],
#  ['place order confirm order item out of stock payment reminder reorder item pay order pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item payment reminder payment reminder pay order reorder item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pick item pay order load cargo start route item out of stock end route'],
#  ['place order fuel car confirm order item out of stock reorder item payment reminder pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder load cargo payment reminder payment reminder start route end route payment reminder payment reminder payment reminder pay order'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route pick item load cargo end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route pick item load cargo end route'],
#  ['place order confirm order fuel car item out of stock pick item reorder item load cargo start route end route payment reminder payment reminder payment reminder pay order'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order load cargo reorder item start route end route'],
#  ['place order fuel car confirm order pick item load cargo payment reminder payment reminder item out of stock payment reminder start route pay order reorder item end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item load cargo start route end route payment reminder pay order'],
#  ['place order confirm order item out of stock fuel car pick item load cargo reorder item payment reminder payment reminder payment reminder payment reminder payment reminder pay order start route pick item end route'],
#  ['fuel car place order confirm order item out of stock payment reminder reorder item payment reminder pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order confirm order pick item payment reminder fuel car payment reminder payment reminder payment reminder payment reminder pay order load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order pick item payment reminder load cargo payment reminder payment reminder payment reminder payment reminder pay order start route item out of stock reorder item pick item end route'],
#  ['place order fuel car confirm order item out of stock pick item payment reminder payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item pay order fuel car item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pay order pick item load cargo reorder item start route end route'],
#  ['place order confirm order pay order pick item item out of stock reorder item pick item load cargo fuel car start route end route'],
#  ['place order confirm order payment reminder pick item load cargo pay order fuel car item out of stock start route end route'],
#  ['place order confirm order payment reminder fuel car pick item load cargo pay order item out of stock reorder item pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock reorder item payment reminder pick item load cargo start route end route payment reminder payment reminder pay order'],
#  ['place order fuel car confirm order payment reminder pay order pick item load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car payment reminder item out of stock pick item load cargo pay order reorder item start route pick item end route'],
#  ['place order fuel car confirm order pick item payment reminder item out of stock pay order load cargo reorder item start route pick item load cargo end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock pay order load cargo reorder item pick item start route end route'],
#  ['place order fuel car confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item payment reminder load cargo reorder item pay order pick item start route load cargo start route end route'],
#  ['place order confirm order fuel car pay order pick item item out of stock reorder item load cargo pick item start route load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo item out of stock reorder item start route end route'],
#  ['place order confirm order fuel car pick item item out of stock pay order load cargo reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pick item payment reminder pay order reorder item load cargo pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo item out of stock reorder item start route end route'],
#  ['place order confirm order pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock payment reminder reorder item load cargo payment reminder pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pay order load cargo pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item payment reminder pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder pick item pay order load cargo start route reorder item end route'],
#  ['place order fuel car confirm order item out of stock pick item pay order load cargo reorder item pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock reorder item pick item end route'],
#  ['fuel car place order confirm order payment reminder pick item load cargo item out of stock pay order reorder item start route pick item end route'],
#  ['place order confirm order pay order item out of stock reorder item pick item fuel car load cargo start route end route'],
#  ['place order confirm order fuel car pick item payment reminder item out of stock pay order load cargo reorder item start route pick item end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock load cargo start route pay order end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pick item pay order reorder item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder pay order pick item load cargo reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder pay order item out of stock pick item load cargo reorder item pick item load cargo fuel car start route end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['place order confirm order item out of stock fuel car payment reminder payment reminder payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder item out of stock pay order pick item reorder item fuel car load cargo pick item start route load cargo end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder item out of stock reorder item load cargo pick item load cargo payment reminder pay order start route end route'],
#  ['place order fuel car confirm order payment reminder pick item item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder item out of stock payment reminder reorder item load cargo pay order pick item start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pick item reorder item load cargo pick item start route pay order load cargo end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder pick item load cargo item out of stock payment reminder payment reminder reorder item pick item pay order load cargo fuel car start route end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order load cargo start route reorder item pick item end route'],
#  ['fuel car place order confirm order pick item item out of stock payment reminder payment reminder payment reminder payment reminder load cargo payment reminder payment reminder payment reminder reorder item pick item load cargo payment reminder start route end route payment reminder pay order'],
#  ['place order fuel car confirm order pick item item out of stock load cargo pay order start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car payment reminder pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder load cargo item out of stock reorder item pick item pay order start route load cargo start route end route'],
#  ['place order confirm order item out of stock pick item load cargo pay order reorder item fuel car start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock pay order pick item reorder item load cargo start route pick item end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock load cargo start route pay order reorder item end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item payment reminder payment reminder payment reminder pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['place order confirm order pay order pick item item out of stock load cargo fuel car start route reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item fuel car load cargo payment reminder start route pay order item out of stock end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock pay order reorder item load cargo start route pick item end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item pay order item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo start route item out of stock end route'],
#  ['place order fuel car confirm order pick item item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock load cargo reorder item pick item payment reminder pay order load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pick item payment reminder reorder item pay order load cargo start route pick item end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo item out of stock reorder item start route pick item end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock payment reminder pay order load cargo reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder pay order load cargo item out of stock start route end route'],
#  ['place order confirm order fuel car item out of stock reorder item payment reminder pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pick item reorder item pay order fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder pay order item out of stock load cargo reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item load cargo payment reminder start route pay order item out of stock reorder item end route'],
#  ['place order confirm order pay order pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pay order load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock pay order pick item load cargo start route reorder item pick item end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pay order pick item load cargo start route reorder item end route'],
#  ['place order confirm order pick item item out of stock fuel car pay order reorder item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item item out of stock fuel car pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route end route'],
#  ['place order fuel car confirm order pay order item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item load cargo payment reminder start route payment reminder pay order end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item item out of stock reorder item load cargo start route pick item load cargo end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pay order pick item reorder item pick item fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock pay order pick item reorder item load cargo pick item load cargo start route end route'],
#  ['place order confirm order item out of stock fuel car reorder item pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order payment reminder payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['place order confirm order item out of stock fuel car payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item payment reminder payment reminder payment reminder pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock start route reorder item pick item end route'],
# ...
#  ['fuel car place order confirm order pick item payment reminder payment reminder load cargo pay order start route item out of stock end route'],
#  ['place order confirm order pay order pick item item out of stock fuel car reorder item load cargo pick item start route end route'],
#  ['place order confirm order payment reminder payment reminder item out of stock payment reminder reorder item pick item load cargo payment reminder pay order fuel car start route end route'],
#  ['place order confirm order item out of stock pick item pay order fuel car load cargo start route reorder item pick item end route'],
#  ['place order fuel car confirm order pick item load cargo payment reminder payment reminder item out of stock reorder item pay order start route end route'],
#  ['place order confirm order fuel car item out of stock pick item load cargo reorder item pick item payment reminder payment reminder start route pay order end route'],
#  ['fuel car place order confirm order pick item payment reminder load cargo pay order start route item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pay order pick item item out of stock reorder item load cargo pick item start route load cargo end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item load cargo item out of stock payment reminder pay order reorder item pick item start route load cargo start route end route'],
#  ['place order confirm order pick item pay order item out of stock reorder item load cargo pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['place order fuel car confirm order payment reminder pay order pick item load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock reorder item end route'],
#  ['fuel car place order confirm order payment reminder payment reminder pick item load cargo payment reminder start route pay order item out of stock end route'],
#  ['place order fuel car confirm order item out of stock payment reminder reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder pay order load cargo start route item out of stock reorder item pick item end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route pick item end route'],
#  ['fuel car place order confirm order item out of stock pick item payment reminder payment reminder reorder item payment reminder pay order load cargo pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item payment reminder fuel car payment reminder payment reminder pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['place order confirm order pick item load cargo pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item load cargo pick item start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder load cargo payment reminder payment reminder start route payment reminder item out of stock payment reminder pay order reorder item pick item load cargo end route'],
#  ['place order confirm order item out of stock reorder item payment reminder pay order pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order reorder item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item load cargo start route reorder item pay order end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item pick item start route end route'],
#  ['place order confirm order pick item payment reminder fuel car pay order item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route end route'],
#  ['place order confirm order pick item item out of stock load cargo fuel car pay order start route reorder item end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item load cargo pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder payment reminder item out of stock pick item load cargo pay order reorder item start route end route'],
#  ['place order confirm order pick item pay order fuel car item out of stock load cargo start route reorder item pick item end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder reorder item payment reminder pick item payment reminder payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route pick item end route'],
#  ['fuel car place order confirm order item out of stock payment reminder reorder item pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo start route item out of stock reorder item end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock reorder item pay order load cargo pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item pick item start route end route'],
#  ['fuel car place order confirm order pick item item out of stock payment reminder pay order reorder item load cargo start route pick item load cargo start route end route'],
#  ['place order confirm order pick item pay order item out of stock load cargo reorder item fuel car pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pick item reorder item pay order pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock reorder item load cargo pick item start route end route payment reminder payment reminder pay order'],
#  ['place order confirm order pick item pay order item out of stock load cargo fuel car start route end route'],
#  ['place order confirm order pay order fuel car item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo start route item out of stock reorder item end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder reorder item pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock reorder item pay order load cargo start route pick item end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['place order confirm order payment reminder payment reminder pay order fuel car item out of stock pick item load cargo start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder payment reminder fuel car pick item item out of stock load cargo pay order start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock reorder item pick item start route end route'],
#  ['place order fuel car confirm order item out of stock payment reminder pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route reorder item end route'],
#  ['place order fuel car confirm order payment reminder pay order item out of stock pick item reorder item load cargo pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item reorder item load cargo pay order start route pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder pay order item out of stock reorder item load cargo start route pick item load cargo end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock pick item load cargo start route reorder item end route'],
#  ['place order confirm order pay order item out of stock reorder item pick item load cargo fuel car start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route pick item end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order reorder item load cargo start route pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo start route end route'],
#  ['place order confirm order pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder item out of stock reorder item load cargo start route pay order pick item end route'],
#  ['fuel car place order confirm order item out of stock pick item reorder item load cargo pick item load cargo payment reminder start route pay order end route'],
#  ['place order fuel car confirm order payment reminder pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pick item payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order pick item load cargo start route item out of stock payment reminder pay order reorder item pick item end route'],
#  ['place order confirm order pay order fuel car item out of stock pick item reorder item load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock pay order reorder item load cargo pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock fuel car pick item reorder item load cargo pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder load cargo start route item out of stock end route pay order'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo start route reorder item pick item end route'],
#  ['place order fuel car confirm order pick item pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order pick item item out of stock load cargo fuel car start route end route'],
#  ['place order fuel car confirm order pick item payment reminder pay order item out of stock reorder item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock fuel car pick item load cargo reorder item start route end route'],
#  ['place order confirm order fuel car pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ...]

# %%
data_path_gen = '../src/data/gen_data_order.txt'

# %%
# with open(data_path_gen, "w", encoding="utf-8") as file:
#     for sentence in log:
#         line = " ".join(sentence) + "\n"
#         file.write(line)

# %%
# Open the file in read mode
file = open(data_path_gen, "r")

# Read the file line by line and split into words
lines = file.readlines()
file.close()

# Process each line and store words in a list of lists
gen_log = []
for line in lines:
    words = line.lower().strip().split()
    line = " ".join(words)
    gen_log.append([line])

# %%
gen_log
# Out:
# [['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pay order pick item load cargo reorder item fuel car start route pick item load cargo end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo pick item start route end route'],
#  ['place order confirm order pick item pay order fuel car load cargo item out of stock start route reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder payment reminder item out of stock reorder item pick item pay order load cargo fuel car start route end route'],
#  ['place order fuel car confirm order pick item load cargo pay order item out of stock start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock payment reminder payment reminder payment reminder pick item reorder item load cargo payment reminder pay order start route pick item end route'],
#  ['place order confirm order pick item load cargo pay order fuel car item out of stock start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item load cargo start route end route'],
#  ['place order confirm order fuel car pick item payment reminder load cargo item out of stock payment reminder pay order start route end route'],
#  ['place order confirm order pay order item out of stock pick item reorder item load cargo fuel car pick item load cargo start route end route'],
#  ['place order confirm order payment reminder item out of stock pick item load cargo payment reminder fuel car payment reminder reorder item pay order start route pick item load cargo end route'],
#  ['place order confirm order fuel car payment reminder item out of stock payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order pick item load cargo pay order start route end route'],
#  ['place order confirm order item out of stock fuel car pick item load cargo start route pay order reorder item end route'],
#  ['fuel car place order confirm order pick item item out of stock load cargo reorder item pick item load cargo start route payment reminder payment reminder end route payment reminder pay order'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['place order confirm order payment reminder item out of stock fuel car reorder item payment reminder payment reminder payment reminder pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item pay order load cargo start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock payment reminder pay order load cargo reorder item pick item start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder pick item payment reminder payment reminder item out of stock load cargo payment reminder payment reminder reorder item pay order pick item start route load cargo end route'],
#  ['fuel car place order confirm order pick item load cargo item out of stock start route pay order end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pick item fuel car reorder item load cargo pick item start route pay order load cargo end route'],
#  ['place order fuel car confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder payment reminder payment reminder item out of stock payment reminder pick item payment reminder load cargo pay order reorder item pick item fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder fuel car pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item item out of stock fuel car load cargo start route pay order reorder item end route'],
#  ['fuel car place order confirm order pick item pay order load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order item out of stock load cargo reorder item pick item start route load cargo end route'],
#  ['fuel car place order confirm order item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item payment reminder pay order pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock reorder item fuel car pick item load cargo start route end route'],
#  ['place order confirm order payment reminder item out of stock reorder item pick item pay order load cargo fuel car start route end route'],
#  ['place order confirm order pick item payment reminder payment reminder payment reminder item out of stock fuel car payment reminder load cargo reorder item start route pick item pay order end route'],
#  ['place order confirm order pay order item out of stock pick item fuel car load cargo start route reorder item end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock payment reminder pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder item out of stock pick item load cargo payment reminder start route reorder item pay order end route'],
#  ['fuel car place order confirm order pick item item out of stock load cargo reorder item pick item load cargo start route payment reminder payment reminder end route payment reminder pay order'],
#  ['place order confirm order pick item payment reminder payment reminder load cargo fuel car start route item out of stock end route payment reminder pay order'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock load cargo pay order reorder item pick item start route load cargo end route'],
#  ['place order confirm order pick item item out of stock load cargo payment reminder reorder item pick item pay order fuel car load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock payment reminder pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order pick item pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock fuel car payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder pay order load cargo item out of stock start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder pay order load cargo item out of stock reorder item start route end route'],
#  ['place order fuel car confirm order pick item payment reminder load cargo start route pay order item out of stock reorder item end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item payment reminder load cargo payment reminder pay order start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route reorder item end route'],
#  ['place order confirm order pick item pay order item out of stock fuel car reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock pick item load cargo reorder item fuel car start route end route'],
#  ['place order confirm order item out of stock payment reminder pick item reorder item fuel car load cargo pay order pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item item out of stock load cargo start route reorder item pick item end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo item out of stock reorder item start route end route'],
#  ['place order confirm order payment reminder pick item load cargo fuel car payment reminder payment reminder item out of stock start route payment reminder end route payment reminder pay order'],
#  ['place order fuel car confirm order item out of stock pick item reorder item pay order load cargo start route pick item load cargo end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder payment reminder pick item pay order load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item pick item start route end route'],
#  ['place order confirm order pay order item out of stock pick item load cargo reorder item fuel car pick item start route end route'],
#  ['place order confirm order pick item load cargo fuel car item out of stock payment reminder payment reminder reorder item pick item pay order start route end route'],
#  ['place order confirm order item out of stock pick item load cargo pay order fuel car reorder item start route pick item end route'],
#  ['fuel car place order confirm order pick item load cargo payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock fuel car reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder pay order load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item pick item start route load cargo end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock reorder item pick item start route end route'],
#  ['place order confirm order pay order pick item item out of stock reorder item load cargo pick item load cargo fuel car start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo item out of stock reorder item start route pick item load cargo end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item load cargo start route pay order end route'],
#  ['fuel car place order confirm order payment reminder payment reminder pick item item out of stock load cargo reorder item start route payment reminder payment reminder end route payment reminder pay order'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order confirm order payment reminder fuel car payment reminder item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order confirm order fuel car payment reminder item out of stock pick item pay order reorder item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['place order confirm order payment reminder payment reminder payment reminder payment reminder pay order item out of stock pick item fuel car reorder item load cargo start route pick item end route'],
#  ['place order fuel car confirm order pick item load cargo pay order item out of stock reorder item pick item start route load cargo end route'],
#  ['place order confirm order pick item load cargo payment reminder item out of stock payment reminder pay order fuel car start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item payment reminder payment reminder payment reminder payment reminder payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder pay order load cargo start route item out of stock end route'],
#  ['place order confirm order item out of stock reorder item pay order pick item load cargo fuel car start route end route'],
#  ['fuel car place order confirm order pick item load cargo payment reminder pay order start route item out of stock end route'],
#  ['place order confirm order payment reminder payment reminder payment reminder fuel car payment reminder payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item load cargo payment reminder payment reminder item out of stock reorder item pay order pick item start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder payment reminder pick item pay order load cargo reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder item out of stock pick item payment reminder pay order reorder item pick item fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder item out of stock reorder item pay order load cargo pick item start route load cargo end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pick item payment reminder payment reminder pay order load cargo reorder item fuel car pick item start route end route'],
#  ['place order confirm order pay order item out of stock fuel car reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder payment reminder item out of stock payment reminder pick item reorder item pay order load cargo pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock reorder item pick item fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder load cargo start route pay order end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order pick item payment reminder load cargo item out of stock payment reminder payment reminder pay order reorder item start route pick item end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item load cargo pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock pick item reorder item load cargo pay order start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order pick item load cargo start route payment reminder pay order end route'],
#  ['fuel car place order confirm order pick item item out of stock load cargo pay order reorder item start route pick item load cargo start route end route'],
#  ['place order confirm order payment reminder fuel car pay order item out of stock pick item load cargo reorder item start route pick item end route'],
#  ['place order confirm order pay order pick item load cargo item out of stock reorder item fuel car pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo start route item out of stock reorder item end route'],
#  ['place order confirm order pick item item out of stock payment reminder payment reminder reorder item pick item fuel car pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item start route pick item load cargo end route'],
#  ['place order confirm order item out of stock payment reminder pick item pay order load cargo reorder item pick item fuel car start route end route'],
#  ['fuel car place order confirm order payment reminder pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder item out of stock payment reminder reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo start route reorder item pick item end route'],
#  ['place order fuel car confirm order pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pick item pay order load cargo item out of stock reorder item start route end route'],
#  ['place order fuel car confirm order item out of stock pick item payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['place order confirm order fuel car pay order pick item item out of stock load cargo start route reorder item pick item end route'],
#  ['place order fuel car confirm order pay order item out of stock pick item load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pick item load cargo item out of stock start route payment reminder end route payment reminder pay order'],
#  ['place order confirm order pick item load cargo item out of stock reorder item pay order pick item load cargo fuel car start route end route'],
#  ['place order confirm order fuel car pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder pay order item out of stock reorder item load cargo pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock reorder item fuel car pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['place order confirm order pay order pick item item out of stock reorder item fuel car load cargo start route pick item end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car pick item pay order load cargo item out of stock start route reorder item end route'],
#  ['place order fuel car confirm order pay order item out of stock pick item load cargo start route reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock payment reminder payment reminder load cargo pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car item out of stock payment reminder pick item reorder item payment reminder payment reminder payment reminder pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder pay order load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order payment reminder item out of stock reorder item pick item payment reminder payment reminder payment reminder pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock reorder item pick item start route end route'],
#  ['place order confirm order pick item load cargo pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock pick item reorder item pick item load cargo payment reminder payment reminder pay order start route end route'],
#  ['place order confirm order payment reminder fuel car payment reminder pay order pick item item out of stock reorder item load cargo pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo start route item out of stock reorder item end route'],
#  ['place order fuel car confirm order pick item payment reminder load cargo payment reminder item out of stock pay order start route end route'],
#  ['place order fuel car confirm order pick item payment reminder load cargo payment reminder pay order item out of stock start route reorder item end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock reorder item pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo start route item out of stock end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder load cargo item out of stock pay order start route reorder item end route'],
#  ['place order confirm order pay order fuel car item out of stock pick item load cargo start route end route'],
#  ['place order confirm order fuel car payment reminder item out of stock reorder item pick item load cargo start route end route pay order'],
#  ['place order fuel car confirm order item out of stock payment reminder pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pay order reorder item fuel car pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item reorder item pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car pick item load cargo start route end route payment reminder pay order'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item payment reminder load cargo payment reminder payment reminder start route pay order end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order pick item load cargo start route pay order item out of stock reorder item end route'],
#  ['place order confirm order fuel car pay order pick item item out of stock reorder item load cargo start route pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item pay order fuel car load cargo item out of stock start route end route'],
#  ['place order confirm order item out of stock payment reminder reorder item pay order pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item payment reminder payment reminder pay order reorder item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pick item pay order load cargo start route item out of stock end route'],
#  ['place order fuel car confirm order item out of stock reorder item payment reminder pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item payment reminder load cargo payment reminder payment reminder start route end route payment reminder payment reminder payment reminder pay order'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route pick item load cargo end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route pick item load cargo end route'],
#  ['place order confirm order fuel car item out of stock pick item reorder item load cargo start route end route payment reminder payment reminder payment reminder pay order'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order load cargo reorder item start route end route'],
#  ['place order fuel car confirm order pick item load cargo payment reminder payment reminder item out of stock payment reminder start route pay order reorder item end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item load cargo start route end route payment reminder pay order'],
#  ['place order confirm order item out of stock fuel car pick item load cargo reorder item payment reminder payment reminder payment reminder payment reminder payment reminder pay order start route pick item end route'],
#  ['fuel car place order confirm order item out of stock payment reminder reorder item payment reminder pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['place order confirm order pick item payment reminder fuel car payment reminder payment reminder payment reminder payment reminder pay order load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order pick item payment reminder load cargo payment reminder payment reminder payment reminder payment reminder pay order start route item out of stock reorder item pick item end route'],
#  ['place order fuel car confirm order item out of stock pick item payment reminder payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item pay order fuel car item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pay order pick item load cargo reorder item start route end route'],
#  ['place order confirm order pay order pick item item out of stock reorder item pick item load cargo fuel car start route end route'],
#  ['place order confirm order payment reminder pick item load cargo pay order fuel car item out of stock start route end route'],
#  ['place order confirm order payment reminder fuel car pick item load cargo pay order item out of stock reorder item pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock reorder item payment reminder pick item load cargo start route end route payment reminder payment reminder pay order'],
#  ['place order fuel car confirm order payment reminder pay order pick item load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car payment reminder item out of stock pick item load cargo pay order reorder item start route pick item end route'],
#  ['place order fuel car confirm order pick item payment reminder item out of stock pay order load cargo reorder item start route pick item load cargo end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock pay order load cargo reorder item pick item start route end route'],
#  ['place order fuel car confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item payment reminder load cargo reorder item pay order pick item start route load cargo start route end route'],
#  ['place order confirm order fuel car pay order pick item item out of stock reorder item load cargo pick item start route load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo item out of stock reorder item start route end route'],
#  ['place order confirm order fuel car pick item item out of stock pay order load cargo reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pick item payment reminder pay order reorder item load cargo pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo item out of stock reorder item start route end route'],
#  ['place order confirm order pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock payment reminder reorder item load cargo payment reminder pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pay order load cargo pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item payment reminder pay order pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder pick item pay order load cargo start route reorder item end route'],
#  ['place order fuel car confirm order item out of stock pick item pay order load cargo reorder item pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock reorder item pick item end route'],
#  ['fuel car place order confirm order payment reminder pick item load cargo item out of stock pay order reorder item start route pick item end route'],
#  ['place order confirm order pay order item out of stock reorder item pick item fuel car load cargo start route end route'],
#  ['place order confirm order fuel car pick item payment reminder item out of stock pay order load cargo reorder item start route pick item end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock load cargo start route pay order end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pick item pay order reorder item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder pay order pick item load cargo reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder pay order item out of stock pick item load cargo reorder item pick item load cargo fuel car start route end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['place order confirm order item out of stock fuel car payment reminder payment reminder payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder item out of stock pay order pick item reorder item fuel car load cargo pick item start route load cargo end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder item out of stock reorder item load cargo pick item load cargo payment reminder pay order start route end route'],
#  ['place order fuel car confirm order payment reminder pick item item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder item out of stock payment reminder reorder item load cargo pay order pick item start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pick item reorder item load cargo pick item start route pay order load cargo end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder pick item load cargo item out of stock payment reminder payment reminder reorder item pick item pay order load cargo fuel car start route end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order load cargo start route reorder item pick item end route'],
#  ['fuel car place order confirm order pick item item out of stock payment reminder payment reminder payment reminder payment reminder load cargo payment reminder payment reminder payment reminder reorder item pick item load cargo payment reminder start route end route payment reminder pay order'],
#  ['place order fuel car confirm order pick item item out of stock load cargo pay order start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['place order confirm order fuel car payment reminder pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder load cargo item out of stock reorder item pick item pay order start route load cargo start route end route'],
#  ['place order confirm order item out of stock pick item load cargo pay order reorder item fuel car start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock pay order pick item reorder item load cargo start route pick item end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock load cargo start route pay order reorder item end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item payment reminder payment reminder payment reminder pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['place order confirm order pay order pick item item out of stock load cargo fuel car start route reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item fuel car load cargo payment reminder start route pay order item out of stock end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock pay order reorder item load cargo start route pick item end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item pay order item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo start route item out of stock end route'],
#  ['place order fuel car confirm order pick item item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock load cargo reorder item pick item payment reminder pay order load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pick item payment reminder reorder item pay order load cargo start route pick item end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo item out of stock reorder item start route pick item end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock payment reminder pay order load cargo reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder pay order load cargo item out of stock start route end route'],
#  ['place order confirm order fuel car item out of stock reorder item payment reminder pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pick item reorder item pay order fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder pay order item out of stock load cargo reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item load cargo payment reminder start route pay order item out of stock reorder item end route'],
#  ['place order confirm order pay order pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pay order load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock pay order pick item load cargo start route reorder item pick item end route'],
#  ['fuel car place order confirm order item out of stock payment reminder pay order pick item load cargo start route reorder item end route'],
#  ['place order confirm order pick item item out of stock fuel car pay order reorder item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item item out of stock fuel car pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route end route'],
#  ['place order fuel car confirm order pay order item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item load cargo payment reminder start route payment reminder pay order end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item item out of stock reorder item load cargo start route pick item load cargo end route'],
#  ['place order fuel car confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pay order pick item reorder item pick item fuel car load cargo start route end route'],
#  ['place order fuel car confirm order pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock pay order pick item reorder item load cargo pick item load cargo start route end route'],
#  ['place order confirm order item out of stock fuel car reorder item pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order payment reminder payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['place order confirm order item out of stock fuel car payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item payment reminder payment reminder payment reminder pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo item out of stock start route reorder item pick item end route'],
# ...
#  ['fuel car place order confirm order pick item payment reminder payment reminder load cargo pay order start route item out of stock end route'],
#  ['place order confirm order pay order pick item item out of stock fuel car reorder item load cargo pick item start route end route'],
#  ['place order confirm order payment reminder payment reminder item out of stock payment reminder reorder item pick item load cargo payment reminder pay order fuel car start route end route'],
#  ['place order confirm order item out of stock pick item pay order fuel car load cargo start route reorder item pick item end route'],
#  ['place order fuel car confirm order pick item load cargo payment reminder payment reminder item out of stock reorder item pay order start route end route'],
#  ['place order confirm order fuel car item out of stock pick item load cargo reorder item pick item payment reminder payment reminder start route pay order end route'],
#  ['fuel car place order confirm order pick item payment reminder load cargo pay order start route item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pay order pick item item out of stock reorder item load cargo pick item start route load cargo end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item pay order load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item load cargo item out of stock payment reminder pay order reorder item pick item start route load cargo start route end route'],
#  ['place order confirm order pick item pay order item out of stock reorder item load cargo pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['place order fuel car confirm order payment reminder pay order pick item load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock reorder item end route'],
#  ['fuel car place order confirm order payment reminder payment reminder pick item load cargo payment reminder start route pay order item out of stock end route'],
#  ['place order fuel car confirm order item out of stock payment reminder reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder pay order load cargo start route item out of stock reorder item pick item end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route pick item end route'],
#  ['fuel car place order confirm order item out of stock pick item payment reminder payment reminder reorder item payment reminder pay order load cargo pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['place order confirm order pick item payment reminder fuel car payment reminder payment reminder pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock start route end route'],
#  ['place order confirm order pick item load cargo pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item load cargo pick item load cargo start route end route'],
#  ['place order fuel car confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item load cargo pick item start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder load cargo payment reminder payment reminder start route payment reminder item out of stock payment reminder pay order reorder item pick item load cargo end route'],
#  ['place order confirm order item out of stock reorder item payment reminder pay order pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order reorder item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item load cargo start route reorder item pay order end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item pick item start route end route'],
#  ['place order confirm order pick item payment reminder fuel car pay order item out of stock load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route end route'],
#  ['place order confirm order pick item item out of stock load cargo fuel car pay order start route reorder item end route'],
#  ['fuel car place order confirm order item out of stock pay order pick item reorder item load cargo pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder payment reminder item out of stock pick item load cargo pay order reorder item start route end route'],
#  ['place order confirm order pick item pay order fuel car item out of stock load cargo start route reorder item pick item end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder reorder item payment reminder pick item payment reminder payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item start route pick item end route'],
#  ['fuel car place order confirm order item out of stock payment reminder reorder item pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder payment reminder pay order reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item load cargo start route item out of stock reorder item end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pick item item out of stock reorder item pay order load cargo pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo reorder item pick item start route end route'],
#  ['fuel car place order confirm order pick item item out of stock payment reminder pay order reorder item load cargo start route pick item load cargo start route end route'],
#  ['place order confirm order pick item pay order item out of stock load cargo reorder item fuel car pick item load cargo start route end route'],
#  ['place order confirm order item out of stock pick item reorder item pay order pick item fuel car load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock reorder item load cargo pick item start route end route payment reminder payment reminder pay order'],
#  ['place order confirm order pick item pay order item out of stock load cargo fuel car start route end route'],
#  ['place order confirm order pay order fuel car item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo reorder item start route end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo start route item out of stock reorder item end route'],
#  ['fuel car place order confirm order item out of stock pay order reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock payment reminder reorder item pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder item out of stock reorder item pay order load cargo start route pick item end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item pay order load cargo start route end route'],
#  ['place order confirm order payment reminder payment reminder pay order fuel car item out of stock pick item load cargo start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order payment reminder payment reminder fuel car pick item item out of stock load cargo pay order start route reorder item end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo item out of stock reorder item start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo item out of stock reorder item pick item start route end route'],
#  ['place order fuel car confirm order item out of stock payment reminder pay order pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo start route reorder item end route'],
#  ['place order fuel car confirm order payment reminder pay order item out of stock pick item reorder item load cargo pick item start route load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item reorder item load cargo pay order start route pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item load cargo reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder pay order item out of stock reorder item load cargo start route pick item load cargo end route'],
#  ['fuel car place order confirm order payment reminder pay order item out of stock pick item load cargo start route reorder item end route'],
#  ['place order confirm order pay order item out of stock reorder item pick item load cargo fuel car start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock reorder item load cargo start route pick item end route'],
#  ['fuel car place order confirm order pick item item out of stock pay order reorder item load cargo start route pick item load cargo start route end route'],
#  ['place order fuel car confirm order item out of stock reorder item pick item load cargo pay order start route end route'],
#  ['fuel car place order confirm order pay order pick item item out of stock load cargo start route end route'],
#  ['place order confirm order pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order fuel car item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pick item payment reminder item out of stock reorder item load cargo start route pay order pick item end route'],
#  ['fuel car place order confirm order item out of stock pick item reorder item load cargo pick item load cargo payment reminder start route pay order end route'],
#  ['place order fuel car confirm order payment reminder pick item pay order load cargo start route end route'],
#  ['fuel car place order confirm order pay order pick item load cargo start route item out of stock reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item item out of stock reorder item pick item payment reminder load cargo pay order start route end route'],
#  ['fuel car place order confirm order pick item load cargo start route item out of stock payment reminder pay order reorder item pick item end route'],
#  ['place order confirm order pay order fuel car item out of stock pick item reorder item load cargo start route end route'],
#  ['place order fuel car confirm order pick item item out of stock pay order reorder item load cargo pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock fuel car pick item reorder item load cargo pick item load cargo start route end route'],
#  ['fuel car place order confirm order pick item payment reminder payment reminder load cargo start route item out of stock end route pay order'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order pick item item out of stock load cargo start route reorder item pick item end route'],
#  ['place order fuel car confirm order pick item pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order pick item item out of stock load cargo fuel car start route end route'],
#  ['place order fuel car confirm order pick item payment reminder pay order item out of stock reorder item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order payment reminder pay order pick item load cargo item out of stock reorder item pick item load cargo start route end route'],
#  ['place order fuel car confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ['place order confirm order pay order item out of stock fuel car pick item load cargo reorder item start route end route'],
#  ['place order confirm order fuel car pay order item out of stock pick item reorder item pick item load cargo start route end route'],
#  ['fuel car place order confirm order item out of stock pick item reorder item pay order pick item load cargo start route end route'],
#  ['fuel car place order confirm order pay order item out of stock reorder item pick item load cargo start route end route'],
#  ...]

# %%
def process_log(gen_log, ocel, ocpn):
    #generate mapping dictionary for activites and objects
    mapping_dict = {}
    for transition in ocpn.transitions:
        if not transition.silent:
            mapping_dict[transition.name] = list(transition.preset_object_type)
    #get the unique activities in the log
    activities = np.unique(ocel.log.log.event_activity)
    original_log = []
    # Iterate over each inner list in gen_log
    for inner_list in gen_log:
        # Create an empty list to store the original activity names
        original_inner_list = []

        # Split the concatenated activities into individual words
        activities_in_inner_list = inner_list[0].split()

        # Initialize the index variable
        i = 0
        # Loop through the activities_in_inner_list
        while i < len(activities_in_inner_list):
            # Initialize a variable to store the matched activity
            matched_activity = None
            # Loop through the activities list to find a match
            for activity in activities:
                # Check if the concatenated words match the activity
                if ' '.join(activities_in_inner_list[i:i+len(activity.split())]).lower() == activity.lower():
                    # Set the matched activity
                    matched_activity = activity
                    # Break the loop as a match is found
                    break

            # Check if a match is found
            if matched_activity:
                # Append the matched activity to the original_inner_list
                original_inner_list.append(matched_activity)
                # Update the index by the number of words in the matched activity
                i += len(matched_activity.split())
            else:
                # If no match is found, update the index by 1 to move to the next word
                i += 1

        # Append the original_inner_list to the original_log
        original_log.append(original_inner_list)
    # Create an empty list to store the data
    data = []

    # Define the start and end date in 2022
    start_date = datetime(2022, 1, 1)

    # Variables for tracking the date and count
    current_date = start_date
    count = 0

    # Iterate over each inner list in original_log
    for inner_list in original_log:
        
        # Get the activities in the inner list
        activities = inner_list

        # Generate a random timestamp within the execution day
        execution_time = random.uniform(0, 1) * 24
        execution_timestamp = current_date + timedelta(hours=execution_time)

        # Create a dictionary to store the column values for each activity
        activity_dict = {
            'event_activity': [],
            'event_execution': [],
            'event_timestamp': [],
            'event_start_timestamp': []
        }

        # Add each activity, execution, and timestamp to the data list
        for activity in activities:

            activity_dict['event_activity'].append(activity)
            activity_dict['event_execution'].append(count+1)
            activity_dict['event_timestamp'].append(execution_timestamp.strftime('%Y-%m-%d %H:%M:%S.%f'))
            activity_dict['event_start_timestamp'].append(execution_timestamp.strftime('%Y-%m-%d %H:%M:%S.%f'))

            # Check if the count is a multiple of 100
            if count % 100 == 0:
                current_date += timedelta(days=1)  # Increase the date by 1

            # Increment the timestamp for the next activity within the same execution
            execution_timestamp += timedelta(minutes=1)
        count += 1
        # Get the distinct object types for the activities in the inner list
        object_types = set()
        for activity in activities:
            object_types.update(mapping_dict.get(activity, []))

        # Add columns for each distinct object type and initialize with empty values
        for object_type in object_types:
            activity_dict[object_type] = [''] * len(activities)

        # Update the column values with the corresponding objects
        for idx, activity in enumerate(activities):
            objects = mapping_dict.get(activity, [])
            for object_type in objects:
                activity_dict[object_type][idx] = [f"{object_type}{count}"]

         # Fill empty values in object columns with an empty list
        for object_type in object_types:
            activity_dict[object_type] = [value if value != '' else [] for value in activity_dict[object_type]]


        # Extend the data list with the activity_dict
        data.extend([{k: v[i] for k, v in activity_dict.items()} for i in range(len(activities))])

    # Convert the data list into a pandas DataFrame
    df_log = pd.DataFrame(data)
    # Include the index as a column
    df_log.reset_index(inplace=True)

    # Rename the index column to 'event_id'
    df_log.rename(columns={'index': 'event_id'}, inplace=True)

    
    return df_log

# %%
df_log = process_log(gen_log, ocel, ocpn)

# %%
df_log
# Out:
#         event_id     event_activity  event_execution  \
# 0              0           Fuel Car                1
# 1              1        Place Order                1
# 2              2      Confirm Order                1
# 3              3          Pay Order                1
# 4              4  Item out of stock                1
# ...          ...                ...              ...
# 114632    114632           Fuel Car            10000
# 114633    114633  Item out of stock            10000
# 114634    114634         Load Cargo            10000
# 114635    114635        Start Route            10000
# 114636    114636          End Route            10000
#
#                    event_timestamp       event_start_timestamp     order  \
# 0       2022-01-01 11:07:26.942074  2022-01-01 11:07:26.942074        []
# 1       2022-01-01 11:08:26.942074  2022-01-01 11:08:26.942074  [order1]
# 2       2022-01-01 11:09:26.942074  2022-01-01 11:09:26.942074  [order1]
# 3       2022-01-01 11:10:26.942074  2022-01-01 11:10:26.942074  [order1]
# 4       2022-01-01 11:11:26.942074  2022-01-01 11:11:26.942074        []
# ...                            ...                         ...       ...
# 114632  2025-02-19 05:55:50.351499  2025-02-19 05:55:50.351499        []
# 114633  2025-02-19 05:56:50.351499  2025-02-19 05:56:50.351499        []
# 114634  2025-02-19 05:57:50.351499  2025-02-19 05:57:50.351499        []
# 114635  2025-02-19 05:58:50.351499  2025-02-19 05:58:50.351499        []
# 114636  2025-02-19 05:59:50.351499  2025-02-19 05:59:50.351499        []
#
#                item         delivery
# 0                []      [delivery1]
# 1           [item1]               []
# 2           [item1]               []
# 3                []               []
# 4           [item1]               []
# ...             ...              ...
# 114632           []  [delivery10000]
# 114633  [item10000]               []
# 114634  [item10000]  [delivery10000]
# 114635  [item10000]  [delivery10000]
# 114636  [item10000]  [delivery10000]
#
# [114637 rows x 8 columns]

# %%
b def readFile(f_name1, f_name2, unique=False):
    traces = []

    skipped = 0

    with open(f_name1) as file:
        file_contents = file.read()
        file_contents = file_contents.split("\n")
        print("Number of train traces are:", str(len(file_contents)))
        for row in file_contents:
            if unique:
                if row not in traces:
                    traces.append(row)
                else:
                    skipped += 1
            else:
                traces.append(row)

    with open(f_name2) as file:
        file_contents = file.read()
        file_contents = file_contents.split("\n")
        print("Number of generated traces are:", str(len(file_contents)))
        for row in file_contents:
            if unique:
                if row not in traces:
                    traces.append(row)
                else:
                    skipped += 1
            else:
                traces.append(row)

    f_traces = []
    for trace in traces:
        f_trace = []
        t = trace.split(" ")
        for i in t:
            if i != "" and "<" not in i:
                f_trace.append(i)
        if len(f_trace) > 0:
            f_traces.append(f_trace)

    print("Number of traces are:", str(len(f_traces)))
    print("Number of skipped traces are:", str(skipped))
    return f_traces

def writeToFile(file, lst):
    with open(file, 'w') as outfile:
        for entry in lst:
            outfile.write(str(entry) + "\n")

def convertToCsv(traces, to_path):
    lines = []

    case = 0
    timestamp = 0
    line = "concept:name,case:concept:name,time:timestamp"
    lines.append(line)
    for trace in traces:
        for event in trace:
            timestamp = timestamp + 1
            dt_object = datetime.fromtimestamp(timestamp)

            line = str(event) + "_" + "," + str(case) + "," + str(dt_object)
            lines.append(line)

        case = case + 1

    writeToFile(str(to_path), lines)

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument('-s', '--system', help='Which system (e.g. pb_system_5_3)', required=True)
    parser.add_argument('-sfx', '--suffix', help='Suffix (chosen epoch, e.g. 1981)', required=True)
    parser.add_argument('-j', '--job', help='Job (0/1)', required=True)
    parser.add_argument('-pn', '--pn', help='Petri net file to evaluate', required=True)
    parser.add_argument('-strategy', '--strategy', help='naive/mh', required=True)
    args = parser.parse_args()

    system = args.system
    suffix = int(args.suffix)
    job = args.job
    pn = args.pn
    strategy = args.strategy

    if DATA_PATH is None:
        train_file = os.path.join(WORK_PATH, "data", "variants", system + "_train.txt")
        gen_file = os.path.join(WORK_PATH, "data", "avatar", "variants", system + "_relgan_" + str(suffix) + "_j" + str(job) + "_" + strategy + ".txt")
        csv_file = os.path.join(WORK_PATH, "data", "avatar", "variants", system + "_relgan_" + str(suffix) + "_j" + str(job) + "_" + strategy + "_generalization.csv")
        xes_file = os.path.join(WORK_PATH, "data", "avatar", "variants", system + "_relgan_" + str(suffix) + "_j" + str(job) + "_" + strategy + "_generalization.xes")
        pn_file = os.path.join(WORK_PATH, "data", "pns", system, pn)
    else:
        train_file = os.path.join(DATA_PATH, "variants", system + "_train.txt")
        gen_file = os.path.join(DATA_PATH, "avatar", "variants", system + "_relgan_" + str(suffix) + "_j" + str(job) + "_" + strategy + ".txt")
        csv_file = os.path.join(DATA_PATH, "avatar", "variants", system + "_relgan_" + str(suffix) + "_j" + str(job) + "_" + strategy + "_generalization.csv")
        xes_file = os.path.join(DATA_PATH, "avatar", "variants", system + "_relgan_" + str(suffix) + "_j" + str(job) + "_" + strategy + "_generalization.xes")
        pn_file = os.path.join(DATA_PATH, "pns", system, pn)


    """ READ FILES AND CONVERT TO XES """
    traces = readFile(train_file,gen_file, unique=True)
    convertToCsv(traces=traces, to_path=csv_file)
    time.sleep(1)

    log = csv_importer.import_event_log(csv_file)
    xes_exporter.export_log(log, xes_file)
    time.sleep(1)

    """ PERFORM MEASUREMENT ON PN AND XES"""
from ocpa.objects.log.importer.ocel import factory as ocel_import_factory
from ocpa.algo.conformance.precision_and_fitness import evaluator as quality_measure_factory
from ocpa.algo.discovery.ocpn import algorithm as ocpn_discovery_factory

filename = "../../sample_logs/jsonocel/p2p-normal.jsonocel"
ocel = ocel_import_factory.apply(filename)
ocpn = ocpn_discovery_factory.apply(ocel, parameters = {"debug":False})
precision, fitness = quality_measure_factory.apply(ocel, ocpn)
print("Precision of IM-discovered net: "+str(precision))
print("Fitness of IM-discovered net: "+str(fitness))

    fitness = fitness["log_fitness"]
    generalization = 2 * ((fitness * precision) / (fitness + precision))

    if strategy == "mh":
        print("**** ", str(system), " Job ", str(job), " on PN ", str(pn_file), " using MH SAMPLING on suffix ", str(suffix)," ***")
    elif strategy == "naive":
        print("**** ", str(system), " Job ", str(job), " on PN ", str(pn_file), " using NAIVE SAMPLING on suffix ", str(suffix), " ***")
    else:
        raise ValueError("Unknown strategy.")
    print("AVATAR Generalization=", generalization)
