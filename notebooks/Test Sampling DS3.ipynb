# %% [markdown]
# # VAE Approach

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from ocpa.objects.log.importer.ocel import factory as ocel_import_factory
from ocpa.algo.discovery.ocpn import algorithm as ocpn_discovery_factory
from tqdm import tqdm
import numpy as np
from ocpa.algo.util.filtering.log.variant_filtering import filter_infrequent_variants
import os
import random
from ocpa.objects.log.importer.csv import factory as ocel_import_factory_csv
from ocpa.visualization.oc_petri_net import factory as ocpn_vis_factory
from ocpa.algo.conformance.precision_and_fitness.variants import replay_context

# %%
def save_process_model_visualization(ocel, save_path) :
    """
    Function to generate the process model of an JSONOCEL-log and save it as svg.
    :param ocel: given OCEL-log, type: OCEL-Log
    :param save_path: path for the saved process model visualization, type: string
    """
    #change the environment path for visualization
    os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin'
    # get the object-centric petri net
    ocpn = ocpn_discovery_factory.apply(ocel, parameters={"debug": False})
    # generate the visualization
    gviz = ocpn_vis_factory.apply(ocpn, parameters={'format': 'svg'})
    # save the visualization
    ocpn_vis_factory.save(gviz, save_path)

# %%
def filter_silent_transitions(dic,silent_transitions):
    """
    Function to filter out the silent transitions defined by a list from a given dictionary.
    :param dic: dictionary to be filtered, type: dictionary
    :param silent_transitions: list of silent transitions in an ocel log, type: list
    :return updated_dictionary: filtered dictionary, type: dictionary
    """
    updated_dictionary = {}
    for key, values in dic.items():
        if key not in silent_transitions:
            new_values = [val for val in values if val not in silent_transitions]
            updated_dictionary[key] = new_values
    return updated_dictionary

#recursive implementation of a depth-first search (DFS) algorithm
def dfs(graph, visited, activity, preceding_events):
    """
    Function to perform a depth-first search (DFS) algorithm on the activity graph.
    :param graph: activity graph, type: dictionary
    :param visited: set of already visited nodes, type: set
    :param activity: current activity, type: string
    :param preceding_events: list to store the preceding events, type: list
    """
    #takes as input the activity graph (represented as a dictionary), a set of visited nodes, the current activity, and a list to store the preceding events.
    visited.add(activity)
    for preceding_event in graph[activity]:
        #eighboring activity has not been visited yet, the algorithm visits it by calling the dfs function with the neighboring activity as the current activity.
        if preceding_event not in visited:
            dfs(graph, visited, preceding_event, preceding_events)
    preceding_events.append(activity)

# %% [markdown]
# # DS3 Log

# %%
filename = "../src/data/jsonocel/DS3.jsonocel"
ocel = ocel_import_factory.apply(filename)
ocpn = ocpn_discovery_factory.apply(ocel, parameters={"debug": False})

# %%
filtered = filter_infrequent_variants(ocel, 0.4)

# %%
filtered.log.log
# Out:
#              event_id      event_activity     event_timestamp event_category  \
# event_index
# 49687           49687        New Incident 2016-01-04 01:59:00    Category 42
# 49688           49688            Resolved 2016-01-04 01:59:00    Category 42
# 49689           49689     Closed Incident 2016-01-04 01:59:00    Category 42
# 49726           49726            Resolved 2016-01-04 08:59:00    Category 32
# 49727           49727     Closed Incident 2016-01-04 08:59:00    Category 32
# ...               ...                 ...                 ...            ...
# 99945           99945              Active 2017-10-01 01:00:00    Category 46
# 99946           99946              Active 2017-10-01 01:00:00    Category 46
# 99947           99947  Awaiting User Info 2017-10-01 01:00:00    Category 46
# 99948           99948            Resolved 2017-10-01 01:00:00    Category 46
# 99949           99949     Closed Incident 2017-10-01 01:00:00    Category 46
#
#             event_location event_cmdb_ci event_resolved_at  \
# event_index
# 49687         Location 204             ?  27/03/2016 01:12
# 49688         Location 204             ?  27/03/2016 01:12
# 49689         Location 204             ?  27/03/2016 01:12
# 49726         Location 204             ?                 ?
# 49727         Location 204             ?                 ?
# ...                    ...           ...               ...
# 99945         Location 179             ?  06/07/2016 16:15
# 99946         Location 179             ?  06/07/2016 16:15
# 99947         Location 179             ?  06/07/2016 16:15
# 99948         Location 179             ?  06/07/2016 16:15
# 99949         Location 179             ?  06/07/2016 16:15
#
#             event_sys_created_by event_problem_id event_subcategory  ...  \
# event_index                                                          ...
# 49687                          ?                ?   Subcategory 174  ...
# 49688                          ?                ?   Subcategory 174  ...
# 49689                          ?                ?   Subcategory 174  ...
# 49726                          ?                ?   Subcategory 174  ...
# 49727                          ?                ?   Subcategory 174  ...
# ...                          ...              ...               ...  ...
# 99945              Created by 13  Problem ID  210   Subcategory 231  ...
# 99946              Created by 13  Problem ID  210   Subcategory 231  ...
# 99947              Created by 13  Problem ID  210   Subcategory 231  ...
# 99948              Created by 13  Problem ID  210   Subcategory 231  ...
# 99949              Created by 13  Problem ID  210   Subcategory 231  ...
#
#             event_caused_by event_assignment_group   event_notify  \
# event_index
# 49687                     ?               Group 70  Do Not Notify
# 49688                     ?               Group 70  Do Not Notify
# 49689                     ?               Group 70  Do Not Notify
# 49726                     ?               Group 70  Do Not Notify
# 49727                     ?               Group 70  Do Not Notify
# ...                     ...                    ...            ...
# 99945                     ?               Group 37  Do Not Notify
# 99946                     ?               Group 37  Do Not Notify
# 99947                     ?               Group 37  Do Not Notify
# 99948                     ?               Group 37  Do Not Notify
# 99949                     ?               Group 37  Do Not Notify
#
#             event_urgency  event_closed_code   event_opened_at  event_impact  \
# event_index
# 49687          2 - Medium             code 6  27/03/2016 00:11    2 - Medium
# 49688          2 - Medium             code 6  27/03/2016 00:11    2 - Medium
# 49689          2 - Medium             code 6  27/03/2016 00:11    2 - Medium
# 49726          2 - Medium             code 7  27/03/2016 08:30    2 - Medium
# 49727          2 - Medium             code 7  27/03/2016 08:30    2 - Medium
# ...                   ...                ...               ...           ...
# 99945            1 - High             code 6  02/05/2016 09:41      1 - High
# 99946            1 - High             code 6  02/05/2016 09:41      1 - High
# 99947            1 - High             code 6  02/05/2016 09:41      1 - High
# 99948            1 - High             code 6  02/05/2016 09:41      1 - High
# 99949            1 - High             code 6  02/05/2016 09:41      1 - High
#
#             event_start_timestamp      incident       customer
# event_index
# 49687         2016-01-04 01:59:00  [INC0011529]  [Caller 5613]
# 49688         2016-01-04 01:59:00  [INC0011529]             []
# 49689         2016-01-04 01:59:00  [INC0011529]  [Caller 5613]
# 49726         2016-01-04 08:59:00  [INC0011551]             []
# 49727         2016-01-04 08:59:00  [INC0011551]  [Caller 5589]
# ...                           ...           ...            ...
# 99945         2017-10-01 01:00:00  [INC0024747]             []
# 99946         2017-10-01 01:00:00  [INC0024747]             []
# 99947         2017-10-01 01:00:00  [INC0024747]             []
# 99948         2017-10-01 01:00:00  [INC0024747]             []
# 99949         2017-10-01 01:00:00  [INC0024747]  [Caller 1441]
#
# [39209 rows x 38 columns]

# %%
save_process_model_visualization(filtered, "../src/DS3_filtered.svg")

# %%
ocpn = ocpn_discovery_factory.apply(filtered, parameters={"debug": False})

# %%
ocel=filtered

# %%
# we create another dictionary that only contains the the value inside the list to be able to derive the case
mapping_dict = {key: ocel.process_execution_mappings[key][0] for key in ocel.process_execution_mappings}
# we generate a new column in the class (log) that contains the process execution (case) number via the generated dictionary
ocel.log.log['event_execution'] = ocel.log.log.index.map(mapping_dict)
# dictionary to store each activity as key and a list of its prior states/places as value
targets = {}
# dictionary to store each activity as key and a list of its following states/places as value
sources = {}
for arc in tqdm(ocpn.arcs, desc="Check the arcs"):
    # for each arc, check if our target is a valid transition
    if arc.target in ocpn.transitions:
        # load all the prior places of a valid transition into a dictionary, where the key is the transition and the value
        # a list of all directly prior places
        if arc.target.name in targets:
            targets[arc.target.name].append(arc.source.name)
        else:
            targets[arc.target.name] = [arc.source.name]
    if arc.source in ocpn.transitions:
        # load all the following places of a valid transition into a dictionary, where the key is the transition and the value
        # a list of all directly following places
        if arc.source.name in sources:
            sources[arc.source.name].append(arc.target.name)
        else:
            sources[arc.source.name] = [arc.target.name]
# generate an empty dictionary to store the directly preceeding transition of an activity
preceding_activities = {}
# use the key and value of targets and source to generate the dictionary
for target_key, target_value in targets.items():
    preceding_activities[target_key] = []
    for source_key, source_value in sources.items():
        for element in target_value:
            if element in source_value:
                preceding_activities[target_key].append(source_key)
                break
# generate an empty dictionary to store the directly succeeding transition of an activity
succeeding_activities = {}
for source_key, source_value in sources.items():
    succeeding_activities[source_key] = []
    for target_key, target_value in targets.items():
        for element in source_value:
            if element in target_value:
                succeeding_activities[source_key].append(target_key)
                break
# store the name of all silent transitions in the log
silent_transitions = [x.name for x in ocpn.transitions if x.silent]
# replace the silent transitions in the succeeding activities dictionary by creating a new dictionary to store the modified values
succeeding_activities_updated = {}
# Iterate through the dictionary
for key, values in succeeding_activities.items():
    # Create a list to store the modified values for this key
    new_values = []
    # Iterate through the values of each key
    for i in range(len(values)):
        # Check if the value is in the list of silent transitions
        if values[i] in silent_transitions:
            # Replace the value with the corresponding value from the dictionary
            new_values.extend(succeeding_activities[values[i]])
        else:
            # If the value is not in the list of silent transitions, add it to the new list
            new_values.append(values[i])
    # Add the modified values to the new dictionary
    succeeding_activities_updated[key] = new_values
# create an empty dictionary to store all the precedding activities of an activity
preceding_events_dict = {}
# use a depth-first search (DFS) algorithm to traverse the activity graph and
# create a list of all preceding events for each activity in the dictionary for directly preceding activities
for activity in preceding_activities:
    # empty set for all the visited activities
    visited = set()
    # list for all currently preceding events
    preceding_events = []
    dfs(preceding_activities, visited, activity, preceding_events)
    # we need to remove the last element from the list because it corresponds to the activity itself
    preceding_events_dict[activity] = preceding_events[:-1][::-1]
# Out:
# Check the arcs: 100%|██████████| 102/102 [00:00<00:00, 106158.56it/s]

# %%
succeding_events_dict = {}

# %%
for activity in succeeding_activities:
    # empty set for all the visited activities
    visited = set()
    # list for all currently preceding events
    succeeding_events = []
    dfs(succeeding_activities, visited, activity, succeeding_events)
    # we need to remove the last element from the list because it corresponds to the activity itself
    succeding_events_dict[activity] = succeeding_events[:-1][::-1]

# %%
succeding_events_dict
# Out:
# {'incidenttauSplit_13': ['incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_43': [],
#  'incidentskip_31': ['incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_26': ['incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_31',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentinit_loop_4': ['New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'Closed Incident': ['customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'Awaiting Problem': ['incidentskip_24',
#   'incidentskip_25',
#   'incidentskip_26',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_31',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_21': ['incidentskip_26',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_31',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'customerskip_9': ['Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_6': ['New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'customerskip_9',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidenttau_1': ['incidentskip_3',
#   'incidentinit_loop_4',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'customerskip_10': ['customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'Closed Incident',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'customerskip_8': ['New Incident',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_41': ['incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'customerskip_11',
#   'incidentskip_40',
#   'incidentskip_43'],
#  'incidentinit_loop_27': ['Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_12': ['Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_36',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'customerskip_11': [],
#  'incidentskip_20': ['incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_30': ['incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentinit_loop_10': ['incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentinit_loop_8': ['incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentinit_loop_32': ['Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_3': ['incidentinit_loop_8',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentinit_loop_22': ['Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentskip_26',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_31',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'Resolved': ['incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'customerskip_5': ['Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_37': ['Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_42': ['incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentinit_loop_16': ['Awaiting User Info',
#   'incidentskip_19',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40',
#   'incidentskip_18'],
#  'incidentskip_24': ['Awaiting Problem',
#   'incidentskip_25',
#   'incidentskip_26',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_31',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'Active': ['incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_7': ['incidentinit_loop_8',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_29': ['Awaiting Vendor',
#   'incidentskip_30',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'Awaiting Evidence': ['incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_36': ['incidentskip_12',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_18': ['Awaiting User Info',
#   'incidentskip_19',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_35': ['incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_25': ['incidentskip_26',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_31',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'Awaiting Vendor': ['incidentskip_29',
#   'incidentskip_30',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'Awaiting User Info': ['incidentskip_19',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40',
#   'incidentskip_18'],
#  'customertau_1': ['customerskip_5',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'New Incident': ['customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_34': ['Awaiting Evidence',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidenttauJoin_14': ['Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_19': ['incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'customerinit_loop_6': ['New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'Closed Incident',
#   'customerskip_10',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40'],
#  'incidentskip_40': ['Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Active',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentskip_15',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidenttauJoin_14',
#   'Resolved',
#   'incidentskip_37',
#   'incidentskip_43',
#   'customerskip_11'],
#  'incidentskip_15': ['incidenttauJoin_14',
#   'Active',
#   'incidentskip_37',
#   'Closed Incident',
#   'customerskip_10',
#   'customerinit_loop_6',
#   'New Incident',
#   'customerskip_8',
#   'incidentskip_7',
#   'incidentinit_loop_8',
#   'incidentskip_6',
#   'customerskip_9',
#   'customerskip_5',
#   'incidentskip_41',
#   'incidentskip_42',
#   'incidentinit_loop_10',
#   'incidentskip_12',
#   'Resolved',
#   'incidentskip_36',
#   'incidenttauSplit_13',
#   'incidentskip_21',
#   'incidentinit_loop_16',
#   'Awaiting User Info',
#   'incidentskip_19',
#   'incidentskip_18',
#   'incidentskip_20',
#   'incidentinit_loop_22',
#   'Awaiting Problem',
#   'incidentskip_24',
#   'incidentskip_25',
#   'incidentinit_loop_27',
#   'Awaiting Vendor',
#   'incidentskip_29',
#   'incidentskip_30',
#   'incidentskip_26',
#   'incidentskip_31',
#   'incidentinit_loop_32',
#   'Awaiting Evidence',
#   'incidentskip_34',
#   'incidentskip_35',
#   'incidentskip_43',
#   'customerskip_11',
#   'incidentskip_40']}

# %%
succeeding_activities_updated
# Out:
# {'incidentskip_26': ['incidenttauJoin_13'],
#  'New Incident': ['incidentskip_8',
#   'incidentinit_loop_9',
#   'New Incident',
#   'New Incident',
#   'customertauJoin_4'],
#  'incidentinit_loop_9': ['Closed Incident',
#   'incidentskip_27',
#   'incidentinit_loop_28',
#   'incidenttauSplit_15',
#   'incidentskip_14'],
#  'Awaiting User Info': ['incidenttauJoin_16', 'Awaiting User Info'],
#  'incidenttauSplit_15': ['incidenttauJoin_16',
#   'incidenttauJoin_16',
#   'Active',
#   'Awaiting User Info'],
#  'customerskip_9': [],
#  'incidentskip_50': ['Closed Incident'],
#  'incidentskip_20': ['Awaiting User Info'],
#  'incidentinit_loop_45': ['Awaiting Vendor'],
#  'incidenttauJoin_13': ['Closed Incident'],
#  'incidentskip_7': ['incidenttau_2', 'incidentskip_11', 'incidenttauSplit_12'],
#  'incidentinit_loop_4': ['New Incident'],
#  'Awaiting Problem': ['Awaiting Problem',
#   'incidentskip_39',
#   'incidentinit_loop_40'],
#  'incidenttau_2': [],
#  'customertauJoin_4': [],
#  'incidentskip_14': ['Closed Incident'],
#  'incidentskip_8': [],
#  'customerskip_13': [],
#  'incidentskip_30': ['Resolved'],
#  'incidentskip_42': ['Awaiting Evidence'],
#  'customerinit_loop_10': ['New Incident'],
#  'incidentskip_49': ['Resolved',
#   'incidentskip_33',
#   'incidentskip_44',
#   'incidentinit_loop_35',
#   'incidentinit_loop_45',
#   'incidentskip_34'],
#  'incidentskip_44': ['Resolved'],
#  'incidentskip_3': ['incidenttau_2', 'incidentskip_11', 'incidenttauSplit_12'],
#  'customertau_1': ['customertauJoin_4', 'Closed Incident', 'New Incident'],
#  'incidenttauJoin_16': ['Closed Incident'],
#  'incidentskip_43': ['Resolved'],
#  'incidentskip_6': ['New Incident'],
#  'Awaiting Evidence': ['incidenttauJoin_32', 'Awaiting Evidence'],
#  'Closed Incident': ['incidentskip_11',
#   'incidenttauSplit_12',
#   'incidenttau_2',
#   'Closed Incident'],
#  'incidentskip_38': ['incidenttauJoin_32', 'Awaiting Evidence'],
#  'incidenttauSplit_12': ['incidenttauJoin_13',
#   'incidentskip_30',
#   'incidenttauSplit_31',
#   'incidentskip_22',
#   'incidentskip_17',
#   'incidentinit_loop_23',
#   'incidentinit_loop_18',
#   'incidenttauJoin_13'],
#  'incidentskip_37': ['Awaiting Problem'],
#  'incidentinit_loop_23': ['Active'],
#  'incidentinit_loop_35': ['Awaiting Problem'],
#  'incidentskip_47': ['Awaiting Vendor'],
#  'incidenttau_1': ['New Incident', 'incidentskip_8', 'incidentinit_loop_9'],
#  'incidenttauSplit_31': ['incidenttauJoin_32',
#   'incidenttauJoin_32',
#   'Awaiting Problem',
#   'Awaiting Vendor',
#   'incidentskip_39',
#   'incidentinit_loop_40'],
#  'incidentskip_27': ['Closed Incident'],
#  'incidentskip_51': ['Closed Incident',
#   'incidentskip_27',
#   'incidentinit_loop_28',
#   'incidenttauSplit_15',
#   'incidentskip_14'],
#  'incidentskip_33': ['Resolved'],
#  'customerskip_7': ['Closed Incident'],
#  'incidentskip_17': ['incidenttauJoin_13'],
#  'customerskip_12': ['New Incident'],
#  'incidentskip_39': ['Resolved'],
#  'Awaiting Vendor': ['Awaiting Vendor', 'incidenttauJoin_32'],
#  'incidentskip_11': ['Closed Incident'],
#  'incidentskip_48': ['Resolved'],
#  'Resolved': ['incidenttauJoin_13', 'incidentskip_30', 'incidenttauSplit_31'],
#  'incidentskip_52': [],
#  'incidentskip_34': ['incidenttauJoin_32', 'Awaiting Evidence'],
#  'incidentinit_loop_28': ['Resolved',
#   'incidentskip_33',
#   'incidentskip_44',
#   'incidentinit_loop_35',
#   'incidentinit_loop_45',
#   'incidentskip_34'],
#  'incidenttauJoin_32': ['Resolved'],
#  'Active': ['Active', 'incidenttauJoin_16'],
#  'incidentskip_21': ['incidenttauJoin_13'],
#  'incidentinit_loop_40': ['Awaiting Evidence'],
#  'incidentskip_22': ['incidenttauJoin_13'],
#  'incidentinit_loop_18': ['Awaiting User Info'],
#  'incidentskip_25': ['Active']}

# %%
# delete all possible silent transitions from preceding_events_dict (dict where all direct preceeding events are stored)
filtered_preceeding_events_full = filter_silent_transitions(preceding_events_dict, silent_transitions)
# delete all possible silent transitions from filtered_preceeding_events (dict where only direct preceeding events are stored)
filtered_preceeding_events = filter_silent_transitions(preceding_activities, silent_transitions)
# delete all possible silent transitions from succeeding_activities_updated (dict where only direct preceeding events are stored)
filtered_succeeding_activities_updated = filter_silent_transitions(succeeding_activities_updated,silent_transitions)

# %%
filtered_preceeding_events_full
# Out:
# {'Active': ['New Incident',
#   'Closed Incident',
#   'Resolved',
#   'Awaiting User Info',
#   'Awaiting Evidence',
#   'Awaiting Vendor',
#   'Awaiting Problem'],
#  'New Incident': ['Closed Incident',
#   'Resolved',
#   'Active',
#   'Awaiting User Info',
#   'Awaiting Evidence',
#   'Awaiting Vendor',
#   'Awaiting Problem'],
#  'Awaiting Evidence': ['New Incident',
#   'Closed Incident',
#   'Resolved',
#   'Active',
#   'Awaiting User Info',
#   'Awaiting Vendor',
#   'Awaiting Problem'],
#  'Closed Incident': ['Resolved',
#   'Active',
#   'Awaiting User Info',
#   'Awaiting Evidence',
#   'Awaiting Vendor',
#   'Awaiting Problem',
#   'New Incident'],
#  'Awaiting Problem': ['New Incident',
#   'Closed Incident',
#   'Resolved',
#   'Active',
#   'Awaiting User Info',
#   'Awaiting Evidence',
#   'Awaiting Vendor'],
#  'Resolved': ['New Incident',
#   'Closed Incident',
#   'Active',
#   'Awaiting User Info',
#   'Awaiting Evidence',
#   'Awaiting Vendor',
#   'Awaiting Problem'],
#  'Awaiting Vendor': ['New Incident',
#   'Closed Incident',
#   'Resolved',
#   'Active',
#   'Awaiting User Info',
#   'Awaiting Evidence',
#   'Awaiting Problem'],
#  'Awaiting User Info': ['New Incident',
#   'Closed Incident',
#   'Resolved',
#   'Active',
#   'Awaiting Evidence',
#   'Awaiting Vendor',
#   'Awaiting Problem']}

# %%
filtered_preceeding_events
# Out:
# {'Active': [],
#  'New Incident': [],
#  'Awaiting Evidence': [],
#  'Closed Incident': [],
#  'Awaiting Problem': [],
#  'Resolved': [],
#  'Awaiting Vendor': [],
#  'Awaiting User Info': []}

# %%
filtered_succeeding_activities_updated
# Out:
# {'Closed Incident': ['Closed Incident'],
#  'Awaiting Problem': ['Awaiting Problem'],
#  'Resolved': ['Closed Incident'],
#  'Active': ['Closed Incident'],
#  'Awaiting Evidence': ['Awaiting Evidence'],
#  'Awaiting Vendor': ['Awaiting Vendor'],
#  'Awaiting User Info': ['Awaiting User Info'],
#  'New Incident': ['Closed Incident', 'New Incident', 'New Incident']}

# %%
def sample_traces(ocel, ocpn, amount, length = None, save_path = None):
    """
    Function to generate a sample of traces from an object-centric petri net.
    :param ocel: given OCEL-log, type: OCEL-Log
    :param ocpn: given object-centric petri net, type: ObjectCentricPetriNet
    :param amount: amount of traces to be generated, type: int
    :param length: maximum length of the traces to be generated, if not given, gets generated as double the average length in th log, type: int
    :return: list of sampled traces in lists, type: list
    """
   # we create another dictionary that only contains the the value inside the list to be able to derive the case
    mapping_dict = {key: ocel.process_execution_mappings[key][0] for key in ocel.process_execution_mappings}
    # we generate a new column in the class (log) that contains the process execution (case) number via the generated dictionary
    ocel.log.log['event_execution'] = ocel.log.log.index.map(mapping_dict)
    # dictionary to store each activity as key and a list of its prior states/places as value
    targets = {}
    # dictionary to store each activity as key and a list of its following states/places as value
    sources = {}
    for arc in tqdm(ocpn.arcs, desc="Check the arcs"):
        # for each arc, check if our target is a valid transition
        if arc.target in ocpn.transitions:
            # load all the prior places of a valid transition into a dictionary, where the key is the transition and the value
            # a list of all directly prior places
            if arc.target.name in targets:
                targets[arc.target.name].append(arc.source.name)
            else:
                targets[arc.target.name] = [arc.source.name]
        if arc.source in ocpn.transitions:
            # load all the following places of a valid transition into a dictionary, where the key is the transition and the value
            # a list of all directly following places
            if arc.source.name in sources:
                sources[arc.source.name].append(arc.target.name)
            else:
                sources[arc.source.name] = [arc.target.name]
    # generate an empty dictionary to store the directly preceeding transition of an activity
    preceding_activities = {}
    # use the key and value of targets and source to generate the dictionary
    for target_key, target_value in targets.items():
        preceding_activities[target_key] = []
        for source_key, source_value in sources.items():
            for element in target_value:
                if element in source_value:
                    preceding_activities[target_key].append(source_key)
                    break
    # generate an empty dictionary to store the directly succeeding transition of an activity
    succeeding_activities = {}
    for source_key, source_value in sources.items():
        succeeding_activities[source_key] = []
        for target_key, target_value in targets.items():
            for element in source_value:
                if element in target_value:
                    succeeding_activities[source_key].append(target_key)
                    break
    # store the name of all silent transitions in the log
    silent_transitions = [x.name for x in ocpn.transitions if x.silent]
    # replace the silent transitions in the succeeding activities dictionary by creating a new dictionary to store the modified values
    succeeding_activities_updated = {}
    # Iterate through the dictionary
    for key, values in succeeding_activities.items():
        # Create a list to store the modified values for this key
        new_values = []
        # Iterate through the values of each key
        for i in range(len(values)):
            # Check if the value is in the list of silent transitions
            if values[i] in silent_transitions:
                # Replace the value with the corresponding value from the dictionary
                new_values.extend(succeeding_activities[values[i]])
            else:
                # If the value is not in the list of silent transitions, add it to the new list
                new_values.append(values[i])
        # Add the modified values to the new dictionary
        succeeding_activities_updated[key] = new_values
    # create an empty dictionary to store all the precedding activities of an activity
    preceding_events_dict = {}
    # use a depth-first search (DFS) algorithm to traverse the activity graph and
    # create a list of all preceding events for each activity in the dictionary for directly preceding activities
    for activity in preceding_activities:
        # empty set for all the visited activities
        visited = set()
        # list for all currently preceding events
        preceding_events = []
        dfs(preceding_activities, visited, activity, preceding_events)
        # we need to remove the last element from the list because it corresponds to the activity itself
        preceding_events_dict[activity] = preceding_events[:-1][::-1]
    # delete all possible silent transitions from preceding_events_dict (dict where all direct preceeding events are stored)
    filtered_preceeding_events_full = filter_silent_transitions(preceding_events_dict, silent_transitions)
    # delete all possible silent transitions from filtered_preceeding_events (dict where only direct preceeding events are stored)
    filtered_preceeding_events = filter_silent_transitions(preceding_activities, silent_transitions)
    # delete all possible silent transitions from succeeding_activities_updated (dict where only direct preceeding events are stored)
    filtered_succeeding_activities_updated = filter_silent_transitions(succeeding_activities_updated,silent_transitions)
    #get average length of an process execution in the original log
    # group by event_execution and count the number of rows in each group
    grouped = ocel.log.log.groupby('event_execution').count()

    # find the event_execution with the lowest and highest number of rows to filter out outliers that distort the length
    lowest = grouped['event_activity'].idxmin()
    highest = grouped['event_activity'].idxmax()

    # filter out the rows corresponding to the process executions with the lowest and highest number of rows to filter out outliers
    df_filtered = ocel.log.log[(ocel.log.log['event_execution'] != lowest) & (ocel.log.log['event_execution'] != highest)]

    # group by event_execution and count the number of rows in each group again
    grouped_filtered = df_filtered.groupby('event_execution').count()

    # calculate the average number of activities per process execution
    avg_activities = grouped_filtered.mean()['event_activity']
    if length == None:
        limit_length = np.round(2 * avg_activities).astype(int)
    else:
        limit_length = length
    #define an empty list for the event log
    event_log_sampled = []
    # store the name of all non-silent transitions in the log to check for variant model in if else statements
    non_silent_transitions = [x.name for x in ocpn.transitions if not x.silent]
    #sample the desired amount of traces
    for j in tqdm(range(amount), desc="Generate the traces"):
        #get a list of all activities that need to be executed before the process is finished
        end_activities = [key for key, value in filtered_succeeding_activities_updated.items() if not value]
        # if all succeeding events equal all preceeding events, we have a flower model and almost everything is enabled all the time
        if filtered_preceeding_events==filtered_succeeding_activities_updated:
            enabled = list(np.unique(ocel.log.log.event_activity))
        #check if one of the non-silent transitions ends with a number, then we have a variant model
        elif non_silent_transitions[0][-1].isdigit():
            #generate the variants
            ocel.variants
            # get the amount of variants in the log
            amount_variants = len(np.unique(ocel.log.log['event_variant']))
            # Generate a random integer between 0 and amount of variants -1 to generate the path we are using
            trace_number = random.randint(0, amount_variants-1)
            # Use a list comprehension to filter out end activities that don't end with the trace number, also checks string length to avoid matching numbers containing the target number.
            end_activities = [x for x in end_activities if x.endswith(str(trace_number)) and (len(x) == len(str(trace_number)) or not x[-len(str(trace_number))-1].isdigit())]
            #generate the list of enabled activities
            enabled = [key for key, value in filtered_preceeding_events_full.items() if not value]
            # Use a list comprehension to filter out enabled activities that don't end with the trace number, also checks string length to avoid matching numbers containing the target number.
            enabled = [x for x in enabled if x.endswith(str(trace_number)) and (len(x) == len(str(trace_number)) or not x[-len(str(trace_number))-1].isdigit())]
        else:
            # list for all the activities that are enabled, starting from all activities that do not have any preceeding activity
            enabled = [key for key, value in filtered_preceeding_events_full.items() if not value]
        # initialise a list of already executed activities in this trace
        trace = []
        # the maximum length of a trace is the double of the average trace length in the log
        for i in range(limit_length):
            # get a random activity from the enabled cases to add to the trace
            # check if there are any enabled activities
            if enabled:
                # generate a random index for an enabled activity
                idx = random.randint(0, len(enabled)-1)

                #get the current activity
                executed_activity = enabled[idx]

                # add the activity at the random index to the trace
                trace.append(executed_activity)

                # remove the activity from enabled activities
                enabled.remove(executed_activity)
            # get all possible new enabled activities
            possible_enabled = filtered_succeeding_activities_updated[executed_activity]
            # check if each activity has more than one directly preceeding state
            for i in range(len(possible_enabled)):
                # check if an event has two or more activities that need to be executed before the event can take place, if not add events to enabled
                if len(filtered_preceeding_events[possible_enabled[i]]) < 2:
                    enabled.append(possible_enabled[i])
                # if all succeeding events equal all preceeding events, we have a flower model and almost everything is enabled all the time
                elif filtered_preceeding_events[possible_enabled[i]] == filtered_succeeding_activities_updated[
                    possible_enabled[i]]:
                    enabled.append(possible_enabled[i])
                else:
                    # if yes, check if all the needed activities have already been performed in this trace
                    if all(elem in trace for elem in filtered_preceeding_events[possible_enabled[i]]):
                        enabled.append(possible_enabled[i])
            #check if activity is an end activity
            if executed_activity in end_activities:
                #if yes get all activites that need to be executed beforehand
                preceeding_activities = filtered_preceeding_events_full[executed_activity]
                #delete these activites from the enabled list if a loop may be possible
                enabled = [x for x in enabled if x not in preceeding_activities]
            # delete all duplicates from the enabled list
            enabled = list(set(enabled))
            #check if all end activities have been performed and if end_activities is non empty
            if end_activities and all(x in trace for x in end_activities):
                break
        event_log_sampled.append(trace)
    if save_path is not None:
        with open(save_path, "w", encoding="utf-8") as file:
            for sentence in event_log_sampled:
                line = " ".join(sentence) + "\n"
                file.write(line)
    return event_log_sampled

# %%
filtered_preceeding_events_full
# Out:
# {'incidentskip_7': ['New Incident',
#   'incidentinit_loop_4',
#   'incidenttau_1',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12'],
#  'incidenttauSplit_15': ['incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_22': ['incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'New Incident': ['incidentinit_loop_4',
#   'incidenttau_1',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12'],
#  'incidentskip_25': ['Active',
#   'incidentinit_loop_23',
#   'incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentinit_loop_40': ['incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'Awaiting Problem': ['incidentskip_37',
#   'incidentinit_loop_35',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_33': ['incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'Resolved': ['incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_38': ['Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentinit_loop_45': ['incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_49': ['Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidenttauJoin_16': ['incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_17': ['incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidenttau_2': ['incidentskip_52',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_11',
#   'incidentskip_51',
#   'incidentinit_loop_9',
#   'customerskip_7',
#   'incidentskip_8',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidenttauJoin_32': ['incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_26': ['Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_50': ['Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'customerskip_9': ['customertau_1'],
#  'Closed Incident': ['incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_11',
#   'incidentskip_51',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1',
#   'customerskip_7'],
#  'incidentskip_3': ['incidenttau_1'],
#  'incidentinit_loop_28': ['incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidenttauJoin_13': ['incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_47': ['Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_8': ['incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'customertau_1': [],
#  'customerinit_loop_10': ['customertau_1'],
#  'customertauJoin_4': ['customerskip_13',
#   'customerskip_9',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_11',
#   'incidentskip_51',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1',
#   'customerskip_7'],
#  'customerskip_7': ['Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_11',
#   'incidentskip_51',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentinit_loop_23': ['incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_14': ['incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_21': ['Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'Awaiting Evidence': ['incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'Awaiting Vendor': ['incidentinit_loop_45',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1',
#   'incidentskip_47'],
#  'incidentskip_43': ['Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_48': ['Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1',
#   'incidentskip_47'],
#  'incidentskip_27': ['incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentinit_loop_9': ['incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentinit_loop_18': ['incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_6': ['New Incident',
#   'incidentinit_loop_4',
#   'incidenttau_1',
#   'customerinit_loop_10',
#   'customertau_1',
#   'customerskip_12'],
#  'incidentinit_loop_4': ['incidenttau_1'],
#  'Active': ['incidentskip_25',
#   'incidentinit_loop_23',
#   'incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentinit_loop_35': ['incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'customerskip_12': ['New Incident',
#   'incidentinit_loop_4',
#   'incidenttau_1',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6'],
#  'incidenttauSplit_31': ['incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_42': ['Awaiting Evidence',
#   'incidentinit_loop_40',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidenttau_1': [],
#  'incidentskip_51': ['Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_11',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1',
#   'customerskip_7'],
#  'Awaiting User Info': ['incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_37': ['Awaiting Problem',
#   'incidentinit_loop_35',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_11': ['incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_20': ['Awaiting User Info',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_39': ['incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_52': ['Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_11',
#   'incidentskip_51',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1',
#   'customerskip_7'],
#  'incidentskip_30': ['incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'customerskip_13': ['New Incident',
#   'incidentinit_loop_4',
#   'incidenttau_1',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12'],
#  'incidentskip_44': ['incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidenttauSplit_12': ['incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_34',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentinit_loop_28',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1'],
#  'incidentskip_34': ['incidenttauSplit_31',
#   'incidentinit_loop_28',
#   'incidenttauSplit_12',
#   'incidentskip_51',
#   'Closed Incident',
#   'incidenttauJoin_13',
#   'incidentskip_27',
#   'incidenttauJoin_16',
#   'incidentskip_26',
#   'Active',
#   'incidentskip_25',
#   'incidentinit_loop_23',
#   'incidentskip_17',
#   'incidentskip_22',
#   'incidentskip_21',
#   'Awaiting User Info',
#   'incidentskip_20',
#   'incidentinit_loop_18',
#   'incidenttauSplit_15',
#   'incidentskip_14',
#   'incidentskip_50',
#   'Resolved',
#   'incidenttauJoin_32',
#   'incidentskip_44',
#   'incidentskip_43',
#   'Awaiting Evidence',
#   'incidentskip_42',
#   'incidentinit_loop_40',
#   'incidentskip_33',
#   'incidentskip_48',
#   'Awaiting Vendor',
#   'incidentinit_loop_45',
#   'incidentskip_47',
#   'incidentskip_39',
#   'incidentskip_38',
#   'Awaiting Problem',
#   'incidentskip_37',
#   'incidentinit_loop_35',
#   'incidentskip_30',
#   'incidentskip_49',
#   'incidentskip_11',
#   'customerskip_7',
#   'incidentinit_loop_9',
#   'incidentskip_7',
#   'New Incident',
#   'incidentinit_loop_4',
#   'customerinit_loop_10',
#   'customertau_1',
#   'incidentskip_6',
#   'customerskip_12',
#   'incidentskip_3',
#   'incidenttau_1']}

# %%
filtered_preceeding_events_full['New Incident']
# Out:
# ['incidentinit_loop_4',
#  'incidenttau_1',
#  'customerinit_loop_10',
#  'customertau_1',
#  'incidentskip_6',
#  'customerskip_12']

# %%
filtered_preceeding_events
# Out:
# {'incidentskip_7': ['New Incident'],
#  'incidenttauSplit_15': ['incidenttauSplit_12'],
#  'incidentskip_22': ['incidenttauSplit_15'],
#  'New Incident': ['customerskip_12',
#   'incidentskip_6',
#   'customerinit_loop_10',
#   'incidentinit_loop_4'],
#  'incidentskip_25': ['Active'],
#  'incidentinit_loop_40': ['incidentskip_34', 'incidentskip_38'],
#  'Awaiting Problem': ['incidentinit_loop_35', 'incidentskip_37'],
#  'incidentskip_33': ['incidenttauSplit_31'],
#  'Resolved': ['incidentskip_30', 'incidenttauJoin_32'],
#  'incidentskip_38': ['Awaiting Problem'],
#  'incidentinit_loop_45': ['incidenttauSplit_31'],
#  'incidentskip_49': ['Resolved'],
#  'incidenttauJoin_16': ['incidentskip_21',
#   'incidentskip_22',
#   'incidentskip_17',
#   'incidentskip_26'],
#  'incidentskip_17': ['incidenttauSplit_15'],
#  'incidenttau_2': ['incidentskip_8', 'incidentskip_52'],
#  'incidenttauJoin_32': ['incidentskip_39',
#   'incidentskip_48',
#   'incidentskip_33',
#   'incidentskip_43',
#   'incidentskip_44'],
#  'incidentskip_26': ['Active'],
#  'incidentskip_50': ['Resolved'],
#  'customerskip_9': ['customertau_1'],
#  'Closed Incident': ['customerskip_7',
#   'incidentskip_11',
#   'customertau_1',
#   'incidenttauJoin_13'],
#  'incidentskip_3': ['incidenttau_1'],
#  'incidentinit_loop_28': ['incidenttauSplit_12'],
#  'incidenttauJoin_13': ['incidentskip_50',
#   'incidentskip_14',
#   'incidenttauJoin_16',
#   'incidentskip_27'],
#  'incidentskip_47': ['Awaiting Vendor'],
#  'incidentskip_8': ['incidentskip_3', 'incidentskip_7'],
#  'customertau_1': [],
#  'customerinit_loop_10': ['customertau_1'],
#  'customertauJoin_4': ['Closed Incident', 'customerskip_9', 'customerskip_13'],
#  'customerskip_7': ['Closed Incident'],
#  'incidentinit_loop_23': ['incidenttauSplit_15'],
#  'incidentskip_14': ['incidenttauSplit_12'],
#  'incidentskip_21': ['Awaiting User Info'],
#  'Awaiting Evidence': ['incidentinit_loop_40', 'incidentskip_42'],
#  'Awaiting Vendor': ['incidentskip_47', 'incidentinit_loop_45'],
#  'incidentskip_43': ['Awaiting Evidence'],
#  'incidentskip_48': ['Awaiting Vendor'],
#  'incidentskip_27': ['incidenttauSplit_12'],
#  'incidentinit_loop_9': ['incidentskip_3', 'incidentskip_7'],
#  'incidentinit_loop_18': ['incidenttauSplit_15'],
#  'incidentskip_6': ['New Incident'],
#  'incidentinit_loop_4': ['incidenttau_1'],
#  'Active': ['incidentinit_loop_23', 'incidentskip_25'],
#  'incidentinit_loop_35': ['incidenttauSplit_31'],
#  'customerskip_12': ['New Incident'],
#  'incidenttauSplit_31': ['incidentinit_loop_28', 'incidentskip_49'],
#  'incidentskip_42': ['Awaiting Evidence'],
#  'incidenttau_1': [],
#  'incidentskip_51': ['Closed Incident'],
#  'Awaiting User Info': ['incidentinit_loop_18', 'incidentskip_20'],
#  'incidentskip_37': ['Awaiting Problem'],
#  'incidentskip_11': ['incidentinit_loop_9', 'incidentskip_51'],
#  'incidentskip_20': ['Awaiting User Info'],
#  'incidentskip_39': ['incidentskip_34', 'incidentskip_38'],
#  'incidentskip_52': ['Closed Incident'],
#  'incidentskip_30': ['incidentinit_loop_28', 'incidentskip_49'],
#  'customerskip_13': ['New Incident'],
#  'incidentskip_44': ['incidenttauSplit_31'],
#  'incidenttauSplit_12': ['incidentinit_loop_9', 'incidentskip_51'],
#  'incidentskip_34': ['incidenttauSplit_31']}

# %%
filtered_succeeding_activities_updated
# Out:
# {'incidenttau_2': [],
#  'incidentskip_3': ['incidenttau_2', 'incidentskip_11', 'incidenttauSplit_12'],
#  'Closed Incident': ['Closed Incident',
#   'incidentskip_11',
#   'incidenttauSplit_12',
#   'incidenttau_2'],
#  'incidenttauSplit_15': ['incidenttauJoin_16',
#   'incidenttauJoin_16',
#   'Active',
#   'Awaiting User Info'],
#  'incidentinit_loop_18': ['Awaiting User Info'],
#  'customerskip_7': ['Closed Incident'],
#  'incidentskip_47': ['Awaiting Vendor'],
#  'incidentskip_50': ['Closed Incident'],
#  'incidentskip_7': ['incidenttau_2', 'incidentskip_11', 'incidenttauSplit_12'],
#  'customerskip_12': ['New Incident'],
#  'incidentskip_39': ['Resolved'],
#  'incidenttau_1': ['incidentskip_8', 'incidentinit_loop_9', 'New Incident'],
#  'incidentskip_48': ['Resolved'],
#  'Awaiting Vendor': ['Awaiting Vendor', 'incidenttauJoin_32'],
#  'incidenttauSplit_31': ['incidenttauJoin_32',
#   'Awaiting Vendor',
#   'Awaiting Problem',
#   'incidenttauJoin_32',
#   'incidentinit_loop_40',
#   'incidentskip_39'],
#  'incidentskip_33': ['Resolved'],
#  'incidentskip_43': ['Resolved'],
#  'incidentskip_6': ['New Incident'],
#  'incidentskip_21': ['incidenttauJoin_13'],
#  'incidentinit_loop_40': ['Awaiting Evidence'],
#  'New Incident': ['incidentskip_8',
#   'incidentinit_loop_9',
#   'New Incident',
#   'New Incident',
#   'customertauJoin_4'],
#  'incidentskip_44': ['Resolved'],
#  'incidentskip_11': ['Closed Incident'],
#  'incidentskip_14': ['Closed Incident'],
#  'incidentskip_42': ['Awaiting Evidence'],
#  'incidentinit_loop_35': ['Awaiting Problem'],
#  'customertau_1': ['customertauJoin_4', 'Closed Incident', 'New Incident'],
#  'Awaiting User Info': ['incidenttauJoin_16', 'Awaiting User Info'],
#  'incidentskip_22': ['incidenttauJoin_13'],
#  'incidenttauJoin_16': ['Closed Incident'],
#  'incidentinit_loop_28': ['incidentskip_33',
#   'incidentinit_loop_45',
#   'incidentinit_loop_35',
#   'incidentskip_44',
#   'incidentskip_34',
#   'Resolved'],
#  'incidentskip_20': ['Awaiting User Info'],
#  'incidenttauJoin_13': ['Closed Incident'],
#  'Awaiting Problem': ['incidentinit_loop_40',
#   'incidentskip_39',
#   'Awaiting Problem'],
#  'incidentinit_loop_9': ['Closed Incident',
#   'incidenttauSplit_15',
#   'incidentinit_loop_28',
#   'incidentskip_14',
#   'incidentskip_27'],
#  'customerinit_loop_10': ['New Incident'],
#  'incidentskip_51': ['Closed Incident',
#   'incidenttauSplit_15',
#   'incidentinit_loop_28',
#   'incidentskip_14',
#   'incidentskip_27'],
#  'incidentskip_34': ['Awaiting Evidence', 'incidenttauJoin_32'],
#  'incidentskip_49': ['incidentskip_33',
#   'incidentinit_loop_45',
#   'incidentinit_loop_35',
#   'incidentskip_44',
#   'incidentskip_34',
#   'Resolved'],
#  'incidentinit_loop_4': ['New Incident'],
#  'incidentskip_37': ['Awaiting Problem'],
#  'incidentskip_38': ['Awaiting Evidence', 'incidenttauJoin_32'],
#  'incidentskip_17': ['incidenttauJoin_13'],
#  'incidentinit_loop_23': ['Active'],
#  'incidentskip_8': [],
#  'incidentskip_30': ['Resolved'],
#  'incidenttauSplit_12': ['incidentskip_22',
#   'incidentskip_17',
#   'incidentinit_loop_23',
#   'incidentinit_loop_18',
#   'incidenttauSplit_31',
#   'incidentskip_30',
#   'incidenttauJoin_13',
#   'incidenttauJoin_13'],
#  'customertauJoin_4': [],
#  'incidentinit_loop_45': ['Awaiting Vendor'],
#  'incidentskip_27': ['Closed Incident'],
#  'incidentskip_25': ['Active'],
#  'customerskip_9': [],
#  'Resolved': ['incidenttauSplit_31', 'incidentskip_30', 'incidenttauJoin_13'],
#  'incidentskip_26': ['incidenttauJoin_13'],
#  'customerskip_13': [],
#  'incidentskip_52': [],
#  'incidenttauJoin_32': ['Resolved'],
#  'Active': ['Active', 'incidenttauJoin_16'],
#  'Awaiting Evidence': ['incidenttauJoin_32', 'Awaiting Evidence']}

# %%
train_log = sample_traces(ocel, ocpn, 1)
# Out:
# Check the arcs: 100%|██████████| 130/130 [00:00<00:00, 55621.70it/s]
# Generate the traces: 100%|██████████| 1/1 [00:00<00:00, 996.27it/s]

# %%
train_log
# Out:
# [['New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident',
#   'New Incident']]
