# %% [markdown]
# # Log conversion and preprocessing

# %% [markdown]
# In this file, we preprocess the logs from the cases and variants paper in object-centric process mining by Adams et al., before we can convert them into JSON-OCEL.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from ocpa.objects.log.importer.csv import factory as ocel_import_factory_csv
from ocpa.objects.log.exporter.ocel import factory as ocel_export_factory

# %%
def preprocess_csv(path,ots):
    """
    Function to preprocess the csv file of the object-centric event log.
    :param path: path to the csv file, type: string
    :param ots: list of object types, type: list
    :return: preprocessed event log, type: pandas dataframe
    """
    #Load the file into a pandas dataframe
    event_df = pd.read_csv(path)
    # split string elements by commas and strip leading/trailing whitespace to generate the lists of objects for the specific object type
    for t in ots:
        event_df[t] = event_df[t].map(lambda x: [y.strip() for y in x.split(',')] if isinstance(x, str) else [])
        #generate the event_id column and the index column in the same way
    event_df["event_id"] = list(range(0, len(event_df)))
    event_df.index = list(range(0, len(event_df)))
    event_df["event_id"] = event_df["event_id"].astype(float).astype(int)
    return event_df

# %% [markdown]
# ## DS3 log

# %%
#first dataset
dataset = "../src/data/csv/DS3.csv"
types = ["incident","customer"]

event_df = preprocess_csv(dataset, types)
#rename the timestamp column such that it fits the pattern
event_df = event_df.rename(columns={'event_closed_at': 'event_timestamp'})
event_df.to_csv("../src/data/csv/DS3.csv",index=False)

# %%
#import the dataframe again and convert it to a JSON-OCEL log
parameters = {
            "obj_names": ["incident","customer"],
            "val_names": [],
            "act_name": "event_activity",
            "time_name": "event_timestamp",
            "sep": ",",
        }
ocel_new = ocel_import_factory_csv.apply(file_path="../src/data/csv/DS3.csv", parameters=parameters)
print("Number of process executions: "+str(len(ocel_new.process_executions)))
print("Number of variants: "+str(len(ocel_new.variants)))
#export the JSON-OCEL file for better usability
ocel_export_factory.apply(
    ocel_new, '../src/data/jsonocel/DS3.jsonocel')
# Out:
# Number of process executions: 4825
# Number of variants: 3380
# {'ocel:global-log': {'ocel:attribute-names': ['event_category',
#    'event_location',
#    'event_cmdb_ci',
#    'event_resolved_at',
#    'event_sys_created_by',
#    'event_problem_id',
#    'event_subcategory',
#    'event_assigned_to',
#    'event_sys_updated_at',
#    'event_sys_created_at',
#    'event_resource',
#    'event_sys_mod_count',
#    'event_knowledge',
#    'event_made_sla',
#    'event_u_symptom',
#    'event_rfc',
#    'event_reopen_count',
#    'event_vendor',
#    'event_u_priority_confirmation',
#    'event_reassignment_count',
#    'event_resolved_by',
#    'event_active',
#    'event_index',
#    'event_priority',
#    'event_sys_updated_by',
#    'event_contact_type',
#    'event_caused_by',
#    'event_assignment_group',
#    'event_notify',
#    'event_urgency',
#    'event_closed_code',
#    'event_id',
#    'event_opened_at',
#    'event_impact'],
#   'ocel:object-types': ['incident', 'customer'],
#   'ocel:version': '1.0',
#   'ocel:ordering': 'timestamp'},
#  'ocel:global-event': {'ocel:activity': '__INVALID__'},
#  'ocel:global-object': {'ocel:type': '__INVALID__'},
#  'ocel:events': {'0': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-05-03T12:00:00',
#    'ocel:omap': ['INC0000045', 'Caller 2403'],
#    'ocel:vmap': {'event_category': 'Category 55',
#     'event_location': 'Location 143',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 11:29',
#     'event_sys_created_by': 'Created by 6',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 170',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 01:23',
#     'event_sys_created_at': '29/02/2016 01:23',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 0,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 72',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 149',
#     'event_active': True,
#     'event_index': 0,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 21',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 56',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 0,
#     'event_opened_at': '29/02/2016 01:16',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-05-03 12:00:00')}},
#   '1': {'ocel:activity': 'Resolved',
#    'ocel:timestamp': '2016-05-03T12:00:00',
#    'ocel:omap': ['INC0000045'],
#    'ocel:vmap': {'event_category': 'Category 55',
#     'event_location': 'Location 143',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 11:29',
#     'event_sys_created_by': 'Created by 6',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 170',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 08:53',
#     'event_sys_created_at': '29/02/2016 01:23',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 2,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 72',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 149',
#     'event_active': True,
#     'event_index': 1,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 642',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 56',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 1,
#     'event_opened_at': '29/02/2016 01:16',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-05-03 12:00:00')}},
#   '2': {'ocel:activity': 'Resolved',
#    'ocel:timestamp': '2016-05-03T12:00:00',
#    'ocel:omap': ['INC0000045'],
#    'ocel:vmap': {'event_category': 'Category 55',
#     'event_location': 'Location 143',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 11:29',
#     'event_sys_created_by': 'Created by 6',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 170',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 11:29',
#     'event_sys_created_at': '29/02/2016 01:23',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 3,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 72',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 149',
#     'event_active': True,
#     'event_index': 2,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 804',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 56',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 2,
#     'event_opened_at': '29/02/2016 01:16',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-05-03 12:00:00')}},
#   '3': {'ocel:activity': 'Closed Incident',
#    'ocel:timestamp': '2016-05-03T12:00:00',
#    'ocel:omap': ['INC0000045', 'Caller 2403'],
#    'ocel:vmap': {'event_category': 'Category 55',
#     'event_location': 'Location 143',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 11:29',
#     'event_sys_created_by': 'Created by 6',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 170',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '05/03/2016 12:00',
#     'event_sys_created_at': '29/02/2016 01:23',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 4,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 72',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 149',
#     'event_active': False,
#     'event_index': 3,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 908',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 56',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 3,
#     'event_opened_at': '29/02/2016 01:16',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-05-03 12:00:00')}},
#   '4': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-06-03T10:00:00',
#    'ocel:omap': ['INC0000047', 'Caller 2403'],
#    'ocel:vmap': {'event_category': 'Category 40',
#     'event_location': 'Location 165',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 09:52',
#     'event_sys_created_by': 'Created by 171',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 215',
#     'event_assigned_to': 'Resolver 89',
#     'event_sys_updated_at': '29/02/2016 04:57',
#     'event_sys_created_at': '29/02/2016 04:57',
#     'event_resource': 'Opened by  397',
#     'event_sys_mod_count': 0,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 81',
#     'event_active': True,
#     'event_index': 4,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 746',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 4,
#     'event_opened_at': '29/02/2016 04:40',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 10:00:00')}},
#   '5': {'ocel:activity': 'Active',
#    'ocel:timestamp': '2016-06-03T10:00:00',
#    'ocel:omap': ['INC0000047'],
#    'ocel:vmap': {'event_category': 'Category 40',
#     'event_location': 'Location 165',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 09:52',
#     'event_sys_created_by': 'Created by 171',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 215',
#     'event_assigned_to': 'Resolver 31',
#     'event_sys_updated_at': '29/02/2016 05:30',
#     'event_sys_created_at': '29/02/2016 04:57',
#     'event_resource': 'Opened by  397',
#     'event_sys_mod_count': 1,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 81',
#     'event_active': True,
#     'event_index': 5,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 21',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 24',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 5,
#     'event_opened_at': '29/02/2016 04:40',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 10:00:00')}},
#   '6': {'ocel:activity': 'Active',
#    'ocel:timestamp': '2016-06-03T10:00:00',
#    'ocel:omap': ['INC0000047'],
#    'ocel:vmap': {'event_category': 'Category 40',
#     'event_location': 'Location 165',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 09:52',
#     'event_sys_created_by': 'Created by 171',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 215',
#     'event_assigned_to': 'Resolver 31',
#     'event_sys_updated_at': '29/02/2016 05:33',
#     'event_sys_created_at': '29/02/2016 04:57',
#     'event_resource': 'Opened by  397',
#     'event_sys_mod_count': 2,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 81',
#     'event_active': True,
#     'event_index': 6,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 21',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 24',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 6,
#     'event_opened_at': '29/02/2016 04:40',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 10:00:00')}},
#   '7': {'ocel:activity': 'Active',
#    'ocel:timestamp': '2016-06-03T10:00:00',
#    'ocel:omap': ['INC0000047'],
#    'ocel:vmap': {'event_category': 'Category 40',
#     'event_location': 'Location 165',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 09:52',
#     'event_sys_created_by': 'Created by 171',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 215',
#     'event_assigned_to': 'Resolver 31',
#     'event_sys_updated_at': '29/02/2016 11:31',
#     'event_sys_created_at': '29/02/2016 04:57',
#     'event_resource': 'Opened by  397',
#     'event_sys_mod_count': 3,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 81',
#     'event_active': True,
#     'event_index': 7,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 804',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 24',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 7,
#     'event_opened_at': '29/02/2016 04:40',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 10:00:00')}},
#   '8': {'ocel:activity': 'Active',
#    'ocel:timestamp': '2016-06-03T10:00:00',
#    'ocel:omap': ['INC0000047'],
#    'ocel:vmap': {'event_category': 'Category 40',
#     'event_location': 'Location 165',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 09:52',
#     'event_sys_created_by': 'Created by 171',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 215',
#     'event_assigned_to': 'Resolver 31',
#     'event_sys_updated_at': '29/02/2016 11:32',
#     'event_sys_created_at': '29/02/2016 04:57',
#     'event_resource': 'Opened by  397',
#     'event_sys_mod_count': 4,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 81',
#     'event_active': True,
#     'event_index': 8,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 703',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 24',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 8,
#     'event_opened_at': '29/02/2016 04:40',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 10:00:00')}},
#   '9': {'ocel:activity': 'Active',
#    'ocel:timestamp': '2016-06-03T10:00:00',
#    'ocel:omap': ['INC0000047'],
#    'ocel:vmap': {'event_category': 'Category 40',
#     'event_location': 'Location 165',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 09:52',
#     'event_sys_created_by': 'Created by 171',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 215',
#     'event_assigned_to': 'Resolver 31',
#     'event_sys_updated_at': '01/03/2016 09:14',
#     'event_sys_created_at': '29/02/2016 04:57',
#     'event_resource': 'Opened by  397',
#     'event_sys_mod_count': 5,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 81',
#     'event_active': True,
#     'event_index': 9,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 332',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 24',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 9,
#     'event_opened_at': '29/02/2016 04:40',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 10:00:00')}},
#   '10': {'ocel:activity': 'Awaiting User Info',
#    'ocel:timestamp': '2016-06-03T10:00:00',
#    'ocel:omap': ['INC0000047'],
#    'ocel:vmap': {'event_category': 'Category 40',
#     'event_location': 'Location 165',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 09:52',
#     'event_sys_created_by': 'Created by 171',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 215',
#     'event_assigned_to': 'Resolver 89',
#     'event_sys_updated_at': '01/03/2016 09:14',
#     'event_sys_created_at': '29/02/2016 04:57',
#     'event_resource': 'Opened by  397',
#     'event_sys_mod_count': 6,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 81',
#     'event_active': True,
#     'event_index': 10,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 332',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 24',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 10,
#     'event_opened_at': '29/02/2016 04:40',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 10:00:00')}},
#   '11': {'ocel:activity': 'Resolved',
#    'ocel:timestamp': '2016-06-03T10:00:00',
#    'ocel:omap': ['INC0000047'],
#    'ocel:vmap': {'event_category': 'Category 40',
#     'event_location': 'Location 165',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 09:52',
#     'event_sys_created_by': 'Created by 171',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 215',
#     'event_assigned_to': 'Resolver 89',
#     'event_sys_updated_at': '01/03/2016 09:52',
#     'event_sys_created_at': '29/02/2016 04:57',
#     'event_resource': 'Opened by  397',
#     'event_sys_mod_count': 7,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 81',
#     'event_active': True,
#     'event_index': 11,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 332',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 24',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 11,
#     'event_opened_at': '29/02/2016 04:40',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 10:00:00')}},
#   '12': {'ocel:activity': 'Closed Incident',
#    'ocel:timestamp': '2016-06-03T10:00:00',
#    'ocel:omap': ['INC0000047', 'Caller 2403'],
#    'ocel:vmap': {'event_category': 'Category 40',
#     'event_location': 'Location 165',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 09:52',
#     'event_sys_created_by': 'Created by 171',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 215',
#     'event_assigned_to': 'Resolver 89',
#     'event_sys_updated_at': '06/03/2016 10:00',
#     'event_sys_created_at': '29/02/2016 04:57',
#     'event_resource': 'Opened by  397',
#     'event_sys_mod_count': 8,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 81',
#     'event_active': False,
#     'event_index': 12,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 908',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 24',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 5',
#     'event_id': 12,
#     'event_opened_at': '29/02/2016 04:40',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 10:00:00')}},
#   '13': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-06-03T03:00:00',
#    'ocel:omap': ['INC0000057', 'Caller 4416'],
#    'ocel:vmap': {'event_category': 'Category 20',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 02:55',
#     'event_sys_created_by': '?',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 125',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 06:26',
#     'event_sys_created_at': '?',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 0,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 5',
#     'event_active': True,
#     'event_index': 13,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 21',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 10',
#     'event_id': 13,
#     'event_opened_at': '29/02/2016 06:10',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 03:00:00')}},
#   '14': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-06-03T03:00:00',
#    'ocel:omap': ['INC0000057', 'Caller 4416'],
#    'ocel:vmap': {'event_category': 'Category 20',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 02:55',
#     'event_sys_created_by': '?',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 125',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 06:38',
#     'event_sys_created_at': '?',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 1,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 5',
#     'event_active': True,
#     'event_index': 14,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 21',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 10',
#     'event_id': 14,
#     'event_opened_at': '29/02/2016 06:10',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 03:00:00')}},
#   '15': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-06-03T03:00:00',
#    'ocel:omap': ['INC0000057', 'Caller 4416'],
#    'ocel:vmap': {'event_category': 'Category 20',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 02:55',
#     'event_sys_created_by': '?',
#     'event_problem_id': 'Problem ID  2',
#     'event_subcategory': 'Subcategory 125',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 10:06',
#     'event_sys_created_at': '?',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 2,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 5',
#     'event_active': True,
#     'event_index': 15,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 451',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 10',
#     'event_id': 15,
#     'event_opened_at': '29/02/2016 06:10',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 03:00:00')}},
#   '16': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-06-03T03:00:00',
#    'ocel:omap': ['INC0000057', 'Caller 4416'],
#    'ocel:vmap': {'event_category': 'Category 20',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 02:55',
#     'event_sys_created_by': '?',
#     'event_problem_id': 'Problem ID  2',
#     'event_subcategory': 'Subcategory 125',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '01/03/2016 02:53',
#     'event_sys_created_at': '?',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 3,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 5',
#     'event_active': True,
#     'event_index': 16,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 21',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 10',
#     'event_id': 16,
#     'event_opened_at': '29/02/2016 06:10',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 03:00:00')}},
#   '17': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-06-03T03:00:00',
#    'ocel:omap': ['INC0000057', 'Caller 4416'],
#    'ocel:vmap': {'event_category': 'Category 20',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 02:55',
#     'event_sys_created_by': '?',
#     'event_problem_id': 'Problem ID  2',
#     'event_subcategory': 'Subcategory 125',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '01/03/2016 02:54',
#     'event_sys_created_at': '?',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 4,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 5',
#     'event_active': True,
#     'event_index': 17,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 21',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 10',
#     'event_id': 17,
#     'event_opened_at': '29/02/2016 06:10',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 03:00:00')}},
#   '18': {'ocel:activity': 'Resolved',
#    'ocel:timestamp': '2016-06-03T03:00:00',
#    'ocel:omap': ['INC0000057'],
#    'ocel:vmap': {'event_category': 'Category 20',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 02:55',
#     'event_sys_created_by': '?',
#     'event_problem_id': 'Problem ID  2',
#     'event_subcategory': 'Subcategory 125',
#     'event_assigned_to': 'Resolver 6',
#     'event_sys_updated_at': '01/03/2016 02:55',
#     'event_sys_created_at': '?',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 5,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 5',
#     'event_active': True,
#     'event_index': 18,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 21',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 10',
#     'event_id': 18,
#     'event_opened_at': '29/02/2016 06:10',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 03:00:00')}},
#   '19': {'ocel:activity': 'Closed Incident',
#    'ocel:timestamp': '2016-06-03T03:00:00',
#    'ocel:omap': ['INC0000057', 'Caller 4416'],
#    'ocel:vmap': {'event_category': 'Category 20',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '01/03/2016 02:55',
#     'event_sys_created_by': '?',
#     'event_problem_id': 'Problem ID  2',
#     'event_subcategory': 'Subcategory 125',
#     'event_assigned_to': 'Resolver 6',
#     'event_sys_updated_at': '06/03/2016 03:00',
#     'event_sys_created_at': '?',
#     'event_resource': 'Opened by  8',
#     'event_sys_mod_count': 6,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 5',
#     'event_active': False,
#     'event_index': 19,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 908',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 10',
#     'event_id': 19,
#     'event_opened_at': '29/02/2016 06:10',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-06-03 03:00:00')}},
#   '20': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-07-03T13:00:00',
#    'ocel:omap': ['INC0000060', 'Caller 4491'],
#    'ocel:vmap': {'event_category': 'Category 9',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '02/03/2016 12:06',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 97',
#     'event_assigned_to': 'Resolver 125',
#     'event_sys_updated_at': '29/02/2016 06:42',
#     'event_sys_created_at': '29/02/2016 06:42',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 0,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 450',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 113',
#     'event_active': True,
#     'event_index': 20,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 340',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 25',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 3',
#     'event_id': 20,
#     'event_opened_at': '29/02/2016 06:38',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-07-03 13:00:00')}},
#   '21': {'ocel:activity': 'Active',
#    'ocel:timestamp': '2016-07-03T13:00:00',
#    'ocel:omap': ['INC0000060'],
#    'ocel:vmap': {'event_category': 'Category 9',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '02/03/2016 12:06',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 97',
#     'event_assigned_to': 'Resolver 125',
#     'event_sys_updated_at': '02/03/2016 08:52',
#     'event_sys_created_at': '29/02/2016 06:42',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 1,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 450',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 113',
#     'event_active': True,
#     'event_index': 21,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 465',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 25',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 3',
#     'event_id': 21,
#     'event_opened_at': '29/02/2016 06:38',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-07-03 13:00:00')}},
#   '22': {'ocel:activity': 'Resolved',
#    'ocel:timestamp': '2016-07-03T13:00:00',
#    'ocel:omap': ['INC0000060'],
#    'ocel:vmap': {'event_category': 'Category 9',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '02/03/2016 12:06',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 97',
#     'event_assigned_to': 'Resolver 125',
#     'event_sys_updated_at': '02/03/2016 12:06',
#     'event_sys_created_at': '29/02/2016 06:42',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 2,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 450',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 113',
#     'event_active': True,
#     'event_index': 22,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 465',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 25',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 3',
#     'event_id': 22,
#     'event_opened_at': '29/02/2016 06:38',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-07-03 13:00:00')}},
#   '23': {'ocel:activity': 'Closed Incident',
#    'ocel:timestamp': '2016-07-03T13:00:00',
#    'ocel:omap': ['INC0000060', 'Caller 4491'],
#    'ocel:vmap': {'event_category': 'Category 9',
#     'event_location': 'Location 204',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '02/03/2016 12:06',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 97',
#     'event_assigned_to': 'Resolver 125',
#     'event_sys_updated_at': '07/03/2016 13:00',
#     'event_sys_created_at': '29/02/2016 06:42',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 3,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 450',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 113',
#     'event_active': False,
#     'event_index': 23,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 908',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 25',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 3',
#     'event_id': 23,
#     'event_opened_at': '29/02/2016 06:38',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-07-03 13:00:00')}},
#   '24': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-05-03T16:00:00',
#    'ocel:omap': ['INC0000062', 'Caller 3765'],
#    'ocel:vmap': {'event_category': 'Category 53',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 15:51',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 168',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 07:26',
#     'event_sys_created_at': '29/02/2016 07:26',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 0,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 232',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': True,
#     'event_index': 24,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 340',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 7',
#     'event_id': 24,
#     'event_opened_at': '29/02/2016 06:58',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-05-03 16:00:00')}},
#   '25': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-05-03T16:00:00',
#    'ocel:omap': ['INC0000062', 'Caller 3765'],
#    'ocel:vmap': {'event_category': 'Category 53',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 15:51',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 168',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 07:29',
#     'event_sys_created_at': '29/02/2016 07:26',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 1,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 232',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': True,
#     'event_index': 25,
#     'event_priority': '2 - High',
#     'event_sys_updated_by': 'Updated by 340',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 7',
#     'event_id': 25,
#     'event_opened_at': '29/02/2016 06:58',
#     'event_impact': '1 - High',
#     'start_timestamp': Timestamp('2016-05-03 16:00:00')}},
#   '26': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-05-03T16:00:00',
#    'ocel:omap': ['INC0000062', 'Caller 3765'],
#    'ocel:vmap': {'event_category': 'Category 53',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 15:51',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 168',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 07:34',
#     'event_sys_created_at': '29/02/2016 07:26',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 2,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 232',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': True,
#     'event_index': 26,
#     'event_priority': '2 - High',
#     'event_sys_updated_by': 'Updated by 340',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 23',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 7',
#     'event_id': 26,
#     'event_opened_at': '29/02/2016 06:58',
#     'event_impact': '1 - High',
#     'start_timestamp': Timestamp('2016-05-03 16:00:00')}},
#   '27': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-05-03T16:00:00',
#    'ocel:omap': ['INC0000062', 'Caller 3765'],
#    'ocel:vmap': {'event_category': 'Category 53',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 15:51',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 168',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 11:23',
#     'event_sys_created_at': '29/02/2016 07:26',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 3,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 232',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': True,
#     'event_index': 27,
#     'event_priority': '2 - High',
#     'event_sys_updated_by': 'Updated by 804',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 23',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 7',
#     'event_id': 27,
#     'event_opened_at': '29/02/2016 06:58',
#     'event_impact': '1 - High',
#     'start_timestamp': Timestamp('2016-05-03 16:00:00')}},
#   '28': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-05-03T16:00:00',
#    'ocel:omap': ['INC0000062', 'Caller 3765'],
#    'ocel:vmap': {'event_category': 'Category 53',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 15:51',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 168',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 11:28',
#     'event_sys_created_at': '29/02/2016 07:26',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 4,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 232',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': True,
#     'event_index': 28,
#     'event_priority': '2 - High',
#     'event_sys_updated_by': 'Updated by 804',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 23',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 7',
#     'event_id': 28,
#     'event_opened_at': '29/02/2016 06:58',
#     'event_impact': '1 - High',
#     'start_timestamp': Timestamp('2016-05-03 16:00:00')}},
#   '29': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-05-03T16:00:00',
#    'ocel:omap': ['INC0000062', 'Caller 3765'],
#    'ocel:vmap': {'event_category': 'Category 53',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 15:51',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 168',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 15:51',
#     'event_sys_created_at': '29/02/2016 07:26',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 5,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 232',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': True,
#     'event_index': 29,
#     'event_priority': '2 - High',
#     'event_sys_updated_by': 'Updated by 241',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 23',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 7',
#     'event_id': 29,
#     'event_opened_at': '29/02/2016 06:58',
#     'event_impact': '1 - High',
#     'start_timestamp': Timestamp('2016-05-03 16:00:00')}},
#   '30': {'ocel:activity': 'Resolved',
#    'ocel:timestamp': '2016-05-03T16:00:00',
#    'ocel:omap': ['INC0000062'],
#    'ocel:vmap': {'event_category': 'Category 53',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 15:51',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 168',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 15:51',
#     'event_sys_created_at': '29/02/2016 07:26',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 6,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 232',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': True,
#     'event_index': 30,
#     'event_priority': '2 - High',
#     'event_sys_updated_by': 'Updated by 241',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 23',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 7',
#     'event_id': 30,
#     'event_opened_at': '29/02/2016 06:58',
#     'event_impact': '1 - High',
#     'start_timestamp': Timestamp('2016-05-03 16:00:00')}},
#   '31': {'ocel:activity': 'Closed Incident',
#    'ocel:timestamp': '2016-05-03T16:00:00',
#    'ocel:omap': ['INC0000062', 'Caller 3765'],
#    'ocel:vmap': {'event_category': 'Category 53',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 15:51',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 168',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '05/03/2016 16:00',
#     'event_sys_created_at': '29/02/2016 07:26',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 7,
#     'event_knowledge': True,
#     'event_made_sla': False,
#     'event_u_symptom': 'Symptom 232',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 1,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': False,
#     'event_index': 31,
#     'event_priority': '2 - High',
#     'event_sys_updated_by': 'Updated by 908',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 23',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 7',
#     'event_id': 31,
#     'event_opened_at': '29/02/2016 06:58',
#     'event_impact': '1 - High',
#     'start_timestamp': Timestamp('2016-05-03 16:00:00')}},
#   '32': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-05-03T17:00:00',
#    'ocel:omap': ['INC0000063', 'Caller 2146'],
#    'ocel:vmap': {'event_category': 'Category 20',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 16:01',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 125',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 07:17',
#     'event_sys_created_at': '29/02/2016 07:17',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 0,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': True,
#     'event_index': 32,
#     'event_priority': '3 - Moderate',
#     'event_sys_updated_by': 'Updated by 340',
#     'event_contact_type': 'Phone',
#     'event_caused_by': '?',
#     'event_assignment_group': 'Group 70',
#     'event_notify': 'Do Not Notify',
#     'event_urgency': '2 - Medium',
#     'event_closed_code': 'code 7',
#     'event_id': 32,
#     'event_opened_at': '29/02/2016 07:08',
#     'event_impact': '2 - Medium',
#     'start_timestamp': Timestamp('2016-05-03 17:00:00')}},
#   '33': {'ocel:activity': 'New Incident',
#    'ocel:timestamp': '2016-05-03T17:00:00',
#    'ocel:omap': ['INC0000063', 'Caller 2146'],
#    'ocel:vmap': {'event_category': 'Category 20',
#     'event_location': 'Location 93',
#     'event_cmdb_ci': '?',
#     'event_resolved_at': '29/02/2016 16:01',
#     'event_sys_created_by': 'Created by 81',
#     'event_problem_id': '?',
#     'event_subcategory': 'Subcategory 125',
#     'event_assigned_to': '?',
#     'event_sys_updated_at': '29/02/2016 07:23',
#     'event_sys_created_at': '29/02/2016 07:17',
#     'event_resource': 'Opened by  180',
#     'event_sys_mod_count': 1,
#     'event_knowledge': True,
#     'event_made_sla': True,
#     'event_u_symptom': 'Symptom 471',
#     'event_rfc': '?',
#     'event_reopen_count': 0,
#     'event_vendor': '?',
#     'event_u_priority_confirmation': False,
#     'event_reassignment_count': 0,
#     'event_resolved_by': 'Resolved by 62',
#     'event_active': True,
#     'event_index': 33,
#     'event_priority': '3 - Moderate',
# ...
#   'INC0000786': {'ocel:type': 'incident', 'ocel:ovmap': {}},
#   'Caller 
            "time_name": "event_timestamp",
            "sep": ",",
        }
ocel_new = ocel_import_factory_csv.apply(file_path="../src/data/csv/DS4.csv", parameters=parameters)
print("Number of process executions: "+str(len(ocel_new.process_executions)))
print("Number of variants: "+str(len(ocel_new.variants)))
#export the JSON-OCEL file for better usability
ocel_export_factory.apply(
    ocel_new, '../src/data/jsonocel/DS4.jsonocel')
# Out:
# Number of process executions: 14507
# Number of variants: 7259
# {'ocel:global-log': {'ocel:attribute-names': ['event_Unnamed: 0',
#    'event_starttime',
#    'event_resource',
#    'event_subprocess',
#    'event_object',
#    'event_docid',
#    'event_identity:id',
#    'event_id',
#    'event_index',
#    'event_success',
#    'event_year',
#    'event_new_activity'],
#   'ocel:object-types': ['Inspection',
#    'Reference alignment',
#    'Geo parcel document',
#    'Entitlement application',
#    'Control summary',
#    'Payment application'],
#   'ocel:version': '1.0',
#   'ocel:ordering': 'timestamp'},
#  'ocel:global-event': {'ocel:activity': '__INVALID__'},
#  'ocel:global-object': {'ocel:type': '__INVALID__'},
#  'ocel:events': {'0': {'ocel:activity': 'Payment application mail income',
#    'ocel:timestamp': '2017-04-07T00:00:00',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661656,
#     'event_starttime': '2017/04/07 00:00:00.000',
#     'event_resource': '0;n/a',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': 'AC63C080-C312-4987-93BE-035B845BDDBD',
#     'event_id': 0,
#     'event_index': 0,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application mail income',
#     'start_timestamp': Timestamp('2017-04-07 00:00:00')}},
#   '1': {'ocel:activity': 'Payment application mail valid',
#    'ocel:timestamp': '2017-04-25T00:00:00',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661657,
#     'event_starttime': '2017/04/25 00:00:00.000',
#     'event_resource': '0;n/a',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '66C6670C-DA26-4B2B-91DA-359E6AAA8A48',
#     'event_id': 1,
#     'event_index': 1,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application mail valid',
#     'start_timestamp': Timestamp('2017-04-25 00:00:00')}},
#   '2': {'ocel:activity': 'Geo parcel document initialize',
#    'ocel:timestamp': '2017-05-01T06:28:07.247000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09', 'adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661658,
#     'event_starttime': '2017/05/01 06:28:07.247',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'C1699E11-DA64-40B4-BE16-2A7940D3D87C',
#     'event_id': 2,
#     'event_index': 2,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document initialize',
#     'start_timestamp': Timestamp('2017-05-01 06:28:07.247000')}},
#   '3': {'ocel:activity': 'Geo parcel document begin editing',
#    'ocel:timestamp': '2017-05-01T06:28:07.286000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661659,
#     'event_starttime': '2017/05/01 06:28:07.286',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'AD587043-F3EE-49C5-8CED-7D7DEEDB8518',
#     'event_id': 3,
#     'event_index': 3,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document begin editing',
#     'start_timestamp': Timestamp('2017-05-01 06:28:07.286000')}},
#   '4': {'ocel:activity': 'Control summary initialize',
#    'ocel:timestamp': '2017-05-01T06:28:08',
#    'ocel:omap': ['746E7AC7-0A2B-413B-BCD1-853779C5A5D3', 'adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661660,
#     'event_starttime': '2017/05/01 06:28:08.000',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '746E7AC7-0A2B-413B-BCD1-853779C5A5D3',
#     'event_docid': -18008424147455741,
#     'event_identity:id': '8B7DCD6B-188A-423A-85E8-7E97B78CBCB9',
#     'event_id': 4,
#     'event_index': 4,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Control summary initialize',
#     'start_timestamp': Timestamp('2017-05-01 06:28:08')}},
#   '5': {'ocel:activity': 'Control summary begin editing',
#    'ocel:timestamp': '2017-05-01T06:28:08',
#    'ocel:omap': ['746E7AC7-0A2B-413B-BCD1-853779C5A5D3'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661661,
#     'event_starttime': '2017/05/01 06:28:08.000',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '746E7AC7-0A2B-413B-BCD1-853779C5A5D3',
#     'event_docid': -18008424147455741,
#     'event_identity:id': 'EB903D97-0356-45C9-AC70-BA0C1388AB5A',
#     'event_id': 5,
#     'event_index': 5,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Control summary begin editing',
#     'start_timestamp': Timestamp('2017-05-01 06:28:08')}},
#   '6': {'ocel:activity': 'Control summary finish editing',
#    'ocel:timestamp': '2017-05-01T06:28:08',
#    'ocel:omap': ['746E7AC7-0A2B-413B-BCD1-853779C5A5D3'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661662,
#     'event_starttime': '2017/05/01 06:28:08.000',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '746E7AC7-0A2B-413B-BCD1-853779C5A5D3',
#     'event_docid': -18008424147455741,
#     'event_identity:id': '7BEC3442-90B3-4057-9775-3ACB2B94CA90',
#     'event_id': 6,
#     'event_index': 6,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Control summary finish editing',
#     'start_timestamp': Timestamp('2017-05-01 06:28:08')}},
#   '7': {'ocel:activity': 'Geo parcel document create',
#    'ocel:timestamp': '2017-05-01T06:28:08.580000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661663,
#     'event_starttime': '2017/05/01 06:28:08.580',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'DBA39780-2E5C-40C8-8854-15E4D1CFF2F7',
#     'event_id': 7,
#     'event_index': 7,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document create',
#     'start_timestamp': Timestamp('2017-05-01 06:28:08.580000')}},
#   '8': {'ocel:activity': 'Geo parcel document clear',
#    'ocel:timestamp': '2017-05-11T06:49:44.034000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661664,
#     'event_starttime': '2017/05/11 06:49:44.034',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'FD0B1E1E-8567-4EEB-A57D-EE0459DB5130',
#     'event_id': 8,
#     'event_index': 8,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document clear',
#     'start_timestamp': Timestamp('2017-05-11 06:49:44.034000')}},
#   '9': {'ocel:activity': 'Geo parcel document create',
#    'ocel:timestamp': '2017-05-11T06:49:45.437000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661665,
#     'event_starttime': '2017/05/11 06:49:45.437',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '79A2FACD-EEB5-478E-8670-D194FC20AA07',
#     'event_id': 9,
#     'event_index': 9,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document create',
#     'start_timestamp': Timestamp('2017-05-11 06:49:45.437000')}},
#   '10': {'ocel:activity': 'Geo parcel document clear',
#    'ocel:timestamp': '2017-05-11T08:02:49.791000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661666,
#     'event_starttime': '2017/05/11 08:02:49.791',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'D41496D3-0B0B-44F6-8497-66F10CA3A4D5',
#     'event_id': 10,
#     'event_index': 10,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document clear',
#     'start_timestamp': Timestamp('2017-05-11 08:02:49.791000')}},
#   '11': {'ocel:activity': 'Geo parcel document create',
#    'ocel:timestamp': '2017-05-11T08:02:51.797000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661667,
#     'event_starttime': '2017/05/11 08:02:51.797',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'EB96CEC7-3416-42F6-87F0-53FA68774FA8',
#     'event_id': 11,
#     'event_index': 11,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document create',
#     'start_timestamp': Timestamp('2017-05-11 08:02:51.797000')}},
#   '12': {'ocel:activity': 'Geo parcel document clear',
#    'ocel:timestamp': '2017-05-11T13:31:34.146000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661668,
#     'event_starttime': '2017/05/11 13:31:34.146',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '774FC406-1DA8-4DC1-9D8A-9096732E0AA6',
#     'event_id': 12,
#     'event_index': 12,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document clear',
#     'start_timestamp': Timestamp('2017-05-11 13:31:34.146000')}},
#   '13': {'ocel:activity': 'Geo parcel document create',
#    'ocel:timestamp': '2017-05-11T13:31:35.403000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661669,
#     'event_starttime': '2017/05/11 13:31:35.403',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '297780CE-1EBA-44AC-81F3-962C0240D5B6',
#     'event_id': 13,
#     'event_index': 13,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document create',
#     'start_timestamp': Timestamp('2017-05-11 13:31:35.403000')}},
#   '14': {'ocel:activity': 'Geo parcel document clear',
#    'ocel:timestamp': '2017-05-18T13:01:35.415000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661670,
#     'event_starttime': '2017/05/18 13:01:35.415',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'F2CD19C7-E9D8-44C1-AC7D-2306C1A6F705',
#     'event_id': 14,
#     'event_index': 14,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document clear',
#     'start_timestamp': Timestamp('2017-05-18 13:01:35.415000')}},
#   '15': {'ocel:activity': 'Geo parcel document create',
#    'ocel:timestamp': '2017-05-18T13:01:38.466000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661671,
#     'event_starttime': '2017/05/18 13:01:38.466',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '80AC9FFF-730A-4A44-80E1-0B4CECF4C022',
#     'event_id': 15,
#     'event_index': 15,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document create',
#     'start_timestamp': Timestamp('2017-05-18 13:01:38.466000')}},
#   '16': {'ocel:activity': 'Geo parcel document finish pre-check',
#    'ocel:timestamp': '2017-07-31T14:44:30.878000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661672,
#     'event_starttime': '2017/07/31 14:44:30.878',
#     'event_resource': '03b214',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '69818E07-76AD-4E15-9C76-044C034D3CD8',
#     'event_id': 16,
#     'event_index': 16,
#     'event_success': False,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish pre-check',
#     'start_timestamp': Timestamp('2017-07-31 14:44:30.878000')}},
#   '17': {'ocel:activity': 'Geo parcel document save',
#    'ocel:timestamp': '2017-07-31T14:45:42.089000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09', 'adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661673,
#     'event_starttime': '2017/07/31 14:45:42.089',
#     'event_resource': '03b214',
#     'event_subprocess': 'Main',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '73A014F3-6A2E-40B6-B2B1-5D203E651E4B',
#     'event_id': 17,
#     'event_index': 17,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document save',
#     'start_timestamp': Timestamp('2017-07-31 14:45:42.089000')}},
#   '18': {'ocel:activity': 'Geo parcel document finish pre-check',
#    'ocel:timestamp': '2017-07-31T14:45:45.750000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661674,
#     'event_starttime': '2017/07/31 14:45:45.750',
#     'event_resource': '03b214',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '0E9A9050-0BB4-4ADD-94ED-DA73107EA1BC',
#     'event_id': 18,
#     'event_index': 18,
#     'event_success': False,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish pre-check',
#     'start_timestamp': Timestamp('2017-07-31 14:45:45.750000')}},
#   '19': {'ocel:activity': 'Geo parcel document save',
#    'ocel:timestamp': '2017-07-31T14:46:02.334000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09', 'adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661675,
#     'event_starttime': '2017/07/31 14:46:02.334',
#     'event_resource': '03b214',
#     'event_subprocess': 'Main',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '62D54B33-1F41-43EA-BAFC-C811B181D48A',
#     'event_id': 19,
#     'event_index': 19,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document save',
#     'start_timestamp': Timestamp('2017-07-31 14:46:02.334000')}},
#   '20': {'ocel:activity': 'Geo parcel document finish pre-check',
#    'ocel:timestamp': '2017-07-31T14:46:03.990000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661676,
#     'event_starttime': '2017/07/31 14:46:03.990',
#     'event_resource': '03b214',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'EA0C5D4E-7B13-4A81-863C-4ECE75C9C267',
#     'event_id': 20,
#     'event_index': 20,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish pre-check',
#     'start_timestamp': Timestamp('2017-07-31 14:46:03.990000')}},
#   '21': {'ocel:activity': 'Geo parcel document finish editing',
#    'ocel:timestamp': '2017-07-31T14:46:14.648000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661677,
#     'event_starttime': '2017/07/31 14:46:14.648',
#     'event_resource': '03b214',
#     'event_subprocess': 'Declared',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '949C4642-B7F4-4A6F-8C57-0B3BC1FFDCE0',
#     'event_id': 21,
#     'event_index': 21,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish editing',
#     'start_timestamp': Timestamp('2017-07-31 14:46:14.648000')}},
#   '22': {'ocel:activity': 'Reference alignment initialize',
#    'ocel:timestamp': '2017-09-26T12:01:54',
#    'ocel:omap': ['059C3D90-60E2-4BA4-AA10-BAC154B167BD', 'adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661678,
#     'event_starttime': '2017/09/26 12:01:54.000',
#     'event_resource': 'scheduler',
#     'event_subprocess': 'Main',
#     'event_object': '059C3D90-60E2-4BA4-AA10-BAC154B167BD',
#     'event_docid': -18008373046451827,
#     'event_identity:id': 'B35FB05E-3594-4DA3-BF26-B26AEDEBFF79',
#     'event_id': 22,
#     'event_index': 22,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Reference alignment initialize',
#     'start_timestamp': Timestamp('2017-09-26 12:01:54')}},
#   '23': {'ocel:activity': 'Reference alignment performed',
#    'ocel:timestamp': '2017-09-26T12:01:54',
#    'ocel:omap': ['059C3D90-60E2-4BA4-AA10-BAC154B167BD'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661679,
#     'event_starttime': '2017/09/26 12:01:54.000',
#     'event_resource': 'scheduler',
#     'event_subprocess': 'Main',
#     'event_object': '059C3D90-60E2-4BA4-AA10-BAC154B167BD',
#     'event_docid': -18008373046451827,
#     'event_identity:id': '350EFB29-1E58-4EEB-B873-5B1883BB2E1A',
#     'event_id': 23,
#     'event_index': 23,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Reference alignment performed',
#     'start_timestamp': Timestamp('2017-09-26 12:01:54')}},
#   '24': {'ocel:activity': 'Payment application initialize',
#    'ocel:timestamp': '2017-10-23T07:37:43.891000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661680,
#     'event_starttime': '2017/10/23 07:37:43.891',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': 'B751ACA5-2C51-4F71-9F61-CAD66501C075',
#     'event_id': 24,
#     'event_index': 24,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application initialize',
#     'start_timestamp': Timestamp('2017-10-23 07:37:43.891000')}},
#   '25': {'ocel:activity': 'Geo parcel document calculate',
#    'ocel:timestamp': '2017-10-29T11:21:31.893000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661681,
#     'event_starttime': '2017/10/29 11:21:31.893',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '57FC9ED1-CAD4-4B99-B952-0ECA1F500CD3',
#     'event_id': 25,
#     'event_index': 25,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document calculate',
#     'start_timestamp': Timestamp('2017-10-29 11:21:31.893000')}},
#   '26': {'ocel:activity': 'Geo parcel document finish editing',
#    'ocel:timestamp': '2017-10-29T11:21:32.033000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661682,
#     'event_starttime': '2017/10/29 11:21:32.033',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'D820EBE1-AEC3-443A-89AB-A40B86B57A36',
#     'event_id': 26,
#     'event_index': 26,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish editing',
#     'start_timestamp': Timestamp('2017-10-29 11:21:32.033000')}},
#   '27': {'ocel:activity': 'Geo parcel document begin editing',
#    'ocel:timestamp': '2017-11-12T20:19:42.550000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661683,
#     'event_starttime': '2017/11/12 20:19:42.550',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '13F40EAB-D4F2-4108-9AC9-D87D15F2A400',
#     'event_id': 27,
#     'event_index': 27,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document begin editing',
#     'start_timestamp': Timestamp('2017-11-12 20:19:42.550000')}},
#   '28': {'ocel:activity': 'Geo parcel document calculate',
#    'ocel:timestamp': '2017-11-12T20:20:22.696000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661684,
#     'event_starttime': '2017/11/12 20:20:22.696',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '4AD0F63E-BB89-44E1-ACDB-FAC3219F2C7A',
#     'event_id': 28,
#     'event_index': 28,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document calculate',
#     'start_timestamp': Timestamp('2017-11-12 20:20:22.696000')}},
#   '29': {'ocel:activity': 'Geo parcel document finish editing',
#    'ocel:timestamp': '2017-11-12T20:20:22.853000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661685,
#     'event_starttime': '2017/11/12 20:20:22.853',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'B8663DD7-7325-4DB8-92DB-9F3A05F41C80',
#     'event_id': 29,
#     'event_index': 29,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish editing',
#     'start_timestamp': Timestamp('2017-11-12 20:20:22.853000')}},
#   '30': {'ocel:activity': 'Payment application begin editing',
#    'ocel:timestamp': '2017-11-17T07:20:08.693000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661686,
#     'event_starttime': '2017/11/17 07:20:08.693',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '817B11B2-37B6-40B1-95F0-41B2854DE213',
#     'event_id': 30,
#     'event_index': 30,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application begin editing',
#     'start_timestamp': Timestamp('2017-11-17 07:20:08.693000')}},
#   '31': {'ocel:activity': 'Payment application calculate',
#    'ocel:timestamp': '2017-11-17T07:20:22.002000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661687,
#     'event_starttime': '2017/11/17 07:20:22.002',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '7846D05A-06E7-4923-A6CA-199AD6B70109',
#     'event_id': 31,
#     'event_index': 31,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application calculate',
#     'start_timestamp': Timestamp('2017-11-17 07:20:22.002000')}},
#   '32': {'ocel:activity': 'Payment application finish editing',
#    'ocel:timestamp': '2017-11-17T07:20:23.830000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661688,
#     'event_starttime': '2017/11/17 07:20:23.830',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '0E382D9C-6B9C-49CE-96AD-C9A2229493A9',
#     'event_id': 32,
#     'event_index': 32,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application finish editing',
#     'start_timestamp': Timestamp('2017-11-17 07:20:23.830000')}},
#   '33': {'ocel:activity': 'Geo parcel document begin editing',
#    'ocel:timestamp': '2017-11-19T17:41:13.256000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661689,
#     'event_starttime': '2017/11/19 17:41:13.256',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '0EE23BFB-389D-4768-BF62-8FA60F5167CC',
#     'event_id': 33,
#     'event_index': 33,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document begin editing',
#     'start_timestamp': Timestamp('2017-11-19 17:41:13.256000')}},
#   '34': {'ocel:activity': 'Geo parcel document calculate',
#    'ocel:timestamp': '2017-11-19T17:41:53.319000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661690,
#     'event_starttime': '2017/11/19 17:41:53.319',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '18EC5880-9927-4C12-8233-F6655F11A230',
#     'event_id': 34,
#     'event_index': 34,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document calculate',
#     'start_timestamp': Timestamp('2017-11-19 17:41:53.319000')}},
#   '35': {'ocel:activity': 'Geo parcel document finish editing',
#    'ocel:timestamp': '2017-11-19T17:41:53.474000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661691,
#     'event_starttime': '2017/11/19 17:41:53.474',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'D5658A2E-A21B-4EBC-887E-6AABFA525F7B',
#     'event_id': 35,
#     'event_index': 35,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish editing',
#     'start_timestamp': Timestamp('2017-11-19 17:41:53.474000')}},
#   '36': {'ocel:activity': 'Geo parcel document begin editing',
#    'ocel:timestamp': '2017-11-27T14:02:42.226000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661692,
#     'event_starttime': '2017/11/27 14:02:42.226',
#     'event_resource': '97d224',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '3A1B11C9-E178-4D1A-9929-993F68235CE9',
#     'event_id': 36,
#     'event_index': 36,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document begin editing',
#     'start_timestamp': Timestamp('2017-11-27 14:02:42.226000')}},
#   '37': {'ocel:activity': 'Geo parcel document calculate',
#    'ocel:timestamp': '2017-11-27T14:03:44.197000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661693,
#     'event_starttime': '2017/11/27 14:03:44.197',
#     'event_resource': '97d224',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'B94A1698-0147-4DA3-8590-64ABB0E0C4C6',
#     'event_id': 37,
#     'event_index': 37,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document calculate',
#     'start_timestamp': Timestamp('2017-11-27 14:03:44.197000')}},
#   '38': {'ocel:activity': 'Geo parcel document finish editing',
#    'ocel:timestamp': '2017-11-27T14:03:44.339000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661694,
#     'event_starttime': '2017/11/27 14:03:44.339',
#     'event_resource': '97d224',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '857245A3-F0D5-42B3-A456-C617B1137018',
#     'event_id': 38,
#     'event_index': 38,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish editing',
#     'start_timestamp': Timestamp('2017-11-27 14:03:44.339000')}},
#   '39': {'ocel:activity': 'Geo parcel document begin editing',
#    'ocel:timestamp': '2017-12-02T20:37:48.847000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661695,
#     'event_starttime': '2017/12/02 20:37:48.847',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'E5D00837-9548-4A95-9D6A-082143294391',
#     'event_id': 39,
#     'event_index': 39,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document begin editing',
#     'start_timestamp': Timestamp('2017-12-02 20:37:48.847000')}},
#   '40': {'ocel:activity': 'Geo parcel document calculate',
#    'ocel:timestamp': '2017-12-02T20:38:46.064000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661696,
#     'event_starttime': '2017/12/02 20:38:46.064',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'CA37CB6D-AD65-4C2B-AEB7-C7494131914A',
#     'event_id': 40,
#     'event_index': 40,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document calculate',
#     'start_timestamp': Timestamp('2017-12-02 20:38:46.064000')}},
#   '41': {'ocel:activity': 'Geo parcel document finish editing',
#    'ocel:timestamp': '2017-12-02T20:38:46.223000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661697,
#     'event_starttime': '2017/12/02 20:38:46.223',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'CFAB909A-F081-466C-BA0F-65DAB7528D60',
#     'event_id': 41,
#     'event_index': 41,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish editing',
#     'start_timestamp': Timestamp('2017-12-02 20:38:46.223000')}},
#   '42': {'ocel:activity': 'Payment application begin editing',
#    'ocel:timestamp': '2017-12-05T00:30:52.899000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661698,
#     'event_starttime': '2017/12/05 00:30:52.899',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '3C214B51-450E-4AE5-8321-DBD4FA748798',
#     'event_id': 42,
#     'event_index': 42,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application begin editing',
#     'start_timestamp': Timestamp('2017-12-05 00:30:52.899000')}},
#   '43': {'ocel:activity': 'Payment application calculate',
#    'ocel:timestamp': '2017-12-05T00:30:59.546000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661699,
#     'event_starttime': '2017/12/05 00:30:59.546',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '5E547084-4273-43D8-9DB6-1244A880DF31',
#     'event_id': 43,
#     'event_index': 43,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application calculate',
#     'start_timestamp': Timestamp('2017-12-05 00:30:59.546000')}},
#   '44': {'ocel:activity': 'Geo parcel document begin editing',
#    'ocel:timestamp': '2017-12-06T00:14:16.953000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661700,
#     'event_starttime': '2017/12/06 00:14:16.953',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '287EB83F-5A43-4DA8-BD0D-3CD049D84478',
#     'event_id': 44,
#     'event_index': 44,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document begin editing',
#     'start_timestamp': Timestamp('2017-12-06 00:14:16.953000')}},
#   '45': {'ocel:activity': 'Geo parcel document calculate',
#    'ocel:timestamp': '2017-12-06T00:14:21.055000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661701,
#     'event_starttime': '2017/12/06 00:14:21.055',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': '1BCC9977-7E93-4DB5-9BDB-594B011062C5',
#     'event_id': 45,
#     'event_index': 45,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document calculate',
#     'start_timestamp': Timestamp('2017-12-06 00:14:21.055000')}},
#   '46': {'ocel:activity': 'Geo parcel document finish editing',
#    'ocel:timestamp': '2017-12-06T00:14:21.228000',
#    'ocel:omap': ['3863FAD1-8FB3-4F1C-82C6-819D27CE6C09'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661702,
#     'event_starttime': '2017/12/06 00:14:21.228',
#     'event_resource': '727350',
#     'event_subprocess': 'Reported',
#     'event_object': '3863FAD1-8FB3-4F1C-82C6-819D27CE6C09',
#     'event_docid': -18008424147456781,
#     'event_identity:id': 'ECCB88DE-882B-481A-B45F-94A8604D9685',
#     'event_id': 46,
#     'event_index': 46,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish editing',
#     'start_timestamp': Timestamp('2017-12-06 00:14:21.228000')}},
#   '47': {'ocel:activity': 'Payment application calculate',
#    'ocel:timestamp': '2017-12-06T17:11:54.212000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661703,
#     'event_starttime': '2017/12/06 17:11:54.212',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '32F32EEE-6F7B-42FB-B371-855D3FB3D06D',
#     'event_id': 47,
#     'event_index': 47,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application calculate',
#     'start_timestamp': Timestamp('2017-12-06 17:11:54.212000')}},
#   '48': {'ocel:activity': 'Payment application finish editing',
#    'ocel:timestamp': '2017-12-06T17:11:55.110000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661704,
#     'event_starttime': '2017/12/06 17:11:55.110',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': 'D3AD63F4-87B1-40C4-A537-9BD81B9582E7',
#     'event_id': 48,
#     'event_index': 48,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application finish editing',
#     'start_timestamp': Timestamp('2017-12-06 17:11:55.110000')}},
#   '49': {'ocel:activity': 'Payment application begin editing',
#    'ocel:timestamp': '2017-12-08T23:31:26.261000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661705,
#     'event_starttime': '2017/12/08 23:31:26.261',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': 'EC2989F4-ED1F-4AA4-8402-7141199C6E9C',
#     'event_id': 49,
#     'event_index': 49,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application begin editing',
#     'start_timestamp': Timestamp('2017-12-08 23:31:26.261000')}},
#   '50': {'ocel:activity': 'Payment application calculate',
#    'ocel:timestamp': '2017-12-08T23:31:40.421000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661706,
#     'event_starttime': '2017/12/08 23:31:40.421',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': 'A6283B35-A744-4AC8-AE0C-68CD17EF2ABF',
#     'event_id': 50,
#     'event_index': 50,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application calculate',
#     'start_timestamp': Timestamp('2017-12-08 23:31:40.421000')}},
#   '51': {'ocel:activity': 'Payment application finish editing',
#    'ocel:timestamp': '2017-12-08T23:31:42.955000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661707,
#     'event_starttime': '2017/12/08 23:31:42.955',
#     'event_resource': '727350',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '5B57478C-CDA9-421C-A572-B0285A7896EE',
#     'event_id': 51,
#     'event_index': 51,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application finish editing',
#     'start_timestamp': Timestamp('2017-12-08 23:31:42.955000')}},
#   '52': {'ocel:activity': 'Payment application decide',
#    'ocel:timestamp': '2017-12-11T10:22:02.006000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661708,
#     'event_starttime': '2017/12/11 10:22:02.006',
#     'event_resource': '155add',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '49743EA1-CB24-4036-A953-F4FBE27E7C4B',
#     'event_id': 52,
#     'event_index': 52,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application decide',
#     'start_timestamp': Timestamp('2017-12-11 10:22:02.006000')}},
#   '53': {'ocel:activity': 'Payment application begin payment',
#    'ocel:timestamp': '2017-12-15T15:58:59.628000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661709,
#     'event_starttime': '2017/12/15 15:58:59.628',
#     'event_resource': 'DP-Z',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': '9279A361-CF2E-4D9A-8902-0D7CAB2A2A2C',
#     'event_id': 53,
#     'event_index': 53,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application begin payment',
#     'start_timestamp': Timestamp('2017-12-15 15:58:59.628000')}},
#   '54': {'ocel:activity': 'Payment application insert document',
#    'ocel:timestamp': '2017-12-15T19:24:36.444000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661710,
#     'event_starttime': '2017/12/15 19:24:36.444',
#     'event_resource': 'Notification automaton',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': 'FB109840-3D28-429B-AA3D-F7EFE0AF6F9B',
#     'event_id': 54,
#     'event_index': 54,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application insert document',
#     'start_timestamp': Timestamp('2017-12-15 19:24:36.444000')}},
#   '55': {'ocel:activity': 'Payment application insert document',
#    'ocel:timestamp': '2017-12-20T09:02:37.544000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661711,
#     'event_starttime': '2017/12/20 09:02:37.544',
#     'event_resource': 'Notification automaton',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': 'F0459B5E-2A51-47AC-86CD-19D80A48373A',
#     'event_id': 55,
#     'event_index': 55,
#     'event_success': False,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application insert document',
#     'start_timestamp': Timestamp('2017-12-20 09:02:37.544000')}},
#   '56': {'ocel:activity': 'Payment application finish payment',
#    'ocel:timestamp': '2018-01-05T14:54:55.095000',
#    'ocel:omap': ['adcbf6cccf7e6c89'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661712,
#     'event_starttime': '2018/01/05 14:54:55.095',
#     'event_resource': 'DP-Z',
#     'event_subprocess': 'Application',
#     'event_object': 'F6BAE319-09AB-4C7D-9098-BCDF71C14DA7',
#     'event_docid': -54037160734315318,
#     'event_identity:id': 'DC08BB5F-AC94-470F-B1F3-68CE7898CC81',
#     'event_id': 56,
#     'event_index': 56,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application finish payment',
#     'start_timestamp': Timestamp('2018-01-05 14:54:55.095000')}},
#   '57': {'ocel:activity': 'Payment application mail income',
#    'ocel:timestamp': '2017-04-06T00:00:00',
#    'ocel:omap': ['492f48ba6e2e3219'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661713,
#     'event_starttime': '2017/04/06 00:00:00.000',
#     'event_resource': '0;n/a',
#     'event_subprocess': 'Application',
#     'event_object': 'F72C1EA4-3FF6-4B05-9F76-DC1045F20987',
#     'event_docid': -54037160735347926,
#     'event_identity:id': '59F4782C-49BC-4EC6-8EE9-BA5C2101E57C',
#     'event_id': 57,
#     'event_index': 57,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application mail income',
#     'start_timestamp': Timestamp('2017-04-06 00:00:00')}},
#   '58': {'ocel:activity': 'Payment application mail valid',
#    'ocel:timestamp': '2017-04-06T00:00:00',
#    'ocel:omap': ['492f48ba6e2e3219'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661714,
#     'event_starttime': '2017/04/06 00:00:00.000',
#     'event_resource': '0;n/a',
#     'event_subprocess': 'Application',
#     'event_object': 'F72C1EA4-3FF6-4B05-9F76-DC1045F20987',
#     'event_docid': -54037160735347926,
#     'event_identity:id': 'B7C39163-0157-4E1A-ACB6-40124E439570',
#     'event_id': 58,
#     'event_index': 58,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Payment application mail valid',
#     'start_timestamp': Timestamp('2017-04-06 00:00:00')}},
#   '59': {'ocel:activity': 'Geo parcel document initialize',
#    'ocel:timestamp': '2017-04-28T06:44:09.629000',
#    'ocel:omap': ['52B7E52B-7086-497C-A4FA-FDBD1B2FD154', '492f48ba6e2e3219'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661715,
#     'event_starttime': '2017/04/28 06:44:09.629',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '52B7E52B-7086-497C-A4FA-FDBD1B2FD154',
#     'event_docid': -18008425218537146,
#     'event_identity:id': 'B0D2AF7A-887E-4506-A652-3ED212B1FA8A',
#     'event_id': 59,
#     'event_index': 59,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document initialize',
#     'start_timestamp': Timestamp('2017-04-28 06:44:09.629000')}},
#   '60': {'ocel:activity': 'Geo parcel document begin editing',
#    'ocel:timestamp': '2017-04-28T06:44:09.668000',
#    'ocel:omap': ['52B7E52B-7086-497C-A4FA-FDBD1B2FD154'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661716,
#     'event_starttime': '2017/04/28 06:44:09.668',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Declared',
#     'event_object': '52B7E52B-7086-497C-A4FA-FDBD1B2FD154',
#     'event_docid': -18008425218537146,
#     'event_identity:id': '0ED4E58B-95C8-4B6A-8A1B-75444EFD159E',
#     'event_id': 60,
#     'event_index': 60,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document begin editing',
#     'start_timestamp': Timestamp('2017-04-28 06:44:09.668000')}},
#   '61': {'ocel:activity': 'Geo parcel document finish pre-check',
#    'ocel:timestamp': '2017-04-28T06:44:09.751000',
#    'ocel:omap': ['52B7E52B-7086-497C-A4FA-FDBD1B2FD154'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661717,
#     'event_starttime': '2017/04/28 06:44:09.751',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Declared',
#     'event_object': '52B7E52B-7086-497C-A4FA-FDBD1B2FD154',
#     'event_docid': -18008425218537146,
#     'event_identity:id': 'D2516D22-D71C-48C9-9040-4B83A3BAFF25',
#     'event_id': 61,
#     'event_index': 61,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Geo parcel document finish pre-check',
#     'start_timestamp': Timestamp('2017-04-28 06:44:09.751000')}},
#   '62': {'ocel:activity': 'Control summary initialize',
#    'ocel:timestamp': '2017-04-28T06:44:10',
#    'ocel:omap': ['979011B8-8FA4-46F9-AB92-4C9E2A93E89E', '492f48ba6e2e3219'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661718,
#     'event_starttime': '2017/04/28 06:44:10.000',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '979011B8-8FA4-46F9-AB92-4C9E2A93E89E',
#     'event_docid': -18008425218536176,
#     'event_identity:id': 'AF943EBE-9F4C-4FF4-B59E-86B752DA8882',
#     'event_id': 62,
#     'event_index': 62,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Control summary initialize',
#     'start_timestamp': Timestamp('2017-04-28 06:44:10')}},
#   '63': {'ocel:activity': 'Control summary begin editing',
#    'ocel:timestamp': '2017-04-28T06:44:10',
#    'ocel:omap': ['979011B8-8FA4-46F9-AB92-4C9E2A93E89E'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661719,
#     'event_starttime': '2017/04/28 06:44:10.000',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '979011B8-8FA4-46F9-AB92-4C9E2A93E89E',
#     'event_docid': -18008425218536176,
#     'event_identity:id': '2FD64196-0DF0-4FF1-A1B9-61AF2631B141',
#     'event_id': 63,
#     'event_index': 63,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Control summary begin editing',
#     'start_timestamp': Timestamp('2017-04-28 06:44:10')}},
#   '64': {'ocel:activity': 'Control summary finish editing',
#    'ocel:timestamp': '2017-04-28T06:44:10',
#    'ocel:omap': ['979011B8-8FA4-46F9-AB92-4C9E2A93E89E'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661720,
#     'event_starttime': '2017/04/28 06:44:10.000',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Main',
#     'event_object': '979011B8-8FA4-46F9-AB92-4C9E2A93E89E',
#     'event_docid': -18008425218536176,
#     'event_identity:id': '832A7E05-F6FA-4DD0-97CA-5F24B3CDA135',
#     'event_id': 64,
#     'event_index': 64,
#     'event_success': True,
#     'event_year': 2017,
#     'event_new_activity': 'Control summary finish editing',
#     'start_timestamp': Timestamp('2017-04-28 06:44:10')}},
#   '65': {'ocel:activity': 'Geo parcel document create',
#    'ocel:timestamp': '2017-04-28T06:44:10.596000',
#    'ocel:omap': ['52B7E52B-7086-497C-A4FA-FDBD1B2FD154'],
#    'ocel:vmap': {'event_Unnamed: 0': 1661721,
#     'event_starttime': '2017/04/28 06:44:10.596',
#     'event_resource': 'Document processing automaton',
#     'event_subprocess': 'Declared',
#     'event_object': '52B7E52B-7086-497C-A4FA-FDBD1B2FD154',
#     'event_docid': -18008425218537146,
#     'event_identity:id': '30F4B756-DD89-4A30-ADDD-D13F3C1AA652',
#     'event_id': 65,
#     'event_index': 65,
# ...
#   'E9B2C22B-31D7-478D-9A26-57B9F5402700': {'ocel:type': 'Geo parcel document',
#    'ocel:ovmap': {}},
#   'CED21AFB-FE36-4649-828A-0C200FCD9D17': {'ocel:type': 'Control summary',
#    'ocel:ovmap': {}},
#   '5CF1386A-9BBF-490F-BAB8-0BFE1AC21786': {'ocel:type': 'Reference alignment',
#    'ocel:ovmap': {}},
#   '1e17eb186bb0dacc': {'ocel:type': 'Payment application', 'ocel:ovmap': {}},
#   '3E314DA3-DDC2-4CBE-AA2E-F32F63AC0DBE': {'ocel:type': 'Control summary',
#    'ocel:ovmap': {}},
#   